# %% [markdown]
# ## NB-03 Information Retrieval

# %% [markdown]
# Now that I have selected my embeddings and added them to the postgreSQL database, we can now use PGVector to run our similarity searches to retrieve our desired chunks which will form the final stage of our RAG pipeline
#
# What I want to do here is to generate the query prompt, and then feed it into the model - treat it as a chunk -> tokenise it -> generate the token-level embeddings vector -> alter the vector embeddings with context specific considerations -> amalgamate to produce a chunk level of embedding ->
#
# After the retrieval portion
# Reranking chunks before answering using a cross-encoder

# %%
# Imports
import pandas as pd
from dotenv import load_dotenv
from sqlalchemy import text, create_engine
from sqlalchemy.orm import sessionmaker
import os
# Import the main components
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# Imports from the 🤗 HuggingFace transformers library.
from transformers import AutoTokenizer, AutoModel

#loading the env file
load_dotenv()

# Create a connection to your database
engine = create_engine(os.getenv("DATABASE_URL"))

# Create a session
session = sessionmaker(engine)()

# %%
import sys
import os
import importlib

parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

import w2v_pre_processing
importlib.reload(w2v_pre_processing)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/bilalhashim/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/bilalhashim/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/bilalhashim/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# <module 'w2v_pre_processing' from '/Users/bilalhashim/Desktop/LSE/Year 4/DS205/summative_project_2/problem-set-2-BilalNHashim/w2v_pre_processing.py'>

# %%
with engine.connect() as conn:
    conn.execute(text("""
        CREATE INDEX IF NOT EXISTS doc_chunks_embedding_idx
        ON doc_chunks
        USING ivfflat (embedding vector_cosine_ops)
        WITH (lists = 100);
    """))
    conn.commit()

# %% [markdown]
# ## Prompt Engineering

# %% [markdown]
# In this section I am trying to identify the most optimal set of prompts that I can use, we reintroduce the climate BERT model to embed the prompts

# %%
from w2v_pre_processing import get_pooled_embeddings
climate_model_name = 'climatebert/distilroberta-base-climate-f'
climate_tokeniser = AutoTokenizer.from_pretrained(climate_model_name)
climate_roberta_model = AutoModel.from_pretrained(climate_model_name)

def tokenize_for_transformer_climate_roberta(text):
    return climate_tokeniser(text, truncation=True, padding=True, return_tensors="pt")
# Out:
# /Users/bilalhashim/Desktop/LSE/Year 4/DS205/summative_project_2/problem-set-2-BilalNHashim/venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of RobertaModel were not initialized from the model checkpoint at climatebert/distilroberta-base-climate-f and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# This is our baseline query - I distilled down the most important parts of the project problem statement to construct a query which is relevant but not redundantly wordy

# %%
full_query_text = '“What emissions reduction target is each country in the NDC registry aiming for by 2030?”'
query_text = "What are the emissions reduction targets for 2030?"
tokenised_query = tokenize_for_transformer_climate_roberta(query_text)
query_embedding = get_pooled_embeddings(tokenised_query, climate_roberta_model)

embedding_str = f"[{','.join(str(x) for x in query_embedding)}]"
# Out:
# /Users/bilalhashim/Desktop/LSE/Year 4/DS205/summative_project_2/problem-set-2-BilalNHashim/venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of RobertaModel were not initialized from the model checkpoint at climatebert/distilroberta-base-climate-f and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
query = text("SELECT DISTINCT country FROM documents;")

with engine.connect() as conn:
    results = conn.execute(query).fetchall()

# Convert to list
country_list = [row[0] for row in results]
country_list
# Out:
# ['Bangladesh',
#  'Indonesia',
#  'Brunei Darussalam',
#  'Cameroon',
#  'Kiribati',
#  'Viet Nam',
#  'Uganda',
#  'Montenegro',
#  'Jordan',
#  'Syrian Arab Republic',
#  'Dominican Republic',
#  'Cambodia',
#  'Papua New Guinea',
#  'Singapore',
#  'San Marino',
#  'Sri Lanka',
#  'Uzbekistan',
#  'Finland',
#  'Colombia',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'Albania',
#  'Grenada',
#  'Ukraine',
#  'Saudi Arabia',
#  'Sao Tome and Principe',
#  'Cuba',
#  'Kyrgyzstan',
#  'Algeria',
#  'Maldives',
#  'Djibouti',
#  'Israel',
#  'Nauru',
#  'Kenya',
#  'Senegal',
#  'Malaysia',
#  'Ghana',
#  'Iceland',
#  'Zambia',
#  'Kuwait',
#  'Madagascar',
#  'Sierra Leone',
#  'Bosnia and Herzegovina',
#  'Liberia',
#  'Philippines',
#  'Benin',
#  'Tuvalu',
#  'State of Palestine',
#  'Cabo Verde',
#  'Guinea',
#  'Nigeria',
#  'Rwanda',
#  'Tajikistan',
#  'Zimbabwe',
#  "Lao People's Democratic Republic",
#  'China',
#  'Comoros',
#  'Saint Lucia',
#  'Armenia',
#  'Belarus',
#  'Qatar',
#  'Lesotho',
#  'Paraguay',
#  'Gabon',
#  'Australia',
#  'Dominica',
#  'Mauritius',
#  'Serbia',
#  'Angola',
#  'Bahrain',
#  'Vanuatu',
#  'Congo',
#  'United Arab Emirates',
#  'Georgia',
#  'Malawi',
#  'Monaco',
#  'Burundi',
#  'Democratic Republic of the Congo',
#  'Bhutan',
#  'Republic of Korea',
#  'Solomon Islands',
#  'Thailand',
#  'Togo',
#  'Niue',
#  'Burkina Faso',
#  'El Salvador',
#  "Democratic People's Republic of Korea",
#  'Uruguay',
#  'Oman',
#  'Venezuela (Bolivarian Republic of)',
#  'Eswatini',
#  'Micronesia (Federated States of)',
#  'Fiji',
#  'Palau',
#  'Holy See',
#  'Eritrea',
#  'Canada',
#  'Barbados',
#  'Saint Vincent and the Grenadines',
#  'United Republic of Tanzania',
#  'Argentina',
#  'Namibia',
#  'Marshall Islands',
#  'Cook Islands',
#  'Liechtenstein',
#  'Azerbaijan',
#  'Egypt',
#  'Afghanistan',
#  'Bahamas',
#  'Chad',
#  'India',
#  'Timor-Leste',
#  'Chile',
#  'Saint Kitts and Nevis',
#  'Gambia',
#  'Suriname',
#  'South Africa',
#  'Peru',
#  'Kazakhstan',
#  'Central African Republic',
#  'Japan',
#  'Jamaica',
#  'Trinidad and Tobago',
#  'Mongolia',
#  'Iraq',
#  'United States of America',
#  'Mauritania',
#  'Mozambique',
#  'Seychelles',
#  'Switzerland',
#  'New Zealand',
#  'Ecuador',
#  "Côte d'Ivoire",
#  'Honduras',
#  'Belize',
#  'Norway',
#  'Botswana',
#  'Russian Federation',
#  'Pakistan',
#  'Brazil',
#  'Guatemala',
#  'Guinea-Bissau',
#  'Ethiopia',
#  'Niger',
#  'Panama',
#  'South Sudan',
#  'Turkmenistan',
#  'Tunisia',
#  'Sudan',
#  'Mali',
#  'North Macedonia',
#  'Morocco',
#  'Myanmar',
#  'Türkiye',
#  'Nicaragua',
#  'Mexico',
#  'Guyana',
#  'Nepal',
#  'Tonga',
#  'Bolivia (Plurinational State of)',
#  'Lebanon',
#  'Costa Rica',
#  'Republic of Moldova',
#  'Haiti',
#  'Samoa',
#  'Equatorial Guinea',
#  'Antigua and Barbuda',
#  'Somalia',
#  'Andorra']

# %% [markdown]
# Running our similarity search with PGVector based on the baseline query <BR> <BR>
#
# This is the standard similarity search procedure I use for the remainder of the searches (explained in depth in the report.md file)

# %%
# Run similarity search
all_results = []
for country in country_list:
    query = text("""
        SELECT 
            doc_chunks.doc_id,
            doc_chunks.chunk_index,
            doc_chunks.content,
            documents.country,
            (doc_chunks.embedding <=> :embedding) AS similarity
        FROM doc_chunks
        LEFT JOIN documents ON doc_chunks.doc_id = documents.doc_id
        WHERE documents.country = :country
        ORDER BY similarity ASC
        LIMIT 10
    """)

    with engine.connect() as conn:
        results = conn.execute(query, {
            "embedding": embedding_str,
            "country": country
        }).fetchall()

# View results
        df_results = pd.DataFrame(results, columns=["doc_id", "chunk_index", "content", "country", "similarity"])
        df_results.rename(columns={"similarity": "cosine_distance"}, inplace=True)
        df_results["cosine_similarity"] = 1 - df_results["cosine_distance"]
        all_results.append(df_results)

final_df = pd.concat(all_results, ignore_index=True)
# Out:
# /var/folders/v6/xrbmfj054b7cb1_bvtvf02nc0000gn/T/ipykernel_65382/2490464773.py:30: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_df = pd.concat(all_results, ignore_index=True)

# %%
final_df
# Out:
#                                    doc_id chunk_index  \
# 0             bangladesh_english_20220601         450
# 1             bangladesh_english_20220601         305
# 2             bangladesh_english_20220601         366
# 3             bangladesh_english_20220601         545
# 4             bangladesh_english_20220601         502
# ..                                    ...         ...
# 582                samoa_english_20220601         551
# 583  antigua_and_barbuda_english_20220601         367
# 584  antigua_and_barbuda_english_20220601         226
# 585              somalia_english_20220601         198
# 586              andorra_spanish_20250201         134
#
#                                                content              country  \
# 0                                      Actions by 2030           Bangladesh
# 1                                      Actions by 2030           Bangladesh
# 2                                      Actions by 2030           Bangladesh
# 3                                      Actions by 2030           Bangladesh
# 4                                      Actions by 2030           Bangladesh
# ..                                                 ...                  ...
# 582                           Selection of a base year                Samoa
# 583                  an indicative start year of 2025)  Antigua and Barbuda
# 584                      for the period of 2020 - 2030  Antigua and Barbuda
# 585  Estimated investment required (in USD, 2021-20...              Somalia
# 586  at COP28. This document establishes a 63% redu...              Andorra
#
#      cosine_distance  cosine_similarity
# 0           0.029974           0.970026
# 1           0.029974           0.970026
# 2           0.029974           0.970026
# 3           0.029974           0.970026
# 4           0.029974           0.970026
# ..               ...                ...
# 582         0.048144           0.951856
# 583         0.034179           0.965821
# 584         0.047802           0.952198
# 585         0.038558           0.961442
# 586         0.032352           0.967648
#
# [587 rows x 6 columns]

# %%
session.rollback()

# %% [markdown]
# Recall as well from the second notebook that we wanted to also consider words which flagged as being highly similar to the core-words from our query, as this might help to optimise the retrieval process

# %%
import pickle
with open("cumulative_tokens.pkl", "rb") as f:
    cumulative_similar_tokens_query = pickle.load(f)

cumulative_similar_tokens_query
# Out:
# {'emission': [('emissions', 0.8504191637039185),
#   ('net', 0.6021032333374023),
#   ('emisisons', 0.6007767915725708),
#   ('reducfion', 0.6007478833198547),
#   ('emitting', 0.5677352547645569),
#   ('ghgs', 0.6484422087669373),
#   ('concentration', 0.6424049139022827),
#   ('possible', 0.6324024796485901),
#   ('overall', 0.6215030550956726),
#   ('double', 0.6183876395225525)],
#  'reduction': [('reductions', 0.7689696550369263),
#   ('reducing', 0.680912971496582),
#   ('reduce', 0.57728511095047),
#   ('figure', 0.5618992447853088),
#   ('limitation', 0.5305630564689636),
#   ('reducing', 0.7049707770347595),
#   ('reduce', 0.6732713580131531),
#   ('cut', 0.6551539897918701),
#   ('reducfions', 0.6286653876304626),
#   ('double', 0.6259312033653259)],
#  'target': [('targets', 0.8495582342147827),
#   ('updated', 0.7189120650291443),
#   ('commitment', 0.7160426378250122),
#   ('previous', 0.7054238319396973),
#   ('revised', 0.6873401403427124),
#   ('commitment', 0.7701578140258789),
#   ('achieved', 0.7536922693252563),
#   ('goal', 0.7452734112739563),
#   ('scope', 0.7358807921409607),
#   ('objective', 0.7226487398147583)],
#  'country': [('maldives', 0.7952395677566528),
#   ('timor', 0.758872389793396),
#   ('fsm', 0.7489310503005981),
#   ('vanuatu', 0.7475461363792419),
#   ('nation', 0.7434694170951843),
#   ('maldives', 0.7452757358551025),
#   ('one', 0.7288265228271484),
#   ('remains', 0.7279740571975708),
#   ('continues', 0.7200953960418701),
#   ('great', 0.7190268635749817)],
#  'ndc': [('ndcs', 0.835304319858551),
#   ('indc', 0.6963733434677124),
#   ('step', 0.6865456700325012),
#   ('progress', 0.6198812127113342),
#   ('submission', 0.603536069393158),
#   ('ndcs', 0.8271272778511047),
#   ('indc', 0.7242047786712646),
#   ('reflect', 0.6504117846488953),
#   ('realistic', 0.6454455852508545),
#   ('voluntarily', 0.6296104788780212)],
#  'registry': [('budgets', 0.693893313407898),
#   ('trading', 0.6928958892822266),
#   ('pricing', 0.6912561058998108),
#   ('counts', 0.6761153340339661),
#   ('lab', 0.6312073469161987),
#   ('pricing', 0.7779973745346069),
#   ('crediting', 0.7424200773239136),
#   ('trading', 0.6782677173614502),
#   ('count', 0.6722514033317566),
#   ('lab', 0.6701520681381226)],
#  'aiming': [('aimed', 0.8674802780151367),
#   ('least', 0.7418562173843384),
#   ('forefront', 0.7086173295974731),
#   ('heart', 0.6976444125175476),
#   ('looking', 0.6938589811325073),
#   ('aim', 0.8480218052864075),
#   ('seek', 0.8198491334915161),
#   ('aimed', 0.7917417287826538),
#   ('accelerate', 0.7906630635261536),
#   ('ultimately', 0.7859369516372681)]}

# %% [markdown]
# From the above - I have qualitatively identified words that could be used to add context/content richness to our prompts - adding them to the below dict. To note, my embeddings will already be 'aware' of the similarity in these words, but including them can help to ensure a more in line response <BR> <BR>
#
# Here I use a randomisation procedure to construct queries which should, meaningfully replicate the baseline query whilst testing for differences in inclusion of '2030' and '%' and 'percent'

# %%
import random 
similar_queries = []
content_additive_words = {
    'emission': ['net', 'ghgs', 'greenhouse'],
    'target': ['commitment', 'revised', 'goal', 'scope', 'objective'],
    'ndc': ['progress', 'step', 'submission'],
    'aiming': ['looking', 'seeking', 'aiming']
}
date_inclusion = [2030, '']
percent_inclusion = ['percent', '%', '']

for _ in range(10):
    emissions_replacement = random.choice(content_additive_words['emission'])
    target_replacement = random.choice(content_additive_words['target'])
    aiming_replacement = random.choice(content_additive_words['aiming'])
    date_replacement = random.choice(date_inclusion)
    percent_replacement = random.choice(percent_inclusion)

    similar_query = f'{emissions_replacement} {target_replacement} {aiming_replacement} {date_replacement} {percent_replacement}'.strip()
    if similar_query not in similar_queries:
        similar_queries.append(similar_query)
    
similar_queries
# Out:
# ['ghgs commitment seeking 2030 %',
#  'ghgs goal aiming  %',
#  'greenhouse revised aiming  %',
#  'greenhouse objective aiming',
#  'net revised seeking',
#  'greenhouse objective looking 2030 percent',
#  'net goal aiming',
#  'net revised seeking 2030 percent',
#  'greenhouse scope looking  %']

# %% [markdown]
# The above looks to be sound in terms of words included and content. However, the logical coherence of these sentences is of course flawed because of our construction method <BR> <BR>
#
# Below I generate embeddings for each of these queries for similarity search

# %%
similar_queries_embeddings = {}
for query in similar_queries:
    tokenised_query = tokenize_for_transformer_climate_roberta(query)
    query_embedding = get_pooled_embeddings(tokenised_query, climate_roberta_model)
    embedding_str = f"[{','.join(str(x) for x in query_embedding)}]"
    similar_queries_embeddings[query] = embedding_str

similar_queries_embeddings
# Out:
# {'ghgs commitment seeking 2030 %': '[-0.034325443,-0.08202738,-0.07436905,-0.0047721183,0.31819838,0.056827612,-0.04221918,0.08525371,0.034144875,-0.13183677,0.13390619,0.18829918,-0.028370287,-0.15103234,0.09272954,-0.018728342,-0.062804274,0.010321592,0.17176038,0.0138945775,-0.06454671,0.16930975,0.109424055,0.13421376,0.21931915,0.19386443,-0.08955947,-0.06738116,0.087019615,-0.25876868,0.05959017,-0.18063557,0.018344052,0.14599195,0.1666557,0.015410055,0.013845953,0.05855412,-0.14936659,0.11223957,0.112508446,-0.1328705,0.1245174,0.037790876,-0.08439667,0.123526305,0.17833059,0.19197145,0.048318014,-0.00763916,0.06860012,0.026593419,-0.054894883,0.043501243,0.023810243,-0.06658885,-0.049101118,0.1611738,-0.00654902,0.056822374,0.06325117,0.2079953,-0.11484671,0.2354936,-0.09605202,0.022060376,-0.041279398,0.23484312,0.021023504,0.06586919,0.11005714,-0.1359883,0.113078676,0.12169834,0.051708814,0.08147492,0.13351464,-3.3268423,-0.40531865,0.113179035,-0.022732303,0.007538042,0.49243975,0.16309056,0.025208803,-0.07251043,0.03292766,0.15802807,-0.038955905,0.0073712897,0.009857086,0.009075154,-0.111116685,0.3471695,-0.09597732,-0.07443518,0.11283244,0.06863162,0.051712617,-0.28104824,0.13516487,0.0571
3463314,0.013840088,-0.07249861,-0.036360767,-0.06841611,-0.07855933,-0.11973029,0.15718174,0.1972061,-0.051019665,0.03799167,0.11934465,0.1471539,-0.13701747,0.08351732,0.078757904,0.121916465,0.02557126,0.1017319,-0.045709323,0.124265544,0.10805651,0.011566373,-0.194939,0.4024029,0.17047836,0.117104046,0.0325326,0.032192253,-0.0749799,-0.031197554,-0.14500812,0.121455066,-0.0010478667,-0.107763745,0.035734475,0.04229214,-0.028724272,-0.05874524,0.07278925,0.3001442,0.07316322,0.051569495,0.090849094,0.04404252,-0.08052641,-0.075251885,-0.27452326,0.29628763,-0.02517449,0.061599523,-0.17103066,-0.062955804,0.054130655,0.15362921,0.13416855,0.06825365,0.0980556,-0.15297882,-0.17751779,0.10530233,0.07658313,-0.16049337,0.2222187,0.17199194,0.13096656,-0.09337516,0.0058054603,-0.22425093,0.023643766,-0.10521237,-0.0783753,-0.006024595,-0.02074643,0.19049338,-0.1657424,-0.09951008,0.12803397,-0.023922494,0.1395149,0.1732631,-0.15366101,-0.2582775,-0.039837014,-0.103904665,0.110174105,0.09623427,-0.13604303,-0.031677507,0.036822114,0.04554304,0.00011983088,-0.19057263,0.04112232,0.3739904,0.11611033,-0.12969264,-0.054372616,-0.37260976,0.050524354,0.15510781,0.009165178,-0.08651273,-0.040922064,-0.08496964,0.05602129 ...

# %% [markdown]
# Running Similarity Search for each of these queries for every country

# %%
all_results = []
for country in country_list:
    for sim_query, embedding_str in similar_queries_embeddings.items():
        query = text("""
        SELECT 
            doc_chunks.doc_id,
            doc_chunks.chunk_index,
            doc_chunks.content,
            documents.country,
            doc_chunks.climate_bert_cluster_labels,
            doc_chunks.w2v_cluster_labels,
            (doc_chunks.embedding <=> :embedding) AS cosine_distance
        FROM doc_chunks
        LEFT JOIN documents ON doc_chunks.doc_id = documents.doc_id
        WHERE 
            documents.country = :country
        ORDER BY cosine_distance ASC
        LIMIT 5
        """)
        params = {
        "embedding": embedding_str,
        }   

        with engine.connect() as conn:
            results = conn.execute(query, {
                "embedding": embedding_str,
                "country": country
            }).fetchall()

            # View results
            df_results = pd.DataFrame(results, columns=[
            "doc_id", "chunk_index", "content", "country", 
            "climate_bert_cluster", "w2v_cluster", "cosine_distance"
            ])
            df_results["sim_query"] = sim_query
            all_results.append(df_results)

similar_queries_df = pd.concat(all_results, ignore_index=True)
# Out:
# /var/folders/v6/xrbmfj054b7cb1_bvtvf02nc0000gn/T/ipykernel_65382/890052353.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   similar_queries_df = pd.concat(all_results, ignore_index=True)

# %%
similar_queries_df
# Out:
#                            doc_id chunk_index  \
# 0     bangladesh_english_20220601         541
# 1     bangladesh_english_20220601         421
# 2     bangladesh_english_20220601         512
# 3     bangladesh_english_20220601         473
# 4     bangladesh_english_20220601         341
# ...                           ...         ...
# 4837     andorra_spanish_20250201         888
# 4838     andorra_spanish_20250201          38
# 4839     andorra_spanish_20230101          50
# 4840     andorra_spanish_20250201          38
# 4841     andorra_spanish_20230101          50
#
#                                        content     country  \
# 0                Ensure 3R principle for waste  Bangladesh
# 1                Ensure 3R principle for waste  Bangladesh
# 2          (generating 164 MW) for agriculture  Bangladesh
# 3                          (ERP) or congestion  Bangladesh
# 4                          (ERP) or congestion  Bangladesh
# ...                                        ...         ...
# 4837                                   Impacto     Andorra
# 4838  Business as usual, escenario inmovilista     Andorra
# 4839                         Business as usual     Andorra
# 4840  Business as usual, escenario inmovilista     Andorra
# 4841                         Business as usual     Andorra
#
#                  climate_bert_cluster  \
# 0     Headers, Keywords, Multilingual
# 1     Headers, Keywords, Multilingual
# 2     Headers, Keywords, Multilingual
# 3     Headers, Keywords, Multilingual
# 4     Headers, Keywords, Multilingual
# ...                               ...
# 4837  Headers, Keywords, Multilingual
# 4838  Headers, Keywords, Multilingual
# 4839  Headers, Keywords, Multilingual
# 4840  Headers, Keywords, Multilingual
# 4841  Headers, Keywords, Multilingual
#
#                                        w2v_cluster  cosine_distance  \
# 0     Mitigation & Adaptation Strategies – English         0.031867
# 1     Mitigation & Adaptation Strategies – English         0.031867
# 2                   Project Sectors & Technologies         0.039676
# 3               Fragmented Phrases & Minor Details         0.041617
# 4               Fragmented Phrases & Minor Details         0.041617
# ...                                            ...              ...
# 4837              Formal Climate Pledges – Spanish         0.046013
# 4838            Fragmented Phrases & Minor Details         0.048813
# 4839      Emission Reduction Targets & Commitments         0.076005
# 4840            Fragmented Phrases & Minor Details         0.063279
# 4841      Emission Reduction Targets & Commitments         0.088322
#
#                              sim_query
# 0       ghgs commitment seeking 2030 %
# 1       ghgs commitment seeking 2030 %
# 2       ghgs commitment seeking 2030 %
# 3       ghgs commitment seeking 2030 %
# 4       ghgs commitment seeking 2030 %
# ...                                ...
# 4837                   net goal aiming
# 4838  net revised seeking 2030 percent
# 4839  net revised seeking 2030 percent
# 4840       greenhouse scope looking  %
# 4841       greenhouse scope looking  %
#
# [4842 rows x 8 columns]

# %%
similar_queries_embeddings
# Out:
# {'ghgs commitment seeking 2030 %': '[-0.034325443,-0.08202738,-0.07436905,-0.0047721183,0.31819838,0.056827612,-0.04221918,0.08525371,0.034144875,-0.13183677,0.13390619,0.18829918,-0.028370287,-0.15103234,0.09272954,-0.018728342,-0.062804274,0.010321592,0.17176038,0.0138945775,-0.06454671,0.16930975,0.109424055,0.13421376,0.21931915,0.19386443,-0.08955947,-0.06738116,0.087019615,-0.25876868,0.05959017,-0.18063557,0.018344052,0.14599195,0.1666557,0.015410055,0.013845953,0.05855412,-0.14936659,0.11223957,0.112508446,-0.1328705,0.1245174,0.037790876,-0.08439667,0.123526305,0.17833059,0.19197145,0.048318014,-0.00763916,0.06860012,0.026593419,-0.054894883,0.043501243,0.023810243,-0.06658885,-0.049101118,0.1611738,-0.00654902,0.056822374,0.06325117,0.2079953,-0.11484671,0.2354936,-0.09605202,0.022060376,-0.041279398,0.23484312,0.021023504,0.06586919,0.11005714,-0.1359883,0.113078676,0.12169834,0.051708814,0.08147492,0.13351464,-3.3268423,-0.40531865,0.113179035,-0.022732303,0.007538042,0.49243975,0.16309056,0.025208803,-0.07251043
-0.046728782,0.046009917,-0.0412363,-0.05709488,0.23070893,0.023167288,0.19737478,0.031259622,-0.1364029,0.2599787,-0.0019187108,0.092323385,-0.19098483,0.1394958,0.20216559,-0.3463314,0.013840088,-0.07249861,-0.036360767,-0.06841611,-0.07855933,-0.11973029,0.15718174,0.1972061,-0.051019665,0.03799167,0.11934465,0.1471539,-0.13701747,0.08351732,0.078757904,0.121916465,0.02557126,0.1017319,-0.045709323,0.124265544,0.10805651,0.011566373,-0.194939,0.4024029,0.17047836,0.117104046,0.0325326,0.032192253,-0.0749799,-0.031197554,-0.14500812,0.121455066,-0.0010478667,-0.107763745,0.035734475,0.04229214,-0.028724272,-0.05874524,0.07278925,0.3001442,0.07316322,0.051569495,0.090849094,0.04404252,-0.08052641,-0.075251885,-0.27452326,0.29628763,-0.02517449,0.061599523,-0.17103066,-0.062955804,0.054130655,0.15362921,0.13416855,0.06825365,0.0980556,-0.15297882,-0.17751779,0.10530233,0.07658313,-0.16049337,0.2222187,0.17199194,0.13096656,-0.09337516,0.0058054603,-0.22425093,0.023643766,-0.10521237,-0.0783753,-0.006024595,-0.02074643,0.19049338,-0.1657424,-0.09951008,0.12803397,-0.023922494,0.1395149,0.1732631,-0.15366101,-0.2582775,-0.039837014,-0.103904665,0.110174105,0.09623427,-0.13604303,-0.031677507,0.036822114,0.04554304,0.00011983088,-0.19057263,0.04112232,0.3739904,0.11611033,-0.12969264,-0.054372616,-0.37260976,0.050524354,0.15510781,0.009165178,-0.08651273,-0.040922064,-0.08496964,0.05602129 ...

# %%
bool_mask = similar_queries_df['sim_query'] == "ghgs commitment seeking 2030 %"
for row in similar_queries_df[bool_mask]['content']:
    print(row)
# Out:
# Ensure 3R principle for waste
# Ensure 3R principle for waste
# (generating 164 MW) for agriculture
# (ERP) or congestion
# (ERP) or congestion
# iii) For climate forcers
# ii) Specific projects, measures
# ii) Contextual matters,
# c) Other contextual
# Tools used:
#  12% inconditionnel
# a) Mesures inconditionnelles ................................................................... 19
# Type de contribution
# (23%) à
# CDN CH4 CMA
# Note (*): increasing GHG removal
# 43.5 Note (*): increasing GHG removal
# to reducing
# but without many specific results.
# Metric applied
# Outcome: Increased- resilient Fisheries sector
# Area under agroforestr y landscape (ha)
# Forest landscape restored (ha)
# change in Uganda. Final Report.
# this waste needs
# GDP growth in %
# E. Prescribed burning of savannahs
# E. Prescribed burning of savannahs
# E. Prescribed burning of savannahs
# E. Prescribed burning of savannahs
# o Energy Efficiency Projects in industry:
# Measures in Residential sector:
# o o o Energy measures in Residential sector
# augmentation tool to save freshwater
#  Jordan’s GHG Inventory was
# land degradation neutrality and
# less GHG production
# Concept note aprobada/ PD
# Fase Inicial*
# Balance Nacional
# co-beneficios
# CO2 y Gases Fluorados
# No FOLU sector targets
# Table 23 FOLU targets
# Components of MRV for NDC tracking
# 1= target is difficult to reach
# NFPs_(F.3)strategic indicators, JMI (2020), National arbor day
# determined contribution;
# Fairness and ambitions of the INDC:
# Scope and coverage:
# NDC # NDC 1
# Large number of Interlinks :10
# synergies and active
# Small number of Interlinks: 1
# improving genetic, feed
# indicator versus benchmark indicator
# Total for sector
# Total for sector
# Total for sector
# Total for sector
# Understanding (ICTU) of the NDC.
# document (ICTU).
# Alcance nacional
# Alcance nacional
# Alcance nacional
# Alcance nacional
# local net zero; and
# 79 Universal Youth Clause in NDCs 28
# attract commercial investment;
# Gases covered
# a. Reference year(s), base
# IPPU NDC scenario
# Figure 54. projected data for crop areas
# FOLU NDC scenario
# Figure 16. Projections for IPPU sector
# Extent (by 2100)
# inventory estimates
# Agreement to submit information on:
# coupled with
# (tourism,
# considerations, on reflecting
# the EU markets within
# in the areas
# Parties with that contain
# Fairness including equity
# GDP in 2012
# paragraph 144, of appropriate;
# With additional measures,% of BAU
# With measures,% of BAU
# WM scenario, % of BAU
# WM scenario,% of BAU
# WAM scenario,% of BAU
# nomic Update June 2024 is used.
# (b) How the nationally determined
# (a) How the nationally determined
# to GDP dollar
# applicable, in the target year
# Funding: GCCA donors.
# for State services and
# 1st electrical tie line with Ethiopia
# 2nd and 3rd electrical tie lines with Ethiopia
# Gases covered
# Conditional Contribution Addressing household cesspits
# Addressing household cesspits
# Introduction / Structure
# Loss & Damage
# % réduction CDN
# % réduction CDN
# % réduction CDN
# % réduction CDN
# % réduction CDN
# reflecting on equity;
# to account removals
# frame and/or period
# b. Fairness considerations,
# consideration
# SLCP** mitigation Relevance
# SLCP** mitigation Relevance
# Emission Reduction (kt)
# Emission Reduction (kt)
# other starting point(s)
# ICTU applicable to Iceland´s NDC
# 1.1 (ICTU) of Zambia's NDC.
# (ii) For Parties with nationally
# guidance adopted by the CMA
# Guidance in decision 4/CMA.1
# removals disturbances
# the NDC contributes
# Amount of reduction- ton
# reflecting on equity;
# The document index:
# Sixth: General observations and assumptions:
# MRV	 «	Measuring,	reporting,	verifying	»
# CBIT	 «	Capacity	Building	Initiative	for	the
# Transparency	of	the	Paris	Agreement	»
# Dioxyde de carbone (CO2)
# LEG	 «	Least	developed	countries’	Expert	Group
# Goal: warning systems
# Objective 1: To degraded forest lands
# plan developed in 2020
# enhance of to
# local Develop institutional capacity
# unconditional target
# (Linked to Mitigation target)
# Para Guidance in decision
# Financial measures through:
# to Agriculture sector)
# (Link to Health sector).
# Contribution conditionnelle 40%
# Contribution inconditionnelle 60%
# 37.221 lampes (Soit 100%)
# Consultant volet adaptation
# gestion rationnelle ressources naturelles.
# ii) Contextual matters, appropriate:
# introduction of a salt tolerant pulaka species.
# iv) Treatment of land sector
# ▪ E-bike initiative
# inter alia, as
# Historical emissions data from Palestine’s INCR.
# 7 MCM of rainwater in the West Bank is harvested by
# a) Relevance to the Palestinian context
# Health: Increasing awareness and
# Status-quo and Independence Scenarios
# ➔ 2025 submit updated NDC
# ➔ 2022: implement national Climate
# ➔ 2021: adopt NAP and NAP
#  NDC 2020 done
# ➔ 2023: undertake a Technology Needs
# Objectifs sectoriels
# Déforestation :
# Objectif inconditionnel
# Objectif inconditionnel
# Objectif inconditionnel
# NDC progress indicators: Waste
# NDC progress indicators: IPPU
# NDC progress indicators: Energy (other)
# NDC progress indicators: AFOLU (agriculture)
# Compost application (ha)
# industrial ones, where the basis
# technologies involvement of waste
# reports will, according
# IPCC Sectors covered:
# regeneration
# INDC emission
# Included, with different target
# Included, with different target
# GHG profile covered
# Increased clinker substitution with BFS (up
# BIOMASS: 300MW installed capacity
# SOLAR and WIND: 1GW installed capacity
# Lao-China railway
# (Million USD)
# Certified emission
# pure electrification of buses, Shenzhen is among
# captured per year
# supervision has been
# of CO2 -EOR in
# h. The intention to engage in REDD+
# g. The intention to use voluntary
# reflecting on equity;
# b. Quantifiable information on the
# Developing Sustainable seamoss farming
# 6. Number of targets
# quality source-specific
# information on each category
# Industry and F-gases)
# Sectors covered
# . с ы т
# Financement climat
# Financement carbone
# Processus planification
# Atténuation - agriculture
# Absorptions nettes
# I. Australia’s strengthened climate ambition
# Climate forcers, as applicable
# Climate forcers, as applicable
# Scope and coverage
# Scope and coverage
# awareness plan on resilience complete
#  Farmers certified DOMGAP (Number, Percentage)
# spending on agriculture (Percentage)
# < 10% of schools used as LT
# < 5% of schools used as LT
# GDP decrease (billion USD and%)
# Liming activities; • Open burning.
# Carbon pools: not applicable
# (ii) For Parties with nationally
# 2 plan.html
# % contribution for target
# % contribution for target
# % contribution for target
# % contribution for target
# % contribution for target
# identify relevant options of how
# M15 By 2030, Implement Waste
# M18 By 2030, Develop and
# A20 Vanuatu commits to strengthen community-
# A19 Vanuatu commits to a collaborative
# Relatable NSDP Indicator
# Figure n°8 : Arrangements institutionnels
# Forêt (FAT)
# 100 kt canne à sucre/an
# Absorption (GgCO2)
# 1 MW cogénération
# share of GDP has
# The 6 solutions”
# The 5 resilience management”
# LEED Certifications
# x0 – the statistical data;
# except the firewood consumption
# NDC 2 deg. Scenario
# GDP real growth, %
# the NDC document;
# See mitigation table
# Total emissions: IPPU
# Vulnerability and resilience ................................................................................ 47
# Modal shift: passenger
# 4 NDC revision process
# Objectif conditionnel (2030) %
# Objectif inconditionnel (2030) %
# 1503142 en 2030)
# Objectif inconditionnel (2025) %
# Projections population rural (12230685 en 2025 et
# RBA RDC REBAC REDD+
# en Carbone/Low Emissions
# Promotion transport masse
# REDD+ REFADD REPALEF-RDC
# Tableaux et figures
# g The intention to use voluntary
# a How the nationally determined
# b How the nationally determined
# b Quantifiable information on the
# d Each Party with a nationally
# the Narrative assessment of the contribution.
# Period of defining actions
# Capacity kW
# Charging carbon levies,
# Capacity (kW)
# sustainable development,
# Time frame Scope and coverage
# ❖ Objectif global
# Actions CDN Agriculture atténuation
# Terres (AFAT) : 28,40 %.
# tonnes) par compostage dans
# Adaptation (milliards USD
# Funding secured. Requires investment.
# identification for project
# Funding secured. Requires implementation.
# Support partner(s) identified?
# Support partner(s) identified?
# scenario inconditionnel
# (PIUP) 1%.
# Scenario inconditionnel
# scenario conditionnel
# Progression (%)
# GCF recursos, a
# (GEI) del sector
# De alcance regional y local:
# ca (EE) por parte
# + (EC+) – Agen-
# Literal c) no aplica.
# Literal b) no aplica.
# Literal b) no aplica.
# Responsables Inumet; SNRCC
# Responsables Inumet; SNRCC
# Oman responsibility encouraging product design.
# is actively planning
# Public MEM AR | Natural gas consumption
# MEM reported production levels
# thorough evaluation of
# Transporte 61
# Alcance y
# Humedales).
# sustentable
# 35 km asphalt
# 40 km asphalt
# Unsealed 0 km
# 10 km double seal
# Conditional Undertake a national methane opportunities.
# d) Target relative
#  ₋argets:
#  commitment
#  Implementation
#  INDCu’s	ion	ng
#  disaggregated)
# Sectors 1. Energy
#  Base year
#  Time frames
#  Scope and coverage
# Investment required MUSD
# Funding needs (000)
# Options excluded in MAR Curve
# villages and 7 islands;
# Options included in MAR Curve
# o Renewed focus on targeting commercial sector.
# o What We Heard document (2022), which summarizes our
# IntroductionConsiderationsonsettinga2035targetforCanada
# IntroductionConsiderationsonsettinga2035targetforCanada
# IntroductionConsiderationsonsettinga2035targetforCanada
# on the GDP forecast (industrial wastewaters).
# Coastal zone:
# IPCC Sectors included:
# the economic and
# account removals,
# Type of contribution
# emissions reduction is subject
# the NDC and providing
# Report (BUR) and Updated GHG inventory in the country.
# in implementation of NDC,
# the process. Their proactive commitment
# Measure 4. Land planning
# % Contribution by sector
# Measure 3. Improve disease management
# Measure 5. Gender mainstreaming
# No. of fishing vessels running on Green H2
# (a) How the Party considers that its nationally
# Scope and coverage
# areas Liechtenstein(cid:146)s influence is very limited.
# Fairness and ambition
# Liechtenstein understands fairness of
# its NDC document, primarily
# financial assistance and
# regarding numerical
# taken a number of
# there are planned expanding
# Approach used emissions and harvested wood
# GDP per capita ($)
# to reach approximately 14 MCM daily.
# food insecure state of the region.
# tons bioethanol annually.
# Finance Needs (USD)
# Finance Needs (USD)
# Own contribution
# Gases Covered:
# Contribution Type: Conditional
# Coverage and addressed NDC commitment
# Coverage and addressed NDC commitment
# Coverage and addressed NDC commitment
# Coverage and addressed NDC commitment
# Coverage and addressed NDC commitment
# Non planification territoriale
# Non planification territoriale
# Estimation FMI
# Estimation FMI
# Estimation FMI
# a) Updated activity data
# Carbon sink and Reservoir
# operations/projects/10181.
# Precautionary principle:
# Commitment type Unconditional
# 21% taxis colectivos a 2050
# Cambio modal transporte
# Estimated Budget (USD)
# Estimated Budget (USD)
# indicator, in
# MA8 – Reducing food losses
# Estimate of costs (aggregate) ($)
# Programme components/SPCR pillars
# (covered under MA10 – Substituting HFC)
# Annex 1: Project portfolio
# Finance (million USD)
# Increase public green
# Scope and coverage
# Area (ha)
# Low Mitigation.” Environmental Research
# long-term perspective contained
# 3. South	Africa’s	first	Adaptation	Communication,	serving	as	the Adaptation	component	of	the	NDC
# ° C ”
# 1	(c)		 Progression	and	highest	possible	ambition,	in	the	light	of	equity	and	national
# (CO2), methane
# % hausse CDN conditionnel
# Emissions CDN inconditionnel (GgeCO2)
# Emissions CDN inconditionnel (GgeCO2)
# Emissions CDN inconditionnel (GgeCO2)
# Emissions CDN inconditionnel (GgeCO2)
# Four gases incl. alternative CFC*3
# Energy conversion*2
# products (HWP))
# products (HWP))
# problems in the country.
# iii. For climate forcers
# to the forecasts of the economic module.
# Depending on its strengths
# Ad-hoc model
# Conditional:
# Prefabricated model Black box
# irrigation by using plastic-
# LEAP (energy sector)
# Metric applied
# Gases covered
# E. Needs for Support
# to power G5 sahel
# transparency (Initiative pour
# institutionnels participation
# inconditionnel 19,68%
# 100.000 naissances)
# aptation commitments, comprising that dozens of actions
# of updating NDC 1 took place
# of mitigation transparency is evident by contemplating the
# and measures incorporating nationally
# European bee honey conversion, 2021.
# Actions in RAC sector
# EE/RE - Baseline
# Baseline KtCo2e
# Policy and financing
# EE + RE
# GDP (real, reference 2010)
# starting point(s);
# reference point(s);
# appropriate, removals
# applicable:
# ambition in market mechanisms.
# (ii) For Parties with nationally
# the avoidance of double counting
# including reflecting on equity
# transparency, and
# 3.	Principales	variables	 macro consideradas
# Environmental	Policy	Integrated	Climate
# Escenarios	Condicional	e
# Variables consideradas
# Soil	&	Water	Assessment	Tool
# 12 Milliards en US$ Budget adaptation
# considérablement
# 1% sector IPPU; y
# 9% sector Energía;
# 5% sector Agricultura;
# 3B3 – Pastizales;
# 3B4 – Humedales; y
# 4 NDC development process
# Deployment 0%
# FOLU sub-sector total
# including bagasse, for electricity
# REDD-plus
# target, as applicable.
# Response Policy of 2021. Furtherm ore, Botswa na has also develo ped t he National Ada ptation
# % water loss by settlement
# % of budget 7%
# the development around
# Climate services 9%
# adequate scientific and
# independent report on implementation by youth.
# GHG inventory of 2015.
# ambition in their actions”.
# cumulative capacity exceeding 75 MW were approved9.
# Pakistan WB commitments and Climate co-Beneﬁts
# determined contribution;
# Axis II - Energy transition
# 1. the climate emergency;
# emissions and removals;
# Eradicating poverty
# Notas: NA = No aplica.
# The updated NDC covers:
# Development (MADS):
# ii) Contextual matters:
# (USD M)
# Acknowledgements •
# 14% below BAU, unconditional pathway
# On mitigation they cover:
# Clinker substitution
# indicator (unit)
# indicator (unit)
# 6. Equité et ambition
# Total financement
# Total financement
# Financement conditionnel
# Gg éqCO2
# Gases incluidos: CO2
# Compromiso CDN1:
# Compromiso CDN1:
# Compromiso CDN1:
# Compromiso CDN1:
# Table 8: Scores for sector prioritization
# A plan included in the NDS.
# Table 37: NDC implementing entities
# Table 37: NDC implementing entities
# Figure 18: The DISRUPT framework
# reforestation measures. As a
# Implementat ion timeline and progress status
# Figure 5. The cost of agricultural products (mln. Manats)
# Means of the population
# financing in 2018
# Conditionnelles Total
# determined contribution;
# monitoring on key stations;
# Relevance to national context
# Relevance to national context
# Relevance to national context
# General description of the target:
# the topic of individual impact.
# LULUCF: 95% removals increase
# Initial NDC (2015)
# High focus on RES
# This conditional target assumes:
# Acc ER in % of FRL baseline unconditional
# Acc ER in % of FRL baseline conditional
# Table 21. Removal Factor of agroforestry88
# To DoA/ DZGD (tCO2e)
# preparation of contribution;
# optimum level, and
# cooling gases (being drafted).
# roadmap is being prepared.
# for international and intercity.
# z Sector	Meta	Sector	Meta
# USCUSS (absorciones) No aplica
# USCUSS (emisiones)
# (IPCC), es
# Implementation of the CRSAP.
# o Drought tolerant,
# Sectors covered
# b. Quantifiable information reference on
# framework/roadmap/plan include:
# the number of organic
# three combined
# The current rail network –a available
# Non-emission targets: (cid:120)
# Understand the NDC
# been amended by a target year.
# Confiden ce (direction of change)
# Increase in ocean acidificatio n
# b) Overall goal
# Baseline 2020: 3.254.200 ha with MIC
# IVSB_1xNorm: Area of forest cover loss
# Conditionality: Goal conditioned at 100%.
# Conditionality: Goal conditioned at 100%.
# Numbers reflect rounding
# integration
# Scope and coverage:
# consideration
# Al 2030, se ha
# Al 2030, se ha
# Al 2030, se ha
# Al 2030, se ha
# Al 2030, se ha
# MARDE in conjunction of MECR
# Policy reviewed; vulnerable assets identified.
# Process and mandate developed.
# Uncertainty of C&B44
# Gender- responsive CCA M&E
# Production de charbon 2%
# Cultivation du riz 9%
# Production efficace de charbon 12%
# Production efficace de charbon 12%
# Production efficace de charbon 12%
# ▪	 AFOLU—manage	 forests	 sustainably	 and	 increase	 total
# ▪	 AFOLU—manage	 forests	 sustainably	 and	 increase	 total
# efficiency	programs
# Requirements ▪	 Samoa requires external
# ▪	 Awareness raising
# Aplicabl e. REDD+ elaborad
# CO2eq al año.
# carbono (REDD+).
# Aplicabl e.
# CO2 Absorciones
# 19 Capacity Building for and on Actions an
# projected climate extremes Barbuda
# accounting gas
# the established enabling
# anthropogenic as and,
# Costs/investment (USD million) for NDC period
# Scope included contribution
# footprint, historical
# responsibility, development
# Least developed Country
# Business as usual, escenario inmovilista
# Business as usual

# %% [markdown]
# The above shows that when we omit semantic sentence structuring we get poorly returned content chunks. Likely because the embeddings match those headings or table entries which have a somewhat unnatural phrasing structure. <BR>
#
# Whilst interesting as an academic excercise, constructing queries based PURELY on Word2Vec word similarity does not seem to be, because it ignores transformer models ability to pick up on semantic context <BR>
#
# __NOTE:__ I manually looked through the rest of the retrieved content blocks from the other 'W2V randomly constructed' queries -> They yielded similar poor results
#
# After exploration below, I build upon this approach by using my retrieved 'gold-standard' ground truth retrieved content blocks to generate a vector of queries which: (A) Allign with the W2V Keywords, (B) Follow natural sentence structure, and (B) Stick closely to those ground truth returned answers

# %% [markdown]
# ### Search Metric Comparison
#
# Here I decide to compare search metrics, using the same procedure to qualitatively analyse chunks returned by top-K approach for: cosine similarity, l2 distance and inner product <BR> <BR>

# %% [markdown]
# __cosine similarity__

# %%
all_results = []
for country in country_list:
    query = text("""
    SELECT 
        doc_chunks.doc_id,
        doc_chunks.chunk_index,
        doc_chunks.content,
        documents.country,
        doc_chunks.climate_bert_cluster_labels,
        doc_chunks.w2v_cluster_labels,
        (doc_chunks.embedding <-> :embedding) AS cosine_distance
    FROM doc_chunks
    LEFT JOIN documents ON doc_chunks.doc_id = documents.doc_id
    WHERE 
        documents.country = :country
    ORDER BY cosine_distance ASC
    LIMIT 5
    """)
    params = {
    "embedding": embedding_str
    }   

    with engine.connect() as conn:
        results = conn.execute(query, {
            "embedding": embedding_str,
            "country": country
        }).fetchall()

        # View results
        df_results = pd.DataFrame(results, columns=[
        "doc_id", "chunk_index", "content", "country", 
        "climate_bert_cluster", "w2v_cluster", "cosine_distance"
        ])
        all_results.append(df_results)

cosine_comparative_df = pd.concat(all_results, ignore_index=True)
# Out:
# /var/folders/v6/xrbmfj054b7cb1_bvtvf02nc0000gn/T/ipykernel_65382/2563596234.py:36: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   cosine_comparative_df = pd.concat(all_results, ignore_index=True)

# %% [markdown]
# __L2 Distance__

# %%
all_results = []
for country in country_list:
    query = text("""
    SELECT 
        doc_chunks.doc_id,
        doc_chunks.chunk_index,
        doc_chunks.content,
        documents.country,
        doc_chunks.climate_bert_cluster_labels,
        doc_chunks.w2v_cluster_labels,
        (doc_chunks.embedding <-> :embedding) AS l2_distance
    FROM doc_chunks
    LEFT JOIN documents ON doc_chunks.doc_id = documents.doc_id
    WHERE 
        documents.country = :country
    ORDER BY l2_distance ASC
    LIMIT 5
    """)
    params = {
    "embedding": embedding_str
    }   

    with engine.connect() as conn:
        results = conn.execute(query, {
            "embedding": embedding_str,
            "country": country
        }).fetchall()

        # View results
        df_results = pd.DataFrame(results, columns=[
        "doc_id", "chunk_index", "content", "country", 
        "climate_bert_cluster", "w2v_cluster", "l2_distance"
        ])
        all_results.append(df_results)

l2_comparative_df = pd.concat(all_results, ignore_index=True)
# Out:
# /var/folders/v6/xrbmfj054b7cb1_bvtvf02nc0000gn/T/ipykernel_65382/1327533772.py:36: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   l2_comparative_df = pd.concat(all_results, ignore_index=True)

# %% [markdown]
# __Inner Product__

# %%
all_results = []
for country in country_list:
    query = text("""
    SELECT 
        doc_chunks.doc_id,
        doc_chunks.chunk_index,
        doc_chunks.content,
        documents.country,
        doc_chunks.climate_bert_cluster_labels,
        doc_chunks.w2v_cluster_labels,
        (doc_chunks.embedding <#> :embedding) AS inner_product
    FROM doc_chunks
    LEFT JOIN documents ON doc_chunks.doc_id = documents.doc_id
    WHERE 
        documents.country = :country
    ORDER BY inner_Product ASC
    LIMIT 5
    """)
    params = {
    "embedding": embedding_str,
    }   

    with engine.connect() as conn:
        results = conn.execute(query, {
            "embedding": embedding_str,
            "country": country
        }).fetchall()

        # View results
        df_results = pd.DataFrame(results, columns=[
        "doc_id", "chunk_index", "content", "country", 
        "climate_bert_cluster", "w2v_cluster", "inner_product"
        ])
        all_results.append(df_results)

inner_product_comparative_df = pd.concat(all_results, ignore_index=True)
# Out:
# /var/folders/v6/xrbmfj054b7cb1_bvtvf02nc0000gn/T/ipykernel_65382/3336980235.py:36: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   inner_product_comparative_df = pd.concat(all_results, ignore_index=True)

# %%
def prepare_distance_df(df, distance_column, method_name):
    df = df.copy()
    df["distance_metric"] = method_name
    df = df.rename(columns={distance_column: "distance_value"})
    df["rank"] = df.groupby("country")["distance_value"].rank(method="first")
    return df[[
        "country", "rank", "distance_metric", "doc_id", "chunk_index", "content",
        "climate_bert_cluster", "w2v_cluster", "distance_value"
    ]]

# %%
df_cosine_prepped = prepare_distance_df(cosine_comparative_df, "cosine_distance", "cosine")
df_l2_prepped = prepare_distance_df(l2_comparative_df, "l2_distance", "l2")
df_inner_prepped = prepare_distance_df(inner_product_comparative_df, "inner_product", "inner_product")

# %%
final_comparison_df = pd.concat(
    [df_cosine_prepped, df_l2_prepped, df_inner_prepped],
    ignore_index=True
)

# %% [markdown]
# ##### Now we can make comaprisons for different countries to see which returns the most intuitively correct response for our query

# %%
boolean_mask = final_comparison_df['country'] == 'Bangladesh'
bangladesh_comparative_df = final_comparison_df[boolean_mask]

bangladesh_comparative_df
# Out:
#          country  rank distance_metric                       doc_id  \
# 0     Bangladesh   1.0          cosine  bangladesh_english_20220601
# 1     Bangladesh   2.0          cosine  bangladesh_english_20220601
# 2     Bangladesh   3.0          cosine  bangladesh_english_20220601
# 3     Bangladesh   4.0          cosine  bangladesh_english_20220601
# 4     Bangladesh   5.0          cosine  bangladesh_english_20220601
# 785   Bangladesh   1.0              l2  bangladesh_english_20220601
# 786   Bangladesh   2.0              l2  bangladesh_english_20220601
# 787   Bangladesh   3.0              l2  bangladesh_english_20220601
# 788   Bangladesh   4.0              l2  bangladesh_english_20220601
# 789   Bangladesh   5.0              l2  bangladesh_english_20220601
# 1570  Bangladesh   1.0   inner_product  bangladesh_english_20220601
# 1571  Bangladesh   2.0   inner_product  bangladesh_english_20220601
# 1572  Bangladesh   3.0   inner_product  bangladesh_english_20220601
# 1573  Bangladesh   4.0   inner_product  bangladesh_english_20220601
# 1574  Bangladesh   5.0   inner_product  bangladesh_english_20220601
#
#      chunk_index                                            content  \
# 0            770  Single-year targets for 2030. The target might...
# 1            745  Total GHG emission will be 409.4 MtCO2e in 203...
# 2             87  Critical assumptions for modelling GHG emissio...
# 3            300  The targeted GHG emission reduction for uncond...
# 4             26  The following table 1 presents the sector-wise...
# 785          770  Single-year targets for 2030. The target might...
# 786          745  Total GHG emission will be 409.4 MtCO2e in 203...
# 787           87  Critical assumptions for modelling GHG emissio...
# 788          300  The targeted GHG emission reduction for uncond...
# 789           26  The following table 1 presents the sector-wise...
# 1570         167           Table 3: GHG emission reduction scenario
# 1571         843  (f) Other assumptions and methodological appro...
# 1572         745  Total GHG emission will be 409.4 MtCO2e in 203...
# 1573         833  (b) Assumptions and methodological approaches ...
# 1574         825  5. Assumptions and methodological approaches, ...
#
#      climate_bert_cluster                               w2v_cluster  \
# 0     Narrative - English  Emission Reduction Targets & Commitments
# 1     Narrative - English  Emission Reduction Targets & Commitments
# 2     Narrative - English  Emission Reduction Targets & Commitments
# 3     Narrative - English  Emission Reduction Targets & Commitments
# 4     Narrative - English  Emission Reduction Targets & Commitments
# 785   Narrative - English  Emission Reduction Targets & Commitments
# 786   Narrative - English  Emission Reduction Targets & Commitments
# 787   Narrative - English  Emission Reduction Targets & Commitments
# 788   Narrative - English  Emission Reduction Targets & Commitments
# 789   Narrative - English  Emission Reduction Targets & Commitments
# 1570  Narrative - English  Emission Reduction Targets & Commitments
# 1571  Narrative - English          Formal Climate Pledges – English
# 1572  Narrative - English  Emission Reduction Targets & Commitments
# 1573  Narrative - English          Formal Climate Pledges – English
# 1574  Narrative - English  Emission Reduction Targets & Commitments
#
#       distance_value
# 0           3.101959
# 1           3.205943
# 2           3.355135
# 3           3.409312
# 4           3.540240
# 785         3.101959
# 786         3.205943
# 787         3.355135
# 788         3.409312
# 789         3.540240
# 1570     -204.979248
# 1571     -204.742844
# 1572     -203.710480
# 1573     -203.554306
# 1574     -203.180786

# %% [markdown]
# At face value, referring to our clustering strategy all seme to be pulling from the most relevant clusters that we had identified. However, inner product seems to be pulling chunks from different clusters. Cosine similarity and l2 distance seem to reach consensus that the most relevant chunks were those previously clustered under 'Emission Reduction Targets & Commitments'. This also is the most likely relevant cluster which suggests positively in favour of these two distance measures

# %% [markdown]
# #### Multi-Country Analysis for each method

# %% [markdown]
# __Bangladesh__

# %%
bangladesh_comparative_df = bangladesh_comparative_df.reset_index(drop=True)

for i in range(len(bangladesh_comparative_df['content'])):
    if i == 0:
        print('=' * 50)
        print('COSINE SIMILARITY RESULTS')
        print('=' * 50)
    elif i == 5:
        print('=' * 50)
        print('L2 DISTANCE RESULTS')
        print('=' * 50)
    elif i == 10:
        print('=' * 50)
        print('INNER PRODUCT RESULTS')
        print('=' * 50)
    print(bangladesh_comparative_df['content'][i])
# Out:
# ==================================================
# COSINE SIMILARITY RESULTS
# ==================================================
# Single-year targets for 2030. The target might be updated in 2025.
# Total GHG emission will be 409.4 MtCO2e in 2030 under BAU scenario. The contributions of the sectors are;
# Critical assumptions for modelling GHG emission for BAU scenarios are:
# The targeted GHG emission reduction for unconditional contributions will be implemented through a set of mitigation actions. The potential mitigations actions are elaborated in Table 4.
# The following table 1 presents the sector-wise GHG emission for the Base year scenario.
# ==================================================
# L2 DISTANCE RESULTS
# ==================================================
# Single-year targets for 2030. The target might be updated in 2025.
# Total GHG emission will be 409.4 MtCO2e in 2030 under BAU scenario. The contributions of the sectors are;
# Critical assumptions for modelling GHG emission for BAU scenarios are:
# The targeted GHG emission reduction for unconditional contributions will be implemented through a set of mitigation actions. The potential mitigations actions are elaborated in Table 4.
# The following table 1 presents the sector-wise GHG emission for the Base year scenario.
# ==================================================
# INNER PRODUCT RESULTS
# ==================================================
# Table 3: GHG emission reduction scenario
# (f) Other assumptions and methodological approaches used for understanding the nationally determined contribution and, if applicable, corresponding emissions and removals, including:
# Total GHG emission will be 409.4 MtCO2e in 2030 under BAU scenario. The contributions of the sectors are;
# (b) Assumptions and methodological approaches used for accounting for the implementation of policies and measures or strategies in the nationally determined contribution:
# 5. Assumptions and methodological approaches, including those for estimating and accounting for anthropogenic greenhouse gas emissions and, as appropriate, removals:

# %% [markdown]
# __Angola__

# %%
boolean_mask = final_comparison_df['country'] == 'Angola'
angola_comparative_df = final_comparison_df[boolean_mask]

angola_comparative_df

angola_comparative_df = angola_comparative_df.reset_index(drop=True)

for i in range(len(angola_comparative_df['content'])):
    if i == 0:
        print('=' * 50)
        print('COSINE SIMILARITY RESULTS')
        print('=' * 50)
    elif i == 5:
        print('=' * 50)
        print('L2 DISTANCE RESULTS')
        print('=' * 50)
    elif i == 10:
        print('=' * 50)
        print('INNER PRODUCT RESULTS')
        print('=' * 50)
    print(angola_comparative_df['content'][i])
# Out:
# ==================================================
# COSINE SIMILARITY RESULTS
# ==================================================
# At least 14% domestic reduction in greenhouse gas emissions by 2025.
# Angola is setting the target to achieve a 14% reduction (unconditionally) by 2025.
# Additional 10% of GHG reduction by 2025
# In terms of flaring, we have increased the ambition to reduce flaring. Instead of 75% reduction, as planned and presented in the unconditional 2030 scenario, it is now considered a 91% emission reduction compared to 2015 emissions.
# implications for emissions in the transport sector, resulting in a rise in global temperature and climate change.
# ==================================================
# L2 DISTANCE RESULTS
# ==================================================
# At least 14% domestic reduction in greenhouse gas emissions by 2025.
# Angola is setting the target to achieve a 14% reduction (unconditionally) by 2025.
# Additional 10% of GHG reduction by 2025
# In terms of flaring, we have increased the ambition to reduce flaring. Instead of 75% reduction, as planned and presented in the unconditional 2030 scenario, it is now considered a 91% emission reduction compared to 2015 emissions.
# implications for emissions in the transport sector, resulting in a rise in global temperature and climate change.
# ==================================================
# INNER PRODUCT RESULTS
# ==================================================
# Facing climate change is the greatest global environmental challenge in the present. Developing countries are particularly vulnerable to the impacts of climate change because they are highly dependent on natural resources and have limited capacity to respond to these impacts.
# The Methodology and Base Data Plan will define the methodologies to be applied in the monitoring of GHG emissions, mitigation and adaptation measures and financial, technical and technological support.
# However, there are other sources of greenhouse gas emissions from the industrial sector. The table below shows which are the relevant subsectors considered for this sector.
# implications for emissions in the transport sector, resulting in a rise in global temperature and climate change.
# Specific national needs related to mitigation and adaptation to climate change include:

# %% [markdown]
# __Jordan__

# %%
boolean_mask = final_comparison_df['country'] == 'Jordan'
jordan_comparative_df = final_comparison_df[boolean_mask]

jordan_comparative_df

jordan_comparative_df = jordan_comparative_df.reset_index(drop=True)

for i in range(len(jordan_comparative_df['content'])):
    if i == 0:
        print('=' * 50)
        print('COSINE SIMILARITY RESULTS')
        print('=' * 50)
    elif i == 5:
        print('=' * 50)
        print('L2 DISTANCE RESULTS')
        print('=' * 50)
    elif i == 10:
        print('=' * 50)
        print('INNER PRODUCT RESULTS')
        print('=' * 50)
    print(jordan_comparative_df['content'][i])
# Out:
# ==================================================
# COSINE SIMILARITY RESULTS
# ==================================================
# The target is a single year for 2030
# 8. Reducing emissions that are under the direct control of the health sector to reach net zero health sector emissions by 2050.
# The energy measures that are considered to achieve the NDC target are;
# Jordan sets the target of achieving 31% reduction of emissions by 2030. Which is quantified to be 11269 Gg CO2 eq.
# Energy measures including renewable energy and energy efficiency targets up to 2030 were considered and estimated, namely;
# ==================================================
# L2 DISTANCE RESULTS
# ==================================================
# The target is a single year for 2030
# 8. Reducing emissions that are under the direct control of the health sector to reach net zero health sector emissions by 2050.
# The energy measures that are considered to achieve the NDC target are;
# Jordan sets the target of achieving 31% reduction of emissions by 2030. Which is quantified to be 11269 Gg CO2 eq.
# Energy measures including renewable energy and energy efficiency targets up to 2030 were considered and estimated, namely;
# ==================================================
# INNER PRODUCT RESULTS
# ==================================================
# Assumptions and methodological approaches used for accounting for the implementation of policies and measures or strategies in the nationally determined contribution
# Other assumptions and methodological approaches used for understanding the nationally determined contribution and, if applicable, estimating corresponding emissions and removals, including:
# IPCC methodologies and metrics used for estimating anthropogenic greenhouse gas emissions and removals
# How the economic and social consequences of response measures have been considered in developing the nationally determined contribution
# For climate forcers included in nationally determined contributions not covered by IPCC guidelines, information on how the climate forcers are estimated;

# %% [markdown]
# The above 3 country tests shows great similarity between the L2 Distance results and the cosine similarity results. This is to be expected given that the calculus for each is done in similar ways. For the Inner Product results, the calculation method here seems to favour more explantory context giving statements, which is very interesting. For the purpose of our task. <BR>
#
# __However__, I recognise if our task was to do something like: 'find the emissions target for xyz country and give context for why they have set thsis target and how they will achieve, their methodology etc.' then I would most probably construct my prompt to the LLM based on top k-results for BOTH Cosine similarity distances and INNER PRODUCT, as this would allow the LLM to generate a response both empirically accurate and qualitatively grounded
#
# As it stands though, cosine similarity fits the brief of this task the most accurately and so I use it going forward

# %%
del final_df

# %% [markdown]
# #### Re-running our query procedure to update the dataframe - this time Selecting cluster labels to add to our dataframe

# %%
query_text = "What are the emissions reduction targets for 2030?"
tokenised_query = tokenize_for_transformer_climate_roberta(query_text)
query_embedding = get_pooled_embeddings(tokenised_query, climate_roberta_model)

embedding_str = f"[{','.join(str(x) for x in query_embedding)}]"

# %%
all_results = []
for country in country_list:
    query = text("""
    SELECT 
        doc_chunks.doc_id,
        doc_chunks.chunk_index,
        doc_chunks.content,
        documents.country,
        doc_chunks.climate_bert_cluster_labels,
        doc_chunks.w2v_cluster_labels,
        doc_chunks.chunk_metadata,
        (doc_chunks.embedding <=> :embedding) AS cosine_distance
    FROM doc_chunks
    LEFT JOIN documents ON doc_chunks.doc_id = documents.doc_id
    WHERE 
        documents.country = :country
        AND doc_chunks.content ILIKE '%2030%'
        AND (doc_chunks.embedding <=> :embedding) <= :distance_threshold
    ORDER BY cosine_distance ASC
    LIMIT 10
    """)
    params = {
    "embedding": embedding_str,
    "distance_threshold": 0.05
    }   

    with engine.connect() as conn:
        results = conn.execute(query, {
            "embedding": embedding_str,
            "country": country,
            "distance_threshold": 0.05
        }).fetchall()

        # View results
        df_results = pd.DataFrame(results, columns=[
        "doc_id", "chunk_index", "content", "country", 
        "climate_bert_cluster", "w2v_cluster", "chunk_metadata", "cosine_distance"
        ])
        df_results["cosine_similarity"] = 1 - df_results["cosine_distance"]
        all_results.append(df_results)

final_df = pd.concat(all_results, ignore_index=True)
# Out:
# /var/folders/v6/xrbmfj054b7cb1_bvtvf02nc0000gn/T/ipykernel_65382/2563391061.py:42: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_df = pd.concat(all_results, ignore_index=True)

# %%
final_df[10:20]

for row in final_df[10:20]['content']:
    print(row)
# Out:
# sectoral development plans for the period 2021-2030 towards the goals of the National Climate Change Strategy to 2050. Specific measures to reduce GHG emissions include:
# Emission reduction targets in the energy, agriculture, LULUCF, waste and industrial processes by 2030 compared to BAU in NDC 2022 are higher than NDC 2020, Unconditional contribution increased from 9% to 15.8% and Conditional contribution increased from 27% to 43.5%.
# The updated NDC highlights a huge progression from 22% to 24.7% reduction in 2030.
# Full implementation of this measure will to emissions reduce potentially approximately 2.9 MtCO2e by 2030.
# The NAMA seeks to contribute to GHG mitigation of 0.5 MtCO2e by 2030.
# Economy wide emissions reduction of 24.7% in 2030 below the BAU conditions. Of which, Uganda’s unconditional efforts will result into reduction of 5.9% in 2030 below the BAU conditions.
# Full implementation of the measure will contribute to a GHG emission reduction of approximately 3.37 MtCO2e by 2030.
# The measure is expected to contribute to a reduction of GHG emissions of about 0.37 MtCO2e by 2030 through woodlots, and/or farm forestry practices.
# If, as a result of inadequate financial, capacity-building and technology transfer support, it is envisaged that Uganda’s unconditional efforts will result into net emissions reductions of 5.9% below the BAU trajectory in 2030.
# Uganda has committed to reduce her economy-wide Greenhouse gas emissions by 24.7% in 2030 below the BAU baseline. 82.7% of the mitigation action will come from the Agriculture, Forestry and Other Land Use AFOLU sector.

# %%
final_df
# Out:
#                                    doc_id chunk_index  \
# 0             bangladesh_english_20220601         745
# 1             bangladesh_english_20220601          10
# 2             bangladesh_english_20220601          92
# 3             bangladesh_english_20220601         588
# 4             bangladesh_english_20220601         886
# ..                                    ...         ...
# 559  antigua_and_barbuda_english_20220601         673
# 560  antigua_and_barbuda_english_20220601         293
# 561  antigua_and_barbuda_english_20220601         674
# 562  antigua_and_barbuda_english_20220601         409
# 563              somalia_english_20220601         111
#
#                                                content              country  \
# 0    Total GHG emission will be 409.4 MtCO2e in 203...           Bangladesh
# 1    Bangladesh’s INDC proposed for 12 million tons...           Bangladesh
# 2    Total GHG emission is found to be increased fr...           Bangladesh
# 3    Under this comprehensive plan, the government ...           Bangladesh
# 4    The updated unconditional and conditional cont...           Bangladesh
# ..                                                 ...                  ...
# 559  86% renewable energy generation in the electri...  Antigua and Barbuda
# 560  1. 86% renewable energy generation from local ...  Antigua and Barbuda
# 561  100% all new vehicle sales to be electric vehi...  Antigua and Barbuda
# 562  10. 30,000 homes or 50% of pre-2020 homes to h...  Antigua and Barbuda
# 563  Estimated projected BAU emissions from the sec...              Somalia
#
#     climate_bert_cluster                               w2v_cluster  \
# 0    Narrative - English  Emission Reduction Targets & Commitments
# 1    Narrative - English  Emission Reduction Targets & Commitments
# 2    Narrative - English  Emission Reduction Targets & Commitments
# 3    Narrative - English  Emission Reduction Targets & Commitments
# 4    Narrative - English  Emission Reduction Targets & Commitments
# ..                   ...                                       ...
# 559  Narrative - English            Project Sectors & Technologies
# 560  Narrative - English            Project Sectors & Technologies
# 561  Narrative - English            Project Sectors & Technologies
# 562  Narrative - English            Project Sectors & Technologies
# 563  Narrative - English  Emission Reduction Targets & Commitments
#
#                                         chunk_metadata  cosine_distance  \
# 0    {'links': [], 'filename': 'bangladesh_english_...         0.024598
# 1    {'links': [], 'filename': 'bangladesh_english_...         0.036378
# 2    {'links': [], 'filename': 'bangladesh_english_...         0.040419
# 3    {'links': [], 'filename': 'bangladesh_english_...         0.042267
# 4    {'links': [], 'filename': 'bangladesh_english_...         0.044091
# ..                                                 ...              ...
# 559  {'links': [], 'filename': 'antigua_and_barbuda...         0.032328
# 560  {'links': [], 'filename': 'antigua_and_barbuda...         0.035110
# 561  {'links': [], 'filename': 'antigua_and_barbuda...         0.036758
# 562  {'links': [], 'filename': 'antigua_and_barbuda...         0.047449
# 563  {'links': [], 'filename': 'somalia_english_202...         0.032208
#
#      cosine_similarity
# 0             0.975402
# 1             0.963622
# 2             0.959581
# 3             0.957733
# 4             0.955909
# ..                 ...
# 559           0.967672
# 560           0.964890
# 561           0.963242
# 562           0.952551
# 563           0.967792
#
# [564 rows x 9 columns]

# %% [markdown]
# # Establishing Ground-Truths/Gold-standard queries
# The above querying system seems to work well, however to improve I wanted to 'train' my query on several return statements that have been __verified__ and that we know to contain the truths we want to obtain

# %%
aus_bool = final_df['country'] == 'Australia'

for i in range(len(final_df[aus_bool]['content'])):
    if i in [3,4,7, 8]:
        print('=' * 40 + '  GROUND TRUTH  ' + '=' * 80)
        print(final_df[aus_bool]['content'].iloc[i])
        print('=' * 140 + '\n')
    else:
        print(final_df[aus_bool]['content'].iloc[i] + '\n')
# Out:
# Australia’s 2030 and 2050 targets are economy-wide absolute emissions reduction targets.
#
# Absolute economy-wide emissions reduction, as an emissions budget covering 2021-2030.
#
# Australia assesses progress towards its 2030 target by comparing cumulative net emissions over the period 2021–2030 with the emissions budget for the period.
#
# ========================================  GROUND TRUTH  ================================================================================
# Australia’s 2030 target is a 43% reduction below 2005 levels (reference indicator) by 2030, implemented as a single-year point target.
# ============================================================================================================================================
#
# ========================================  GROUND TRUTH  ================================================================================
# Australia’s 2030 target is a 43% reduction below 2005 levels by 2030, implemented as an emissions budget (reference indicator) covering the period 2021-2030.
# ============================================================================================================================================
#
# Implemented as an emissions budget covering the period 2021-2030
#
# A commitment to reduce the emissions of Commonwealth Government agencies to net zero by 2030 (excluding defence and security agencies).
#
# ========================================  GROUND TRUTH  ================================================================================
# In this updated NDC, Australia is increasing the ambition of its 2030 target, committing to reduce greenhouse gas emissions 43% below 2005 levels by 2030.
# ============================================================================================================================================
#
# ========================================  GROUND TRUTH  ================================================================================
# 43% below 2005 levels by 2030
# ============================================================================================================================================
#
# Australia will account for its 2030 single-year target on the basis of total net national emissions reported in its National Inventory Report for the year 2030, submitted under the Paris Agreement.

# %% [markdown]
# __Here I manually went into the docs to verify that the returned chunk was indeed correct for identifying the target__ See SS's below

# %% [markdown]
# ![Chart](ground_truth_images/Screenshot%202025-04-10%20at%2017.22.44.png)

# %% [markdown]
# ![Chart](ground_truth_images/Screenshot%202025-04-10%20at%2017.24.31.png)

# %% [markdown]
# We see in Australia's case for example, that our model has picked up on 4 'target-relevant chunks' out of 10 of the returned content chunks, already this is very promising, but I want to see if we can improve our selection (e.g. Better ranking of the true emissions targets, increased percentage of top 10 chunks containing target if possible). <BR>
#
# I want to develop a general array which captures the various forms that the emissions target are presented in - we see just in Australia's case there are two or 3 distinct ways that the targets are presented

# %%
# I'm building up a list of the ground truth sentences that I can use to strengthen the final queries I use to retrieve the chunks that will go into the LLM
gold_standard = ['43% below 2005 levels by 2030', 
                 'Australia’s 2030 target is a 43% reduction below 2005 levels (reference indicator) by 2030, implemented as a single-year point target.',
                 'In this updated NDC, Australia is increasing the ambition of its 2030 target, committing to reduce greenhouse gas emissions 43% below 2005 levels by 2030.'
                 ]

# %% [markdown]
# ##### Jordan

# %%
jord_bool = final_df['country'] == 'Jordan'

for i in range(len(final_df[jord_bool]['content'])):
    if i in [0, 1, 4]:
        print('=' * 40 + '  GROUND TRUTH  ' + '=' * 80)
        print(final_df[jord_bool]['content'].iloc[i])
        print('=' * 140 + '\n')
    else:
        print(final_df[jord_bool]['content'].iloc[i] + '\n')
# Out:
# ========================================  GROUND TRUTH  ================================================================================
# Jordan sets the target of achieving 31% reduction of emissions by 2030. Which is quantified to be 11269 Gg CO2 eq.
# ============================================================================================================================================
#
# ========================================  GROUND TRUTH  ================================================================================
# Outcomes of the analysis of the actions resulted in the target of total GHG emission reduction of 31% in 2030 compared to BAU in 2012 (description of actions is in Annex 1)
# ============================================================================================================================================
#
#  The projected emissions under BAU scenario is estimated to 43,989.0 Gg CO2 eq in year 2030.
#
# Increased percentage of electricity generated from renewables1 to have a share of more 35% by the year 2030
#
# ========================================  GROUND TRUTH  ================================================================================
# 2012 2015 2020 2025 2030 *The Estimated Mitigation Target is 31% ** Resulting target was calculated by dividing the accumulative emissions avoided till 2030 by the total emissions in 2030 resulting in the BAU scenario [target% = (accumulative emissions by 2030/BAU-2030 emissions)* 100]
# ============================================================================================================================================

# %% [markdown]
# <img src="ground_truth_images/Screenshot%202025-04-10%20at%2017.42.56.png" width="500"/>

# %% [markdown]
# __Other screenshots for Jordan and following countries omitted for brevity of the notebook__

# %% [markdown]
# For Jordan we see that we have 3 retrieved truths - all in different forms - again building up our 'gold-standard' templates

# %%
gold_standard.extend(['Jordan sets the target of achieving 31% reduction of emissions by 2030. Which is quantified to be 11269 Gg CO2 eq.', 'The Estimated Mitigation Target is 31%'])

# %%
final_df['country'].unique()
# Out:
# array(['Bangladesh', 'Brunei Darussalam', 'Cameroon', 'Viet Nam',
#        'Uganda', 'Montenegro', 'Jordan', 'Cambodia', 'Papua New Guinea',
#        'Singapore', 'Sri Lanka', 'Uzbekistan', 'Finland',
#        'United Kingdom of Great Britain and Northern Ireland', 'Albania',
#        'Grenada', 'Ukraine', 'Saudi Arabia', 'Sao Tome and Principe',
#        'Cuba', 'Kyrgyzstan', 'Algeria', 'Maldives', 'Djibouti',
#        'Malaysia', 'Ghana', 'Iceland', 'Zambia', 'Bosnia and Herzegovina',
#        'Liberia', 'Philippines', 'Tuvalu', 'State of Palestine',
#        'Cabo Verde', 'Rwanda', 'Tajikistan', 'Zimbabwe',
#        "Lao People's Democratic Republic", 'China', 'Saint Lucia',
#        'Armenia', 'Belarus', 'Australia', 'Dominica', 'Serbia', 'Angola',
#        'Vanuatu', 'United Arab Emirates', 'Georgia', 'Bhutan',
#        'Republic of Korea', 'Solomon Islands', 'Thailand', 'Togo',
#        'Burkina Faso', 'Oman', 'Micronesia (Federated States of)', 'Fiji',
#        'Holy See', 'Eritrea', 'Canada', 'Barbados',
#        'United Republic of Tanzania', 'Namibia', 'Marshall Islands',
#        'Cook Islands', 'Liechtenstein', 'Egypt', 'Afghanistan', 'Bahamas',
#        'India', 'Timor-Leste', 'Saint Kitts and Nevis', 'Gambia',
#        'Suriname', 'Kazakhstan', 'Japan', 'Jamaica',
#        'Trinidad and Tobago', 'Mongolia', 'United States of America',
#        'Seychelles', 'Switzerland', 'New Zealand', 'Belize', 'Norway',
#        'Botswana', 'Russian Federation', 'Pakistan', 'Guinea-Bissau',
#        'Ethiopia', 'South Sudan', 'Turkmenistan', 'Sudan',
#        'North Macedonia', 'Myanmar', 'Türkiye', 'Nepal', 'Tonga',
#        'Bolivia (Plurinational State of)', 'Lebanon', 'Samoa',
#        'Antigua and Barbuda', 'Somalia'], dtype=object)

# %%
swiss_bool = final_df['country'] == 'Switzerland'

for i in range(len(final_df[swiss_bool]['content'])):
    if i in [5]:
        print('=' * 40 + '  GROUND TRUTH  ' + '=' * 80)
        print(final_df[swiss_bool]['content'].iloc[i])
        print('=' * 140 + '\n')
    else:
        print(final_df[swiss_bool]['content'].iloc[i] + '\n')
# Out:
# globally, in particular methane emissions by 2030
#
# Switzerland’s emission reductions by 2030 will mainly be achieved domestically, thereby further strengthening Switzerland’s transition to a low carbon economy. Given the low greenhouse gas intensity of Switzerland today, its first NDC represents a high level of ambition.
#
# Switzerland expresses its first NDC both as single-year (2030) and multi-year target (2021–2030). The single-year target is implemented using an emission budget over the period 2021–2030.
#
# about 45 per cent compared with 2010 levels by 2030, given Switzerland’s per capita emissions are below global average. On the other hand, and in line with the IPCC report on 1.5 degrees Celsius, the indicative target for 2050 communicated in 2015 has been revised and raised to net zero greenhouse gas emissions.
#
# Emission reduction of at least minus 50 per cent by 2030 compared with 1990 levels, implemented as an emission budget covering 2021–2030, which is equivalent to an average reduction of net greenhouse gas emissions of at least 35 per cent over the period 2021–2030.
#
# ========================================  GROUND TRUTH  ================================================================================
# Switzerland’s commitment to reduce greenhouse gas emissions by at least 50 per cent by 2030 relative to 1990 levels puts Switzerland on an emission development pathway in line with the recommendations by science to keep average global temperature increase to 1.5 degrees Celsius.
# ============================================================================================================================================

# %%
gold_standard.extend(['Switzerland’s NDC target is to reduce greenhouse gas emissions by 50% by 2030 compared to 1990 levels.'])

# %%
belarus_bool = final_df['country'] == 'Belarus'

for i in range(len(final_df[belarus_bool]['content'])):
    if i in [4,5]:
        print('=' * 40 + '  GROUND TRUTH  ' + '=' * 80)
        print(final_df[belarus_bool]['content'].iloc[i])
        print('=' * 140 + '\n')
    else:
        print(final_df[belarus_bool]['content'].iloc[i] + '\n')
# Out:
# The type of commitment is the absolute reduction of greenhouse gas emissions until 2030 as compared to the base year emissions, inclusive of the LULUCF sector.
#
# The year 2018 was chosen as the base year for generating emission projections and accounting for greenhouse gas reduction policy and measures until 2030.
#
# Figure 1. Greenhouse gas emissions in 1990-2018 and commitment until 2030
#
# The dynamics of greenhouse gas emissions exclusive of the LULUCF sector during 1990-2018 and the commitment until 2030 are shown in Figure 1.
#
# ========================================  GROUND TRUTH  ================================================================================
# Taking into account the economic situation and the country's capabilities, the new unconditional economy-wide target is to reduce greenhouse gas emissions by at least 35 per cent from the 1990 level by 2030, inclusive of the LULUCF sector.
# ============================================================================================================================================
#
# ========================================  GROUND TRUTH  ================================================================================
# The new conditional economy-wide target is to reduce greenhouse gas emissions by at least 40 per cent from the 1990 level by 2030, inclusive of the LULUCF sector and subject to using international financing mechanisms to introduce the best available technologies for achieving greenhouse gas emissions reduction.
# ============================================================================================================================================
#
# The target will be achieved during the period from January 1, 2021 to December 31, 2030.
#
# The year 1990 is the base year for determining the target for reducing greenhouse gas emissions until 2030. The level of greenhouse gas emissions in 1990 was 137.8 million tonnes of CO2-eq. exclusive of the LULUCF sector, and 117.2 million tonnes of CO2-eq. inclusive of the LULUCF sector.

# %%
gold_standard.extend(['Belarus aims to reduce its greenhouse gas emissions by 2030 by 35% compared to 1990 levels.', 'The new conditional economy-wide target is to reduce greenhouse gas emissions by at least 40 per cent from the 1990 level by 2030'])

# %%
gold_standard
# Out:
# ['43% below 2005 levels by 2030',
#  'Australia’s 2030 target is a 43% reduction below 2005 levels (reference indicator) by 2030, implemented as a single-year point target.',
#  'In this updated NDC, Australia is increasing the ambition of its 2030 target, committing to reduce greenhouse gas emissions 43% below 2005 levels by 2030.',
#  'Jordan sets the target of achieving 31% reduction of emissions by 2030. Which is quantified to be 11269 Gg CO2 eq.',
#  'The Estimated Mitigation Target is 31%',
#  'Switzerland’s NDC target is to reduce greenhouse gas emissions by 50% by 2030 compared to 1990 levels.',
#  'Belarus aims to reduce its greenhouse gas emissions by 2030 by 35% compared to 1990 levels.',
#  'The new conditional economy-wide target is to reduce greenhouse gas emissions by at least 40 per cent from the 1990 level by 2030']

# %% [markdown]
# __We have now collected a nice list of 'gold-standard' phrases which capture exactly what we want to extract from the text - my idea is to curate a list of queries based on these and then generate embeddings for each of these, using them to fortify the chance that correct target-specific chunks are amongst the those that I feed into the LLM__
#
# To do so, I need to generalise the statements so that they are country-neutral, remove the numbers, and overall clean up so that they are more simplified which will help make them queryable

# %%
gold_standard_queries = [
 '2030 target is a % reduction in ghgs below levels by 2030',
 'reduce greenhouse gas emissions % below levels by 2030.',
 '% reduction of GHG emissions by 2030. Which is quantified to be Gg CO2 eq.',
 'The Estimated Mitigation Target is X% by 2030',
 'NDC target is to reduce greenhouse gas emissions by % by 2030',
 'aims to reduce its greenhouse gas emissions by 2030 by per cent compared to levels.']

gold_standard_queries
# Out:
# ['2030 target is a % reduction in ghgs below levels by 2030',
#  'reduce greenhouse gas emissions % below levels by 2030.',
#  '% reduction of GHG emissions by 2030. Which is quantified to be Gg CO2 eq.',
#  'The Estimated Mitigation Target is X% by 2030',
#  'NDC target is to reduce greenhouse gas emissions by % by 2030',
#  'aims to reduce its greenhouse gas emissions by 2030 by per cent compared to levels.']

# %%
gold_standard_query_embeddings = {}
for query in gold_standard_queries:
    tokenised_gs_query = tokenize_for_transformer_climate_roberta(query)
    gs_query_embedding = get_pooled_embeddings(tokenised_gs_query, climate_roberta_model)
346335,-0.025456594,-0.08191085,0.04273897,-0.034628864,-0.2657404,-0.10422671,-0.09134295,0.1475562,-0.09289896,0.062114984,0.07198396,0.18319285,0.12237171,-0.2211724,0.08496761,0.33873788,0.08759612,0.076745264,-0.043686703,-0.04961719,0.020164594,0.010386073,-0.010558185,-0.00069545704,0.3301383,0.049237132,0.34489873,0.09985292,0.03559724,0.1306911,0.11636293,-0.22965051,-0.024373153,-0.1634704,-0.091997385,0.39354917,0.011700091,-0.11201272,0.071517505,0.09586758,0.35806927,0.027260588,0.045775082,0.025558086,0.008184925,-0.04035725,0.31116048,0.101652324,0.16869374,-0.09291006,0.037942152,0.2076299,0.05946899,-0.0063794106,-0.25151646,0.11236622,0.08094039,0.071032315,-0.14813334,0.15168373,0.017177535,-0.03174368,-0.65405613,-0.03811857,0.21406893,0.17312562,-0.052179262,-0.010844965,0.15140264,-0.008408819,0.07797582,0.118987106,0.0001770084,0.06845215,0.06679208,-0.13939868,-0.031230306,0.009391603,0.08201211,-0.1024976,-0.35663685,-0.35141623,0.29029,0.15253985,0.21350472,-0.17954661,-0.09444058,0.21430866,0.020693136,0.08873127,-0.11442524,0.008694903,-0.023949347,0.112047255,-0.020308828,-0.16299054,0.1619478,0.093781926,0.30275577,0.106122494,-0.01926483,0.14362349,-0.105020605,-0.29247987,-0.11070246,0.09822011,0.16940121,0.2959622,-0.110237814,-0.28320011,0.12951802,0.24465303,0.08617129,-0.07345864,0.137766,-0.16800816,-0.13939561,0.019900301,0.06906622,-0.07822479,-0.048658356,0.3962051,0.038309246,-0.14312692,0.04934023,-0.15670286,0.029523835,-0.20699008,0.015593602,-0.0609584,-0.106894635,0.094896615,-0.20877464,-0.08172368,-0.08327289,0.15065144,-0.0025462015,0.018527402,0.11474815,-0.39338505,0.108192526,-0.07113494,-0.064292714,-0.11376508,0.019534586,0.113649964,-0.034877677,-0.18992329,0.14282614,-0.14934884,0.08732158,0.15137148,0.5893699,1.2922322,0.19284959,0.010654543,-0.08217 ...

# %%
all_gs_results = []
for country in country_list:
    for gs_query, embedding_val in gold_standard_query_embeddings.items():
        query = text("""
        SELECT 
            doc_chunks.doc_id,
            doc_chunks.chunk_index,
            doc_chunks.content,
            documents.country,
            doc_chunks.climate_bert_cluster_labels,
            doc_chunks.w2v_cluster_labels,
            doc_chunks.chunk_metadata,
            (doc_chunks.embedding <=> :embedding) AS cosine_distance
        FROM doc_chunks
        LEFT JOIN documents ON doc_chunks.doc_id = documents.doc_id
        WHERE 
            documents.country = :country
        ORDER BY cosine_distance ASC
        LIMIT 10
        """)

        with engine.connect() as conn:
            result_rows = conn.execute(query, {
                "embedding": embedding_val,
                "country": country
            }).fetchall()

        df_gs_results = pd.DataFrame(result_rows, columns=[
            "doc_id", "chunk_index", "content", "country", 
            "climate_bert_cluster", "w2v_cluster", "chunk_metadata", "cosine_distance"
        ])
        df_gs_results["gs_query"] = gs_query
        all_gs_results.append(df_gs_results)
        df_gs_results["cosine_similarity"] = 1 - df_gs_results["cosine_distance"]

# Combine all into one DataFrame
gs_queries_df = pd.concat(all_gs_results, ignore_index=True)
# Out:
# /var/folders/v6/xrbmfj054b7cb1_bvtvf02nc0000gn/T/ipykernel_65382/1674531613.py:37: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gs_queries_df = pd.concat(all_gs_results, ignore_index=True)

# %%
gs_queries_df['country'].unique()
# Out:
# array(['Bangladesh', 'Brunei Darussalam', 'Cameroon', 'Viet Nam',
#        'Uganda', 'Montenegro', 'Jordan', 'Syrian Arab Republic',
#        'Dominican Republic', 'Cambodia', 'Papua New Guinea', 'Singapore',
#        'San Marino', 'Sri Lanka', 'Uzbekistan', 'Finland',
#        'United Kingdom of Great Britain and Northern Ireland', 'Albania',
#        'Grenada', 'Ukraine', 'Saudi Arabia', 'Sao Tome and Principe',
#        'Cuba', 'Kyrgyzstan', 'Algeria', 'Maldives', 'Djibouti', 'Nauru',
#        'Senegal', 'Malaysia', 'Ghana', 'Iceland', 'Zambia', 'Kuwait',
#        'Sierra Leone', 'Bosnia and Herzegovina', 'Liberia', 'Philippines',
#        'Benin', 'Tuvalu', 'State of Palestine', 'Cabo Verde', 'Rwanda',
#        'Tajikistan', 'Zimbabwe', "Lao People's Democratic Republic",
#        'China', 'Saint Lucia', 'Armenia', 'Belarus', 'Gabon', 'Australia',
#        'Dominica', 'Serbia', 'Angola', 'Vanuatu', 'United Arab Emirates',
#        'Georgia', 'Malawi', 'Burundi', 'Democratic Republic of the Congo',
#        'Bhutan', 'Republic of Korea', 'Solomon Islands', 'Thailand',
#        'Togo', 'Niue', 'Burkina Faso', 'Oman',
#        'Micronesia (Federated States of)', 'Fiji', 'Holy See', 'Eritrea',
#        'Canada', 'Barbados', 'Saint Vincent and the Grenadines',
#        'United Republic of Tanzania', 'Namibia', 'Marshall Islands',
#        'Cook Islands', 'Liechtenstein', 'Azerbaijan', 'Egypt',
#        'Afghanistan', 'Bahamas', 'India', 'Timor-Leste', 'Chile',
#        'Saint Kitts and Nevis', 'Gambia', 'Suriname', 'South Africa',
#        'Kazakhstan', 'Central African Republic', 'Japan', 'Jamaica',
#        'Trinidad and Tobago', 'Mongolia', 'United States of America',
#        'Mauritania', 'Mozambique', 'Seychelles', 'Switzerland',
#        'New Zealand', 'Belize', 'Norway', 'Botswana',
#        'Russian Federation', 'Pakistan', 'Brazil', 'Guinea-Bissau',
#        'Ethiopia', 'Niger', 'Panama', 'South Sudan', 'Turkmenistan',
#        'Sudan', 'North Macedonia', 'Myanmar', 'Türkiye', 'Nicaragua',
#        'Mexico', 'Guyana', 'Nepal', 'Tonga',
#        'Bolivia (Plurinational State of)', 'Lebanon',
#        'Republic of Moldova', 'Samoa', 'Antigua and Barbuda', 'Somalia',
#        'Andorra'], dtype=object)

# %% [markdown]
# These already look strong, I have viewed the full content chunks below to ensure we are getting the ones we want

# %%
for i in range(0, 1500, 50):
    print(gs_queries_df['content'].iloc[i])
# Out:
# in household and commercial buildings (achieve 19% and 25% reduction in emission respectively)
# in household and commercial buildings (achieve 19% and 25% reduction in emission respectively)
# +0,6° C en 2025 à +3,6° C en 2100.
# Full implementation of the measure will contribute to a GHG emission reduction of approximately 3.37 MtCO2e by 2030.
# NDC scenario 2030 19%
#  The projected emissions under BAU scenario is estimated to 43,989.0 Gg CO2 eq in year 2030.
# GHG emission reduction is estimated at 0.002 MtCO2e/year for 3,500 new electric machines.
# Enhancing levels of renewables in the energy mix – through increasing from 30% (2015) to 78% the level of installed capacity for on grid electricity generation that is produced by renewables9.
# Not applicable. Singapore’s 2nd NDC is an economy-wide absolute GHG emissions reduction target.
# BAU emissions scenario and potential GHG emission reduction pathways for some mitigation
# − reduce pollutant emissions by 10% (from 2.5 million to 2.2 million tons);
# The EU’s at least 55% net reduction target by 2030 is to be achieved through domestic measures only, without contribution from international credits.
# In its NDC the UK commits to reducing economy-wide greenhouse gas emissions by at least 68% by 2030 compared to 1990 levels. This requires the fastest rate of reduction in greenhouse gases between 1990 and 2030 of all major economies. It remains a fair and ambitious contribution to global action on climate change.
# Reference (BAU) Fuelwood consumption decreases by 14% between 2016 and 2030
# The baseline GHG emissions for all sectors were calculated using 2006 IPCC guidelines.
# target of 65% emissions reduction The NDC economy-wide, is achievable for all sectors of the economy under the following conditions:
# In 2012, these emissions stood at approx. 154 GgCO2eq, while BAU projections indicate that by 2030 these emissions could reach 400 ktCO2eq, maintained the projected growth parametres adopted.
# In 2025, GHG emissions will be reduced by 16.63% on the GHG emission level under the BAU scenario, and by 36.61% subject to international support.
# The indicated CO2 reduction will reduce the GHG emissions of the sector in relation to the
# through to 2035. It underscores our ambitious commitment
# The adaptation projects currently being implemented account for a budget of nearly €100 million. However, that sum represents just 12% of the total amount that will need to be invested in adaptation under the 2°C Scenario, and a mere 7.5% in the case of the 4°C Scenario.
# 1 Carbon intensity throughout the document refers to GHG intensity from all the seven GHGs.
# Economy-wide net reduction of at least 55% in greenhouse gas emissions by 2030 compared to 1990. (see 3(a))
# This provisional NDC 3.0 is submitted with a conditional pledge of reducing Greenhouse Gas (GHG) emissions by 25% (20,000 Gg CO2 eq.) by 2030 against a base year of 2010 under the BAU scenario with levels of international support prevailing in 2015 or by 47% (38,000 Gg CO2 eq.) with substantial international support.
# Unconditional (in %) 80 10
# Reduction of GHG emissions compared to the baseline year
# o Reduce emissions by 25.63 Gg CO2e per year by supporting the implementation of a landfill gas recovery system on
# Objectif quantifié (horizon 2030)
# (power) sector by 100%, i.e., almost zero emissions by 2030. Increase energy efficiency in Funafuti by 30%.
# f. 30% reduction of methane emissions from landfill sites by 2030 and 70% reduction by

# %% [markdown]
# __These look very promising and already an improvement over the queries we have been running__ <BR>
#
# There are of course some duplicates in the chunks generated by the different queries so we need to filter these out first - doc_id plus chunk_index creates a unique filter for each content block so I will screen based on that

# %% [markdown]
# #### Threshold Intrdouction
# The only concern at this stage is that some of the chunks seems to be speaking about other targets related to NDC such as electricity, methane etc.. Aside from this there are of course obvious redundant chunks. If my similarity seearch process is robust then, by implementing a threshold filter, I should be able to isolate mostly those content chunks which are (A) specific to emissions and, (B) are not redundant unstructured pieces of text <BR>
#
# 434   by improving animal comfort and welfare (40% i...
# 743   Ukraine ranks 56th in the world by the size of...
# 954                       every five years thereafter”.
# 1004                         10,000 year flood scenario
# 1005                         Business-as-usual scenario
# 1006                         Business-as-usual scenario
# 1025                                Timeframe 1-3months
# 1090                                   Base year - 2019
# 1323  The Philippines is a low-middle income develop...
# 1563                                ‘Business as usual’
# 1782      As of the end of 2019, there were 16,432 pure
# 1854  Total final consumption of energy in 2018 was ...
# 1860  Total final consumption of energy in 2018 was ...
# 2068   13.2 % compared to 2010 - 33.3% compared to 1990
# 2077   13.2 % compared to 2010 - 33.3% compared to 1990
# 2086   13.2 % compared to 2010 - 33.3% compared to 1990
# 2099   13.2 % compared to 2010 - 33.3% compared to 1990
# 2144                    Start year: 2020 End year: 2025
# 2352             5.3.2 Business-as-usual (BAU) scenario
# 2499    average temperature are July and August (29°C).
# 2500                           Reference year or period
# 2692                    Start date: 2021 End date: 2030
# 2754  Accumulated until 2030 Accumulated until 2025 ...
# 2755  Accumulated until 2030 Accumulated until 2025 ...
# 2896                       Reference point or base year
# 3047                1 January 2031 to 31 December 2035.
# 3393                        Long-term ($) (11-25 years)
# 3394                         Short-term ($) (0-5 years)
# 3395                       Medium-term ($) (6-10 years)
# 3439                           Reference year or period
# 3518                in the second half of this century.
# 3519                       above pre-industrial levels.
# 3520                 1.5°C above pre-industrial levels.
# 3797                           business-as-usual (BAU);
# 4091                       (for the period up to 2025).
# 4298              Horizonte temporal Horizonte temporal
# 4299              Horizonte temporal Horizonte temporal
# 4300              Horizonte temporal Horizonte temporal
# 4301              Horizonte temporal Horizonte temporal
# 4302              Horizonte temporal Horizonte temporal
# 4303              Horizonte temporal Horizonte temporal
# 4304              Horizonte temporal Horizonte temporal
# 4506                      20% to MM 20% to MM 20% to MM
# 4858                  Extreme weather events: - - - - -
# 4859                  Extreme weather events: - - - - -
# 4860                  Extreme weather events: - - - - -
# 4861                  Extreme weather events: - - - - -
# 4862                  Extreme weather events: - - - - -
# 4907                           Selection of a base year
#
#                                country             climate_bert_cluster  \
# 100                           Cameroon              Narrative - English
# 102                           Cameroon              Narrative - English
# 106                           Cameroon              Narrative - English
# 108                           Cameroon              Narrative - English
# 246                             Jordan                 Tabular, Numeric
# 277                 Dominican Republic              Narrative - English
# 278                 Dominican Republic              Narrative - English
# 351                   Papua New Guinea              Narrative - English
# 391                          Singapore              Narrative - English
# 434                          Sri Lanka              Narrative - English
# 743                            Ukraine              Narrative - English
# 954                           Maldives  Headers, Keywords, Multilingual
# 1004                          Djibouti              Narrative - English
# 1005                          Djibouti              Narrative - English
# 1006                          Djibouti              Narrative - English
# 1025                             Nauru  Headers, Keywords, Multilingual
# 1090                             Ghana  Headers, Keywords, Multilingual
# 1323                       Philippines              Narrative - English
# 1563                            Rwanda              Narrative - English
# 1782                             China              Narrative - English
# 1854                           Armenia              Narrative - English
# 1860                           Armenia              Narrative - English
# 2068                            Serbia              Narrative - English
# 2077                            Serbia              Narrative - English
# 2086                            Serbia              Narrative - English
# 2099                            Serbia              Narrative - English
# 2144                            Angola              Narrative - English
# 2352                            Malawi                 Tabular, Numeric
# 2499                   Solomon Islands              Narrative - English
# 2500                   Solomon Islands  Headers, Keywords, Multilingual
# 2692                              Fiji              Narrative - English
# 2754                           Eritrea              Narrative - English
# 2755                           Eritrea              Narrative - English
# 2896  Saint Vincent and the Grenadines  Headers, Keywords, Multilingual
# 3047                  Marshall Islands              Narrative - English
# 3393                            Gambia              Narrative - English
# 3394                            Gambia              Narrative - English
# 3395                            Gambia              Narrative - English
# 3439                          Suriname  Headers, Keywords, Multilingual
# 3518                             Japan              Narrative - English
# 3519                             Japan              Narrative - English
# 3520                             Japan              Narrative - English
# 3797                        Seychelles              Narrative - English
# 4091                Russian Federation              Narrative - English
# 4298                            Panama  Headers, Keywords, Multilingual
# 4299                            Panama  Headers, Keywords, Multilingual
# 4300                            Panama  Headers, Keywords, Multilingual
# 4301                            Panama  Headers, Keywords, Multilingual
# 4302                            Panama  Headers, Keywords, Multilingual
# 4303                            Panama  Headers, Keywords, Multilingual
# 4304                            Panama  Headers, Keywords, Multilingual
# 4506                           Myanmar              Narrative - English
# 4858               Republic of Moldova                 Tabular, Numeric
# 4859               Republic of Moldova                 Tabular, Numeric
# 4860               Republic of Moldova                 Tabular, Numeric
# 4861               Republic of Moldova                 Tabular, Numeric
# 4862               Republic of Moldova                 Tabular, Numeric
# 4907                             Samoa  Headers, Keywords, Multilingual
#
#                                    w2v_cluster  \
# 100         Fragmented Phrases & Minor Details
# 102         Fragmented Phrases & Minor Details
# 106         Fragmented Phrases & Minor Details
# 108         Fragmented Phrases & Minor Details
# 246   Emission Reduction Targets & Commitments
# 277           Formal Climate Pledges – Spanish
# 278           Formal Climate Pledges – Spanish
# 351   Emission Reduction Targets & Commitments
# 391         Fragmented Phrases & Minor Details
# 434          Legal & Institutional Disclaimers
# 743          Legal & Institutional Disclaimers
# 954   Emission Reduction Targets & Commitments
# 1004  Emission Reduction Targets & Commitments
# 1005  Emission Reduction Targets & Commitments
# 1006  Emission Reduction Targets & Commitments
# 1025        Fragmented Phrases & Minor Details
# 1090  Emission Reduction Targets & Commitments
# 1323         Legal & Institutional Disclaimers
# 1563  Emission Reduction Targets & Commitments
# 1782        Fragmented Phrases & Minor Details
# 1854            Project Sectors & Technologies
# 1860            Project Sectors & Technologies
# 2068  Emission Reduction Targets & Commitments
# 2077  Emission Reduction Targets & Commitments
# 2086  Emission Reduction Targets & Commitments
# 2099  Emission Reduction Targets & Commitments
# 2144  Emission Reduction Targets & Commitments
# 2352  Emission Reduction Targets & Commitments
# 2499         Legal & Institutional Disclaimers
# 2500  Emission Reduction Targets & Commitments
# 2692        Fragmented Phrases & Minor Details
# 2754        Fragmented Phrases & Minor Details
# 2755        Fragmented Phrases & Minor Details
# 2896  Emission Reduction Targets & Commitments
# 3047        Fragmented Phrases & Minor Details
# 3393         Legal & Institutional Disclaimers
# 3394         Legal & Institutional Disclaimers
# 3395         Legal & Institutional Disclaimers
# 3439  Emission Reduction Targets & Commitments
# 3393  {'links': [], 'filename': 'gambia_english_2022...         0.052829
# 3394  {'links': [], 'filename': 'gambia_english_2022...         0.052951
# 3395  {'links': [], 'filename': 'gambia_english_2022...         0.054161
# 3439  {'links': [], 'filename': 'suriname_english_20...         0.053346
# 3518  {'links': [], 'filename': 'japan_english_20220...         0.054150
# 3519  {'links': [], 'filename': 'japan_english_20250...         0.067044
# 3520  {'links': [], 'filename': 'japan_english_20220...         0.069027
# 3797  {'links': [], 'filename': 'seychelles_english_...         0.060422
# 4091  {'links': [], 'filename': 'russian_federation_...         0.056229
# 4298  {'links': [], 'filename': 'panama_spanish_2024...         0.062223
# 4299  {'links': [], 'filename': 'panama_spanish_2024...         0.062223
# 4300  {'links': [], 'filename': 'panama_spanish_2024...         0.062223
# 4301  {'links': [], 'filename': 'panama_spanish_2024...         0.062223
# 4302  {'links': [], 'filename': 'panama_spanish_2024...         0.062223
# 4303  {'links': [], 'filename': 'panama_spanish_2024...         0.062223
# 4304  {'links': [], 'filename': 'panama_spanish_2024...         0.062223
# 4506  {'links': [], 'filename': 'myanmar_english_202...         0.061160
# 4858  {'links': [], 'filename': 'republic_of_moldova...         0.081684
# 4859  {'links': [], 'filename': 'republic_of_moldova...         0.081684
# 4860  {'links': [], 'filename': 'republic_of_moldova...         0.081684
# 4861  {'links': [], 'filename': 'republic_of_moldova...         0.081684
# 4862  {'links': [], 'filename': 'republic_of_moldova...         0.081684
# 4907  {'links': [], 'filename': 'samoa_english_20220...         0.052304
#
#                                                gs_query  cosine_similarity
# 100   reduce greenhouse gas emissions % below levels...           0.942609
# 102   % reduction of GHG emissions by 2030. Which is...           0.946854
# 106   NDC target is to reduce greenhouse gas emissio...           0.939166
# 108   aims to reduce its greenhouse gas emissions by...           0.938493
# 246       The Estimated Mitigation Target is X% by 2030           0.947053
# 277       The Estimated Mitigation Target is X% by 2030           0.948948
# 278       The Estimated Mitigation Target is X% by 2030           0.946612
# 351       The Estimated Mitigation Target is X% by 2030           0.948178
# 391       The Estimated Mitigation Target is X% by 2030           0.947795
# 434   reduce greenhouse gas emissions % below levels...           0.947139
# 743   reduce greenhouse gas emissions % below levels...           0.947170
# 954       The Estimated Mitigation Target is X% by 2030           0.942005
# 1004      The Estimated Mitigation Target is X% by 2030           0.949864
# 1005      The Estimated Mitigation Target is X% by 2030           0.942059
# 1006      The Estimated Mitigation Target is X% by 2030           0.942059
# 1025      The Estimated Mitigation Target is X% by 2030           0.949815
# 1090      The Estimated Mitigation Target is X% by 2030           0.946394
# 1323  reduce greenhouse gas emissions % below levels...           0.947824
# 1563      The Estimated Mitigation Target is X% by 2030           0.944680
# 1782      The Estimated Mitigation Target is X% by 2030           0.938069
# 1854  2030 target is a % reduction in ghgs below lev...           0.946096
# 1860  reduce greenhouse gas emissions % below levels...           0.948034
# 2068  2030 target is a % reduction in ghgs below lev...           0.948388
# 2077  reduce greenhouse gas emissions % below levels...           0.938690
# 2086  % reduction of GHG emissions by 2030. Which is...           0.949578
# 2099  NDC target is to reduce greenhouse gas emissio...           0.945702
# 2144      The Estimated Mitigation Target is X% by 2030           0.939935
# 2352      The Estimated Mitigation Target is X% by 2030           0.945364
# 2499      The Estimated Mitigation Target is X% by 2030           0.948425
# 2500      The Estimated Mitigation Target is X% by 2030           0.946654
# 2692      The Estimated Mitigation Target is X% by 2030           0.938417
# 2754      The Estimated Mitigation Target is X% by 2030           0.934467
# 2755      The Estimated Mitigation Target is X% by 2030           0.934467
# 2896      The Estimated Mitigation Target is X% by 2030           0.942953
# 3047      The Estimated Mitigation Target is X% by 2030           0.947795
# 3393      The Estimated Mitigation Target is X% by 2030           0.947171
# 3394      The Estimated Mitigation Target is X% by 2030           0.947049
# 3395      The Estimated Mitigation Target is X% by 2030           0.945839
# 3439      The Estimated Mitigation Target is X% by 2030           0.946654
# 3518      The Estimated Mitigation Target is X% by 2030           0.945850
# 3519      The Estimated Mitigation Target is X% by 2030           0.932956
# 3520      The Estimated Mitigation Target is X% by 2030           0.930973
# 3797      The Estimated Mitigation Target is X% by 2030           0.939578
# 4091      The Estimated Mitigation Target is X% by 2030           0.943771
# 4298      The Estimated Mitigation Target is X% by 2030           0.937777
# 4299      The Estimated Mitigation Target is X% by 2030           0.937777
# 4300      The Estimated Mitigation Target is X% by 2030           0.937777
# 4301      The Estimated Mitigation Target is X% by 2030           0.937777
# 4302      The Estimated Mitigation Target is X% by 2030           0.937777
# 4303      The Estimated Mitigation Target is X% by 2030           0.937777
# 4304      The Estimated Mitigation Target is X% by 2030           0.937777
# 4506      The Estimated Mitigation Target is X% by 2030           0.938840
# 4858      The Estimated Mitigation Target is X% by 2030           0.918316
# 4859      The Estimated Mitigation Target is X% by 2030           0.918316
# 4860      The Estimated Mitigation Target is X% by 2030           0.918316
# 4861      The Estimated Mitigation Target is X% by 2030           0.918316
# 4862      The Estimated Mitigation Target is X% by 2030           0.918316
# 4907      The Estimated Mitigation Target is X% by 2030           0.947696

# %% [markdown]
# The above filters out 58 chunks - they all look redundant so I will look to see if implementing an even tighter threshold helps with screening or if it skims some relevant chunks

# %%
distant_96_chunks_mask = gs_queries_df['cosine_distance'] > 0.04
print(f'Number of distance chunks (<0.95 cosine similarity distance away:{len(gs_queries_df[distant_96_chunks_mask])}')

for i in range(0, len(gs_queries_df[distant_96_chunks_mask]), 10):
    print(gs_queries_df[distant_96_chunks_mask]['content'].iloc[i])
# Out:
# Number of distance chunks (<0.95 cosine similarity distance away:299
# In unconditional scenario, GHG emissions would be reduced by 27.56 Mt CO2e (6.73%) below BAU in 2030 and in conditional scenario, GHG emissions would be reduced by 89.47 Mt CO2e (21.85%) below BAU in 2030 in the respective sectors.
# +0,6° C en 2025 à +3,6° C en 2100.
# Planificación: (2020-2022) Ejecución (2022-2030)
# Base year: 2005
# projected high growth in the near future;
# Ukraine ranks 56th in the world by the size of nominal GDP in absolute terms, and 119th by size of GDP per capita.
# The adaptation projects currently being implemented account for a budget of nearly €100 million. However, that sum represents just 12% of the total amount that will need to be invested in adaptation under the 2°C Scenario, and a mere 7.5% in the case of the 4°C Scenario.
# d. Target relative to the reference indicator, expressed numerically, for example, in percentage or amount of reduction.
# The Philippines is a low-middle income developing country with a current population of 108.7
# 5 MW solar photovoltaic plant for São Vicente by 2023 ;
# Jilin Oilfield 300,000 tons / year
# Value of target relative to the reference indicator
# Serbia suffered damages caused by climate change and extreme weather events (in the period 2000-2015 minimum EUR 1.8 billion, additional to EUR 5 billion in the 2015-2020 period).
# Population projections 2020-2050 (hab.)
# 2019 - end of 2035
#  899042 en 2030
# The Republic of Korea has significantly enhanced the previous update of its first NDC by 2030 from the 24.4% reduction compared to 2017 level to 40% reduction from 2018 level. Accordingly, the GHG emissions level targeted in 2030 is reduced from 536.1 MtCO2eq to 436.6 MtCO2eq, which is approximately 100 MtCO2eq reduction.
# 21 574,63 Gg CO2eq à l’horizon 2030, soit 18,2% par rapport au scenario Business As Usual
# Base year 2011
# a 1.2°C to 2.3°C median annual increase in surface temperature; and
# w Multi-Year Target (2022-2030) w The NDC is based on a range of steps and milestones that will be achieved at different points over the 2022-2030 timeframe.
# 1 Excluded from the indicative NDC costs of 637 million USD as the plant is already being constructed and financed by a private party with an expected commercial operation date in 2023.
# fiscal year 2030*1
# d. Target relative to the reference indicator, expressed numerically, in percentage or amount of reduction
# Start year: 2020; End year: 2030
# d) Target relative to the reference indicator, expressed numerically, for example in percentage or amount of reduction
# Horizonte temporal Horizonte temporal
# FY 2018-2019 (MMK million)
# and pursuing efforts to limit the increase to 1.5 °C; and
# Lost heat production due to the current water supply deficit on Dniester River is estimated at US$ 4.6 million per year, based on the current import price and the assumption that energy production is affected proportionally by the water supply shortage.

# %% [markdown]
# Majority of these look to be irrelevant however, some chunks are relevant - I will therefore adopt a threshold slightly below this at 0.958

# %%
irrelevant_chunks_mask = gs_queries_df['cosine_distance'] > 0.042
print(gs_queries_df[irrelevant_chunks_mask])
print(f'We will be removing: {len(gs_queries_df[irrelevant_chunks_mask])} chunks')

irrelevant_chunks_mask = gs_queries_df['cosine_distance'] > 0.042
gs_queries_df_partial_clean = gs_queries_df[~irrelevant_chunks_mask].reset_index(drop=True)
# Out:
#                                     doc_id chunk_index  \
# 19             bangladesh_english_20220601         886
# 81      brunei_darussalam_english_20220601          25
# 82      brunei_darussalam_english_20220601           7
# 98                cameroon_french_20220601         898
# 100               cameroon_french_20220601         898
# ...                                    ...         ...
# 4958  antigua_and_barbuda_english_20220601         367
# 4959  antigua_and_barbuda_english_20220601         226
# 4991              andorra_spanish_20250201         140
# 4998              andorra_spanish_20250201         140
# 5001              andorra_spanish_20250201         140
#
#                                                 content              country  \
# 19    The updated unconditional and conditional cont...           Bangladesh
# 81    1 January 2021 – 31 December 2030 (10-year per...    Brunei Darussalam
# 82                                      Base year: 2015    Brunei Darussalam
# 98                   +0,6° C en 2025 à +3,6° C en 2100.             Cameroon
# 100                  +0,6° C en 2025 à +3,6° C en 2100.             Cameroon
# ...                                                 ...                  ...
# 4958                  an indicative start year of 2025)  Antigua and Barbuda
# 4959                      for the period of 2020 - 2030  Antigua and Barbuda
# 4991  target based on a "Business as Usual" (BAU) sc...              Andorra
# 4998  target based on a "Business as Usual" (BAU) sc...              Andorra
# 5001  target based on a "Business as Usual" (BAU) sc...              Andorra
#
#                  climate_bert_cluster  \
# 19                Narrative - English
# 81                Narrative - English
# 82    Headers, Keywords, Multilingual
# 98                Narrative - English
# 100               Narrative - English
# ...                               ...
# 4958  Headers, Keywords, Multilingual
# 4959              Narrative - English
# 4991              Narrative - English
# 4998              Narrative - English
# 5001              Narrative - English
#
#                                    w2v_cluster  \
# 19    Emission Reduction Targets & Commitments
# 81    Emission Reduction Targets & Commitments
# 82    Emission Reduction Targets & Commitments
# 98          Fragmented Phrases & Minor Details
# 100         Fragmented Phrases & Minor Details
# ...                                        ...
# 4958  Emission Reduction Targets & Commitments
# 4959  Emission Reduction Targets & Commitments
# 4991  Emission Reduction Targets & Commitments
# 4998  Emission Reduction Targets & Commitments
# 5001  Emission Reduction Targets & Commitments
#
#                                          chunk_metadata  cosine_distance  \
# 19    {'links': [], 'filename': 'bangladesh_english_...         0.045121
# 81    {'links': [], 'filename': 'brunei_darussalam_e...         0.045216
# 82    {'links': [], 'filename': 'brunei_darussalam_e...         0.049579
# 98    {'links': [], 'filename': 'cameroon_french_202...         0.049589
# 100   {'links': [], 'filename': 'cameroon_french_202...         0.057391
# ...                                                 ...              ...
# 4958  {'links': [], 'filename': 'antigua_and_barbuda...         0.042392
# 4959  {'links': [], 'filename': 'antigua_and_barbuda...         0.043195
# 4991  {'links': [], 'filename': 'andorra_spanish_202...         0.043098
# 4998  {'links': [], 'filename': 'andorra_spanish_202...         0.046471
# 5001  {'links': [], 'filename': 'andorra_spanish_202...         0.045762
#
#                                                gs_query  cosine_similarity
# 19    reduce greenhouse gas emissions % below levels...           0.954879
# 81        The Estimated Mitigation Target is X% by 2030           0.954784
# 82        The Estimated Mitigation Target is X% by 2030           0.950421
# 98    2030 target is a % reduction in ghgs below lev...           0.950411
# 100   reduce greenhouse gas emissions % below levels...           0.942609
# ...                                                 ...                ...
# 4958      The Estimated Mitigation Target is X% by 2030           0.957608
# 4959      The Estimated Mitigation Target is X% by 2030           0.956805
# 4991  reduce greenhouse gas emissions % below levels...           0.956902
# 4998  NDC target is to reduce greenhouse gas emissio...           0.953529
# 5001  aims to reduce its greenhouse gas emissions by...           0.954238
#
# [222 rows x 10 columns]
# We will be removing: 222 chunks

# %%
gs_queries_df_clean= gs_queries_df_partial_clean.drop_duplicates(subset=["doc_id", "chunk_index"], keep="first").reset_index(drop=True)

#This drops the number of rows to 1773, this is very good when we consider that we want to pass as few chunks/tokens into the LLM to keep within the limit and also to not overload with unnecessary information
gs_queries_df_clean
# Out:
#                            doc_id chunk_index  \
# 0     bangladesh_english_20220601         517
# 1     bangladesh_english_20220601         377
# 2     bangladesh_english_20220601         745
# 3     bangladesh_english_20220601          10
# 4     bangladesh_english_20220601         740
# ...                           ...         ...
# 1669     somalia_english_20220601         198
# 1670     andorra_spanish_20250201         135
# 1671     andorra_spanish_20250201         136
# 1672     andorra_spanish_20250201         140
# 1673     andorra_spanish_20250201         134
#
#                                                 content     country  \
# 0     in household and commercial buildings (achieve...  Bangladesh
# 1     in household and commercial buildings (achieve...  Bangladesh
# 2     Total GHG emission will be 409.4 MtCO2e in 203...  Bangladesh
# 3     Bangladesh’s INDC proposed for 12 million tons...  Bangladesh
# 4     Total GHG emission accounts for 169.05 MtCO2e ...  Bangladesh
# ...                                                 ...         ...
# 1669  Estimated investment required (in USD, 2021-20...     Somalia
# 1670  in net greenhouse gas emissions by 2035, compa...     Andorra
# 1671  2005 levels, with the ambition of achieving ca...     Andorra
# 1672  target based on a "Business as Usual" (BAU) sc...     Andorra
# 1673  at COP28. This document establishes a 63% redu...     Andorra
#
#      climate_bert_cluster                               w2v_cluster  \
# 0     Narrative - English  Emission Reduction Targets & Commitments
# 1     Narrative - English  Emission Reduction Targets & Commitments
# 2     Narrative - English  Emission Reduction Targets & Commitments
# 3     Narrative - English  Emission Reduction Targets & Commitments
# 4     Narrative - English  Emission Reduction Targets & Commitments
# ...                   ...                                       ...
# 1669  Narrative - English   Population & Infrastructure Projections
# 1670  Narrative - English  Emission Reduction Targets & Commitments
# 1671  Narrative - English  Emission Reduction Targets & Commitments
# 1672  Narrative - English  Emission Reduction Targets & Commitments
# 1673  Narrative - English  Emission Reduction Targets & Commitments
#
#                                          chunk_metadata  cosine_distance  \
# 0     {'links': [], 'filename': 'bangladesh_english_...         0.021411
# 1     {'links': [], 'filename': 'bangladesh_english_...         0.021864
# 2     {'links': [], 'filename': 'bangladesh_english_...         0.023136
# 3     {'links': [], 'filename': 'bangladesh_english_...         0.028163
# 4     {'links': [], 'filename': 'bangladesh_english_...         0.029066
# ...                                                 ...              ...
# 1669  {'links': [], 'filename': 'somalia_english_202...         0.028079
# 1670  {'links': [], 'filename': 'andorra_spanish_202...         0.021906
# 1671  {'links': [], 'filename': 'andorra_spanish_202...         0.024723
# 1672  {'links': [], 'filename': 'andorra_spanish_202...         0.036083
# 1673  {'links': [], 'filename': 'andorra_spanish_202...         0.024120
#
#                                                gs_query  cosine_similarity
# 0     2030 target is a % reduction in ghgs below lev...           0.978589
# 1     2030 target is a % reduction in ghgs below lev...           0.978136
# 2     2030 target is a % reduction in ghgs below lev...           0.976864
# 3     2030 target is a % reduction in ghgs below lev...           0.971837
# 4     2030 target is a % reduction in ghgs below lev...           0.970934
# ...                                                 ...                ...
# 1669      The Estimated Mitigation Target is X% by 2030           0.971921
# 1670  2030 target is a % reduction in ghgs below lev...           0.978094
# 1671  2030 target is a % reduction in ghgs below lev...           0.975277
# 1672  2030 target is a % reduction in ghgs below lev...           0.963917
# 1673      The Estimated Mitigation Target is X% by 2030           0.975880
#
# [1674 rows x 10 columns]

# %%
#Quick calculation to see if we are on track in terms of the number of tokens we are going to be passing in to the LLM
len(gs_queries_df_clean) / len(gs_queries_df_clean['country'].unique())

#13 chunks per country on average - assuming with the other retrieved chunks we end passing in 20 chunks to the LLM, this should be fine given the number of tokens I have
# Out:
# 12.976744186046512

# %%
#Manipulate the gs dataframe so that columns match the final_df -> ready for merging
final_gs_queries = gs_queries_df_clean.copy()
final_gs_queries.drop(columns='gs_query', inplace=True)

if list(final_gs_queries.columns) == list(final_df.columns):
    print('Columns are the same, ready for merging')
# Out:
# Columns are the same, ready for merging

# %%
complete_embeddings_df = pd.concat([final_df, final_gs_queries], ignore_index=True)

# %%
complete_embeddings_df = complete_embeddings_df.drop_duplicates(subset=["doc_id", "chunk_index"]).reset_index(drop=True)
complete_embeddings_df
# Out:
#                            doc_id chunk_index  \
# 0     bangladesh_english_20220601         745
# 1     bangladesh_english_20220601          10
# 2     bangladesh_english_20220601          92
# 3     bangladesh_english_20220601         588
# 4     bangladesh_english_20220601         886
# ...                           ...         ...
# 1726     somalia_english_20220601         198
# 1727     andorra_spanish_20250201         135
# 1728     andorra_spanish_20250201         136
# 1729     andorra_spanish_20250201         140
# 1730     andorra_spanish_20250201         134
#
#                                                 content     country  \
# 0     Total GHG emission will be 409.4 MtCO2e in 203...  Bangladesh
# 1     Bangladesh’s INDC proposed for 12 million tons...  Bangladesh
# 2     Total GHG emission is found to be increased fr...  Bangladesh
# 3     Under this comprehensive plan, the government ...  Bangladesh
# 4     The updated unconditional and conditional cont...  Bangladesh
# ...                                                 ...         ...
# 1726  Estimated investment required (in USD, 2021-20...     Somalia
# 1727  in net greenhouse gas emissions by 2035, compa...     Andorra
# 1728  2005 levels, with the ambition of achieving ca...     Andorra
# 1729  target based on a "Business as Usual" (BAU) sc...     Andorra
# 1730  at COP28. This document establishes a 63% redu...     Andorra
#
#      climate_bert_cluster                               w2v_cluster  \
# 0     Narrative - English  Emission Reduction Targets & Commitments
# 1     Narrative - English  Emission Reduction Targets & Commitments
# 2     Narrative - English  Emission Reduction Targets & Commitments
# 3     Narrative - English  Emission Reduction Targets & Commitments
# 4     Narrative - English  Emission Reduction Targets & Commitments
# ...                   ...                                       ...
# 1726  Narrative - English   Population & Infrastructure Projections
# 1727  Narrative - English  Emission Reduction Targets & Commitments
# 1728  Narrative - English  Emission Reduction Targets & Commitments
# 1729  Narrative - English  Emission Reduction Targets & Commitments
# 1730  Narrative - English  Emission Reduction Targets & Commitments
#
#                                          chunk_metadata  cosine_distance  \
# 0     {'links': [], 'filename': 'bangladesh_english_...         0.024598
# 1     {'links': [], 'filename': 'bangladesh_english_...         0.036378
# 2     {'links': [], 'filename': 'bangladesh_english_...         0.040419
# 3     {'links': [], 'filename': 'bangladesh_english_...         0.042267
# 4     {'links': [], 'filename': 'bangladesh_english_...         0.044091
# ...                                                 ...              ...
# 1726  {'links': [], 'filename': 'somalia_english_202...         0.028079
# 1727  {'links': [], 'filename': 'andorra_spanish_202...         0.021906
# 1728  {'links': [], 'filename': 'andorra_spanish_202...         0.024723
# 1729  {'links': [], 'filename': 'andorra_spanish_202...         0.036083
# 1730  {'links': [], 'filename': 'andorra_spanish_202...         0.024120
#
#       cosine_similarity
# 0              0.975402
# 1              0.963622
# 2              0.959581
# 3              0.957733
# 4              0.955909
# ...                 ...
# 1726           0.971921
# 1727           0.978094
# 1728           0.975277
# 1729           0.963917
# 1730           0.975880
#
# [1731 rows x 9 columns]

# %%
# The final number of chunks is 13.4 per country - some will of course have more and some less 
len(complete_embeddings_df) / len(complete_embeddings_df['country'].unique())
# Out:
# 13.418604651162791

# %%
complete_embeddings_df
# Out:
#                            doc_id chunk_index  \
# 0     bangladesh_english_20220601         745
# 1     bangladesh_english_20220601          10
# 2     bangladesh_english_20220601          92
# 3     bangladesh_english_20220601         588
# 4     bangladesh_english_20220601         886
# ...                           ...         ...
# 1726     somalia_english_20220601         198
# 1727     andorra_spanish_20250201         135
# 1728     andorra_spanish_20250201         136
# 1729     andorra_spanish_20250201         140
# 1730     andorra_spanish_20250201         134
#
#                                                 content     country  \
# 0     Total GHG emission will be 409.4 MtCO2e in 203...  Bangladesh
# 1     Bangladesh’s INDC proposed for 12 million tons...  Bangladesh
# 2     Total GHG emission is found to be increased fr...  Bangladesh
# 3     Under this comprehensive plan, the government ...  Bangladesh
# 4     The updated unconditional and conditional cont...  Bangladesh
# ...                                                 ...         ...
# 1726  Estimated investment required (in USD, 2021-20...     Somalia
# 1727  in net greenhouse gas emissions by 2035, compa...     Andorra
# 1728  2005 levels, with the ambition of achieving ca...     Andorra
# 1729  target based on a "Business as Usual" (BAU) sc...     Andorra
# 1730  at COP28. This document establishes a 63% redu...     Andorra
#
#      climate_bert_cluster                               w2v_cluster  \
# 0     Narrative - English  Emission Reduction Targets & Commitments
# 1     Narrative - English  Emission Reduction Targets & Commitments
# 2     Narrative - English  Emission Reduction Targets & Commitments
# 3     Narrative - English  Emission Reduction Targets & Commitments
# 4     Narrative - English  Emission Reduction Targets & Commitments
# ...                   ...                                       ...
# 1726  Narrative - English   Population & Infrastructure Projections
# 1727  Narrative - English  Emission Reduction Targets & Commitments
# 1728  Narrative - English  Emission Reduction Targets & Commitments
# 1729  Narrative - English  Emission Reduction Targets & Commitments
# 1730  Narrative - English  Emission Reduction Targets & Commitments
#
#                                          chunk_metadata  cosine_distance  \
# 0     {'links': [], 'filename': 'bangladesh_english_...         0.024598
# 1     {'links': [], 'filename': 'bangladesh_english_...         0.036378
# 2     {'links': [], 'filename': 'bangladesh_english_...         0.040419
# 3     {'links': [], 'filename': 'bangladesh_english_...         0.042267
# 4     {'links': [], 'filename': 'bangladesh_english_...         0.044091
# ...                                                 ...              ...
# 1726  {'links': [], 'filename': 'somalia_english_202...         0.028079
# 1727  {'links': [], 'filename': 'andorra_spanish_202...         0.021906
# 1728  {'links': [], 'filename': 'andorra_spanish_202...         0.024723
# 1729  {'links': [], 'filename': 'andorra_spanish_202...         0.036083
# 1730  {'links': [], 'filename': 'andorra_spanish_202...         0.024120
#
#       cosine_similarity
# 0              0.975402
# 1              0.963622
# 2              0.959581
# 3              0.957733
# 4              0.955909
# ...                 ...
# 1726           0.971921
# 1727           0.978094
# 1728           0.975277
# 1729           0.963917
# 1730           0.975880
#
# [1731 rows x 9 columns]

# %%
countries = complete_embeddings_df['country'].unique()
countries
# Out:
# array(['Bangladesh', 'Brunei Darussalam', 'Cameroon', 'Viet Nam',
#        'Uganda', 'Montenegro', 'Jordan', 'Cambodia', 'Papua New Guinea',
#        'Singapore', 'Sri Lanka', 'Uzbekistan', 'Finland',
#        'United Kingdom of Great Britain and Northern Ireland', 'Albania',
#        'Grenada', 'Ukraine', 'Saudi Arabia', 'Sao Tome and Principe',
#        'Cuba', 'Kyrgyzstan', 'Algeria', 'Maldives', 'Djibouti',
#        'Malaysia', 'Ghana', 'Iceland', 'Zambia', 'Bosnia and Herzegovina',
#        'Liberia', 'Philippines', 'Tuvalu', 'State of Palestine',
#        'Cabo Verde', 'Rwanda', 'Tajikistan', 'Zimbabwe',
#        "Lao People's Democratic Republic", 'China', 'Saint Lucia',
#        'Armenia', 'Belarus', 'Australia', 'Dominica', 'Serbia', 'Angola',
#        'Vanuatu', 'United Arab Emirates', 'Georgia', 'Bhutan',
#        'Republic of Korea', 'Solomon Islands', 'Thailand', 'Togo',
#        'Burkina Faso', 'Oman', 'Micronesia (Federated States of)', 'Fiji',
#        'Holy See', 'Eritrea', 'Canada', 'Barbados',
#        'United Republic of Tanzania', 'Namibia', 'Marshall Islands',
#        'Cook Islands', 'Liechtenstein', 'Egypt', 'Afghanistan', 'Bahamas',
#        'India', 'Timor-Leste', 'Saint Kitts and Nevis', 'Gambia',
#        'Suriname', 'Kazakhstan', 'Japan', 'Jamaica',
#        'Trinidad and Tobago', 'Mongolia', 'United States of America',
#        'Seychelles', 'Switzerland', 'New Zealand', 'Belize', 'Norway',
#        'Botswana', 'Russian Federation', 'Pakistan', 'Guinea-Bissau',
#        'Ethiopia', 'South Sudan', 'Turkmenistan', 'Sudan',
#        'North Macedonia', 'Myanmar', 'Türkiye', 'Nepal', 'Tonga',
#        'Bolivia (Plurinational State of)', 'Lebanon', 'Samoa',
#        'Antigua and Barbuda', 'Somalia', 'Syrian Arab Republic',
#        'San Marino', 'Senegal', 'Kuwait', 'Sierra Leone', 'Benin',
#        'Gabon', 'Malawi', 'Burundi', 'Democratic Republic of the Congo',
#        'Niue', 'Saint Vincent and the Grenadines', 'Azerbaijan', 'Chile',
#        'South Africa', 'Central African Republic', 'Mauritania',
#        'Mozambique', 'Brazil', 'Niger', 'Nicaragua', 'Mexico', 'Guyana',
#        'Republic of Moldova', 'Andorra'], dtype=object)

# %%
complete_embeddings_df
# Out:
#                            doc_id chunk_index  \
# 0     bangladesh_english_20220601         745
# 1     bangladesh_english_20220601          10
# 2     bangladesh_english_20220601          92
# 3     bangladesh_english_20220601         588
# 4     bangladesh_english_20220601         886
# ...                           ...         ...
# 1726     somalia_english_20220601         198
# 1727     andorra_spanish_20250201         135
# 1728     andorra_spanish_20250201         136
# 1729     andorra_spanish_20250201         140
# 1730     andorra_spanish_20250201         134
#
#                                                 content     country  \
# 0     Total GHG emission will be 409.4 MtCO2e in 203...  Bangladesh
# 1     Bangladesh’s INDC proposed for 12 million tons...  Bangladesh
# 2     Total GHG emission is found to be increased fr...  Bangladesh
# 3     Under this comprehensive plan, the government ...  Bangladesh
# 4     The updated unconditional and conditional cont...  Bangladesh
# ...                                                 ...         ...
# 1726  Estimated investment required (in USD, 2021-20...     Somalia
# 1727  in net greenhouse gas emissions by 2035, compa...     Andorra
# 1728  2005 levels, with the ambition of achieving ca...     Andorra
# 1729  target based on a "Business as Usual" (BAU) sc...     Andorra
# 1730  at COP28. This document establishes a 63% redu...     Andorra
#
#      climate_bert_cluster                               w2v_cluster  \
# 0     Narrative - English  Emission Reduction Targets & Commitments
# 1     Narrative - English  Emission Reduction Targets & Commitments
# 2     Narrative - English  Emission Reduction Targets & Commitments
# 3     Narrative - English  Emission Reduction Targets & Commitments
# 4     Narrative - English  Emission Reduction Targets & Commitments
# ...                   ...                                       ...
# 1726  Narrative - English   Population & Infrastructure Projections
# 1727  Narrative - English  Emission Reduction Targets & Commitments
# 1728  Narrative - English  Emission Reduction Targets & Commitments
# 1729  Narrative - English  Emission Reduction Targets & Commitments
# 1730  Narrative - English  Emission Reduction Targets & Commitments
#
#                                          chunk_metadata  cosine_distance  \
# 0     {'links': [], 'filename': 'bangladesh_english_...         0.024598
# 1     {'links': [], 'filename': 'bangladesh_english_...         0.036378
# 2     {'links': [], 'filename': 'bangladesh_english_...         0.040419
# 3     {'links': [], 'filename': 'bangladesh_english_...         0.042267
# 4     {'links': [], 'filename': 'bangladesh_english_...         0.044091
# ...                                                 ...              ...
# 1726  {'links': [], 'filename': 'somalia_english_202...         0.028079
# 1727  {'links': [], 'filename': 'andorra_spanish_202...         0.021906
# 1728  {'links': [], 'filename': 'andorra_spanish_202...         0.024723
# 1729  {'links': [], 'filename': 'andorra_spanish_202...         0.036083
# 1730  {'links': [], 'filename': 'andorra_spanish_202...         0.024120
#
#       cosine_similarity
# 0              0.975402
# 1              0.963622
# 2              0.959581
# 3              0.957733
# 4              0.955909
# ...                 ...
# 1726           0.971921
# 1727           0.978094
# 1728           0.975277
# 1729           0.963917
# 1730           0.975880
#
# [1731 rows x 9 columns]

# %% [markdown]
# ### LLM API Interaction - The Generative Portion of My RAG Pipeline
#
# The final step in my pipeline is to 'generate' responses to the original question <BR>
# We have completed the retrieval stage as is evident in the above dataframe - now is a question of generating the optimal response using LLM responses based on the fed in chunks we have identified

# %%
## CAN IGNORE
# Practice cell for formatting context to pass to the LLM - 
def format_context(row):
    return f"Doc ID: {row['doc_id']}, Chunk ID: {row['chunk_index']}, Chunk Content: '{row['content']}'"

for country in countries:
    formatted_chunks = ''
    relevant_df = complete_embeddings_df[complete_embeddings_df['country'] == country]

    for i in range(len(relevant_df)):
        row = relevant_df.iloc[i]
        formatted_chunk = format_context(row)
        formatted_chunks += formatted_chunk + '\n'
    
    formatted_chunks 

print(formatted_chunks)
# Out:
# Doc ID: andorra_spanish_20250201, Chunk ID: 135, Chunk Content: 'in net greenhouse gas emissions by 2035, compared to'
# Doc ID: andorra_spanish_20250201, Chunk ID: 136, Chunk Content: '2005 levels, with the ambition of achieving carbon neutrality by'
# Doc ID: andorra_spanish_20250201, Chunk ID: 140, Chunk Content: 'target based on a "Business as Usual" (BAU) scenario to an'
# Doc ID: andorra_spanish_20250201, Chunk ID: 134, Chunk Content: 'at COP28. This document establishes a 63% reduction target'

# %% [markdown]
# Below is my process for generating the queries to feed to the LLM through our API key. I ended up experimenting with 3 different system prompts to give to the LLM. Whilst results are removed, I tested each one and ended up using system_prompt_c for the final workflow

# %%
country_message_directory = {}
system_prompt_a = (
    "You are a climate policy expert. Answer the question using ONLY the provided document chunks below. "
    "Your answer must clearly and concisely state the country's 2030 emissions reduction target. "
    "Do not make assumptions or use information not present in the chunks. "
    "Cite sources using [Doc ID: <id>, Chunk ID: <id>]. "
    "Your answer should be specific and clearly state the emissions reduction target by 2030, be concise where possible."
    " If the answer is not clearly stated, respond with: 'The target is not clearly specified in the provided chunks.'"
)

system_prompt_b = (
    "You are a climate policy analyst. Based only on the following document chunks, extract the official 2030 emissions reduction target for the country. "
    "If both unconditional and conditional targets exist, return both clearly. "
    "Include % reduction, baseline year or scenario (e.g. BAU, 1990), and any numerical estimates (e.g. MtCO2e). "
    "Always cite the relevant chunk in the format [Doc ID: <id>, Chunk ID: <id>]. "
    "If a target is not stated, write: 'Target not found in provided chunks.'"
)

system_prompt_c = (
    "You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. "
    "If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). "
    "Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. "
    "If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'"
)

def format_context(row):
    return f"[Doc ID: {row['doc_id']}, Chunk ID: {row['chunk_index']}] \n '{row['content']}'"


# Here I am constructing the dictionary of prompts that I will give to the API indexing by country - note that for each coutry I restrict the number of chunks to 10
for country in countries:
    formatted_chunks = ''
    relevant_df = complete_embeddings_df[complete_embeddings_df['country'] == country]
    query_text = f"What is the official 2030 emissions reduction target for {country}, based on the provided document chunks?"
    
    for i in range(len(relevant_df)):
        if i == 10:
            break
        row = relevant_df.iloc[i]
        formatted_chunk = format_context(row)
        formatted_chunks += formatted_chunk + '\n'
            
    messages = [
        {"role": "system", "content": system_prompt_c},
        {"role": "user", "content": f"Context:\n{formatted_chunks.strip()}\n\nQuestion: {query_text}\n\nAnswer:"}]
    
    for row in messages:
        for key, value in row.items():
            print(f"{key}: {value}")
    
    country_message_directory[country] = messages
    
country_message_directory
# Out:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: bangladesh_english_20220601, Chunk ID: 745]
#  'Total GHG emission will be 409.4 MtCO2e in 2030 under BAU scenario. The contributions of the sectors are;'
# [Doc ID: bangladesh_english_20220601, Chunk ID: 10]
#  'Bangladesh’s INDC proposed for 12 million tons (5%) unconditional reduction in GHG emission from Business as Usual (BAU) scenario by 2030 and a further 24 million tons (10%) conditional reduction in GHG emission with support from the international community taking the base year 2011.'
# [Doc ID: bangladesh_english_20220601, Chunk ID: 92]
#  'Total GHG emission is found to be increased from 169.05 Mt CO2e in 2012 to 409.4 Mt CO2e in 2030 under the Business as Usual (BAU) scenario with an increase of 2.4 times than base year. The following table 2 presents the sector-wise distribution of the GHG emission for the BAU scenario in 2030.'
# [Doc ID: bangladesh_english_20220601, Chunk ID: 588]
#  'Under this comprehensive plan, the government aims to lower energy intensity (national primary energy consumption per unit of GDP) in 2030 by 20% compared to the 2013 level. A total of 95 million toe (113 billion m3 of gas equivalent) is expected to be saved during the period.'
# [Doc ID: bangladesh_english_20220601, Chunk ID: 886]
#  'The updated unconditional and conditional contributions of Bangladesh have increased emission reduction targets target has been substantially. The unconditional increased from 12 MtCO2e to 27.56 MtCO2e below BAU in 2030. The conditional target has been increased from 36 MtCO2e to 89.47 MtCO2e below BAU in 2030.'
# [Doc ID: bangladesh_english_20220601, Chunk ID: 755]
#  'In unconditional scenario, GHG emissions would be reduced by 27.56 Mt CO2e (6.73%) below BAU in 2030 and in conditional scenario, GHG emissions would be reduced by 89.47 Mt CO2e (21.85%) below BAU in 2030 in the respective sectors.'
# [Doc ID: bangladesh_english_20220601, Chunk ID: 517]
#  'in household and commercial buildings (achieve 19% and 25% reduction in emission respectively)'
# [Doc ID: bangladesh_english_20220601, Chunk ID: 377]
#  'in household and commercial buildings (achieve 5% and 12% reduction in emission respectively)'
# [Doc ID: bangladesh_english_20220601, Chunk ID: 740]
#  'Total GHG emission accounts for 169.05 MtCO2e for the Base Year 2012. The contributions of the sectors are;'
# [Doc ID: bangladesh_english_20220601, Chunk ID: 84]
#  'The base year GHG emission scenario for 2012, has been updated with additional information for Fugitive emission from leakages in the gas distribution network, F-gases, gas and electricity use in households. This information was not included in the TNC. So, there is an increase in total emission from 152.27 MtCO2e to 169. 05 MtCO2e.'
#
# Question: What is the official 2030 emissions reduction target for Bangladesh, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: brunei_darussalam_english_20220601, Chunk ID: 16]
#  'Brunei Darussalam is committed to a reduction in GHG emissions by 20% relative to Business-As-Usual levels by 2030.'
# [Doc ID: brunei_darussalam_english_20220601, Chunk ID: 5]
#  'Brunei Darussalam is committed to a reduction in greenhouse gas (GHG) emissions by 20% relative to Business-As-Usual levels by 2030.'
# [Doc ID: brunei_darussalam_english_20220601, Chunk ID: 32]
#  'Economy-wide total GHG emissions reduction relative to BAU levels by 2030. GHG covered: Carbon dioxide (CO2), Methane (CH4) and Nitrous oxide (N2O).'
# [Doc ID: brunei_darussalam_english_20220601, Chunk ID: 17]
#  'Reference indicator will be quantified based on national total GHG emissions in 2015.'
# [Doc ID: brunei_darussalam_english_20220601, Chunk ID: 152]
#  'BNCCP Strategy 5 on Power Management - Reduce GHG emissions by at least 10% through better supply and demand management of electricity consumption by 2035.'
# [Doc ID: brunei_darussalam_english_20220601, Chunk ID: 141]
#  'BNCCP Strategy 3 on Electric Vehicles - Increase total share of electric vehicles (EV) to 60% of the total annual vehicle sales by 2035.'
# [Doc ID: brunei_darussalam_english_20220601, Chunk ID: 144]
#  'BNCCP Strategy 4 on Renewable Energy - Increase total share of renewable energy to at least 30% of total capacity in the power generation mix by 2035.'
#
# Question: What is the official 2030 emissions reduction target for Brunei Darussalam, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: cameroon_french_20220601, Chunk ID: 677]
#  'CO2, soit 12 % des émissions dans le scenario BAU 2030.'
# [Doc ID: cameroon_french_20220601, Chunk ID: 569]
#  'Scénario "with measures" 2030'
#
# Question: What is the official 2030 emissions reduction target for Cameroon, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: viet_nam_english_20221101, Chunk ID: 130]
#  'sectoral development plans for the period 2021-2030 towards the goals of the National Climate Change Strategy to 2050. Specific measures to reduce GHG emissions include:'
# [Doc ID: viet_nam_english_20221101, Chunk ID: 74]
#  'Emission reduction targets in the energy, agriculture, LULUCF, waste and industrial processes by 2030 compared to BAU in NDC 2022 are higher than NDC 2020, Unconditional contribution increased from 9% to 15.8% and Conditional contribution increased from 27% to 43.5%.'
# [Doc ID: viet_nam_english_20221101, Chunk ID: 81]
#  'of increased risks due to climate change under the 2020 climate change scenario.'
# [Doc ID: viet_nam_english_20221101, Chunk ID: 168]
#  'Emissions under the Business-As-Usual scenario (BAU)'
# [Doc ID: viet_nam_english_20221101, Chunk ID: 186]
#  'Compared to BAU scenario'
# [Doc ID: viet_nam_english_20221101, Chunk ID: 189]
#  'Compared to BAU scenario'
# [Doc ID: viet_nam_english_20221101, Chunk ID: 183]
#  'Compared to BAU scenario'
#
# Question: What is the official 2030 emissions reduction target for Viet Nam, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: uganda_english_20220901, Chunk ID: 1756]
#  'The updated NDC highlights a huge progression from 22% to 24.7% reduction in 2030.'
# [Doc ID: uganda_english_20220901, Chunk ID: 1101]
#  'Full implementation of this measure will to emissions reduce potentially approximately 2.9 MtCO2e by 2030.'
# [Doc ID: uganda_english_20220901, Chunk ID: 1152]
#  'The NAMA seeks to contribute to GHG mitigation of 0.5 MtCO2e by 2030.'
# [Doc ID: uganda_english_20220901, Chunk ID: 1601]
#  'Economy wide emissions reduction of 24.7% in 2030 below the BAU conditions. Of which, Uganda’s unconditional efforts will result into reduction of 5.9% in 2030 below the BAU conditions.'
# [Doc ID: uganda_english_20220901, Chunk ID: 1106]
#  'Full implementation of the measure will contribute to a GHG emission reduction of approximately 3.37 MtCO2e by 2030.'
# [Doc ID: uganda_english_20220901, Chunk ID: 1103]
#  'The measure is expected to contribute to a reduction of GHG emissions of about 0.37 MtCO2e by 2030 through woodlots, and/or farm forestry practices.'
# [Doc ID: uganda_english_20220901, Chunk ID: 1053]
#  'If, as a result of inadequate financial, capacity-building and technology transfer support, it is envisaged that Uganda’s unconditional efforts will result into net emissions reductions of 5.9% below the BAU trajectory in 2030.'
# [Doc ID: uganda_english_20220901, Chunk ID: 1674]
#  'Uganda has committed to reduce her economy-wide Greenhouse gas emissions by 24.7% in 2030 below the BAU baseline. 82.7% of the mitigation action will come from the Agriculture, Forestry and Other Land Use AFOLU sector.'
# [Doc ID: uganda_english_20220901, Chunk ID: 1187]
#  'This consists of the following power generation capacity to come online between 2015 and 2030:'
# [Doc ID: uganda_english_20220901, Chunk ID: 1238]
#  'The emissions under the Business-As-Usual scenario in the Energy sector (stationary) will increase from 5.7 MtCO2e in 2015 to about 12.4 MtCO2e in 2030. The main mitigation actions above have a potential to reduce GHG emissions in this sector by 18.8% to 10.1 MtCO2e in 2030 as shown in figure 3-5. The Figure also presents the sector’s annual mitigation targets.'
#
# Question: What is the official 2030 emissions reduction target for Uganda, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: montenegro_english_20220601, Chunk ID: 9]
#  'At least a 35% reduction in total national GHG emissions (excl. LULUCF) by 2030 compared to 1990 (base year).'
# [Doc ID: montenegro_english_20250201, Chunk ID: 40]
#  'Economy-wide net domestic reduction in GHG emissions of at least 55% by 2030 and 60% by 2035, compared to 1990 levels.'
# [Doc ID: montenegro_english_20250201, Chunk ID: 43]
#  '2(b) Whether it is a single-year or multi-year target, as applicable. Multi-year target, 2030 and 2035'
# [Doc ID: montenegro_english_20220601, Chunk ID: 18]
#  '(b) Whether it is a single-year or multi-year target, as applicable Single-year target, namely 2030'
# [Doc ID: montenegro_english_20220601, Chunk ID: 2112]
#  'NDC scenario 2030 19%'
# [Doc ID: montenegro_english_20220601, Chunk ID: 2109]
#  'BAU scenario 2030 32%'
# [Doc ID: montenegro_english_20220601, Chunk ID: 2048]
#  'Annual relative GDP growth: considering moderate growth after 2023'
#
# Question: What is the official 2030 emissions reduction target for Montenegro, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: jordan_english_20220601, Chunk ID: 750]
#  'Jordan sets the target of achieving 31% reduction of emissions by 2030. Which is quantified to be 11269 Gg CO2 eq.'
# [Doc ID: jordan_english_20220601, Chunk ID: 290]
#  'Outcomes of the analysis of the actions resulted in the target of total GHG emission reduction of 31% in 2030 compared to BAU in 2012 (description of actions is in Annex 1)'
# [Doc ID: jordan_english_20220601, Chunk ID: 707]
#  ' The projected emissions under BAU scenario is estimated to 43,989.0 Gg CO2 eq in year 2030.'
# [Doc ID: jordan_english_20220601, Chunk ID: 308]
#  'Increased percentage of electricity generated from renewables1 to have a share of more 35% by the year 2030'
# [Doc ID: jordan_english_20220601, Chunk ID: 297]
#  '2012 2015 2020 2025 2030 *The Estimated Mitigation Target is 31% ** Resulting target was calculated by dividing the accumulative emissions avoided till 2030 by the total emissions in 2030 resulting in the BAU scenario [target% = (accumulative emissions by 2030/BAU-2030 emissions)* 100]'
# [Doc ID: jordan_english_20220601, Chunk ID: 532]
#  '8. Reducing emissions that are under the direct control of the health sector to reach net zero health sector emissions by 2050.'
# [Doc ID: jordan_english_20220601, Chunk ID: 188]
#  'Latest GHG mitigation projections and GHG data updates for the period 2020- 2040 (published in BUR1, 2017).'
# [Doc ID: jordan_english_20220601, Chunk ID: 751]
#  'Jordan committed to reduce 5% compared to the BAU scenario unconditionally, and to reduce conditionally an additional 26% compared to BAU scenario if the resources and means of implementation are available.'
# [Doc ID: jordan_english_20220601, Chunk ID: 718]
#  ' The reduction target (31%)is divided into conditional and unconditional as “percentage of total reduction” as follows: - Conditional target: 26% - Unconditional target: 5%'
# [Doc ID: jordan_english_20220601, Chunk ID: 303]
#  'Figure 1: the GHG trajectory of the proposed mitigation scenarios vs BAU scenario.'
#
# Question: What is the official 2030 emissions reduction target for Jordan, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: cambodia_english_20220601, Chunk ID: 213]
#  'The estimated emissions reduction with the FOLU by 2030 under the NDC scenario will be'
# [Doc ID: cambodia_english_20220601, Chunk ID: 725]
#  'the highest overall BAU emissions in 2030. This would be followed by the agriculture sector'
# [Doc ID: cambodia_english_20220601, Chunk ID: 597]
#  'Figure 3 illustrates the forecast of emissions for each mitigation sector (excluding the FOLU) up to 2030.'
# [Doc ID: cambodia_english_20220601, Chunk ID: 646]
#  'The share of emission contributions of the sectors in 2016 and 2030 are illustrated in Figure'
# [Doc ID: cambodia_english_20220601, Chunk ID: 5168]
#  'The FOLU is to provide the major share of 92% emission reduction by 2030. Other sectors'
# [Doc ID: cambodia_english_20220601, Chunk ID: 160]
#  'In the BAU scenario, overall GHG emissions in 2030 without the FOLU are expected to rise'
# [Doc ID: cambodia_english_20220601, Chunk ID: 5272]
#  'Under the NDC scenario 3, the target emission reduction is 30.2 million tCO2e/year by 2030,'
# [Doc ID: cambodia_english_20220601, Chunk ID: 574]
#  'According to Figure 1, overall GHG emissions in 2030 without the FOLU would rise by up to'
# [Doc ID: cambodia_english_20220601, Chunk ID: 183]
#  'forecasted BAU emissions in 2030. This would be followed by the energy sector with 22.2%,'
# [Doc ID: cambodia_english_20220601, Chunk ID: 5246]
#  'Figure 18: GHG emission reduction under NDC scenario 3 in 2030'
#
# Question: What is the official 2030 emissions reduction target for Cambodia, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: papua_new_guinea_english_20220601, Chunk ID: 27]
#  'Energy Industries: Within the Energy Industries PNG is committing to a headline target of carbon neutrality within the energy industries sub-sector by 2030.'
# [Doc ID: papua_new_guinea_english_20220601, Chunk ID: 46]
#  'PNG’s annual GHG emissions and removals between 2001 and 2015, the future emissions prediction under the business as usual scenario and an illustrative pathway to the NDC target for the LULUCF sub-sector.'
# [Doc ID: papua_new_guinea_english_20220601, Chunk ID: 40]
#  'It should be noted that the LULUCF sector in PNG makes up significantly higher levels of emissions (13,574.04 Gg CO2 eq in 2015) but these are offset by removals within PNG’s current approach to reporting leaving a relatively small net emission of 1,716.46 Gg CO2 eq.'
# [Doc ID: papua_new_guinea_english_20220601, Chunk ID: 31]
#  'Enhancing levels of renewables in the energy mix – through increasing from 30% (2015) to 78% the level of installed capacity for on grid electricity generation that is produced by renewables9.'
#
# Question: What is the official 2030 emissions reduction target for Papua New Guinea, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: singapore_english_20221101, Chunk ID: 26]
#  'Singapore’s NDC is an economy-wide absolute GHG emissions limitation target to reduce its GHG emissions to around 60 MtCO2e in 2030 after peaking emissions earlier.'
# [Doc ID: singapore_english_20221101, Chunk ID: 7]
#  'Singapore’s 2030 emissions will be demonstrated in the national greenhouse gas (GHG) inventory time series reported in its Biennial Transparency Reports.'
# [Doc ID: singapore_english_20221101, Chunk ID: 1]
#  'Singapore intends to reduce emissions to around 60 million tonnes of carbon dioxide equivalent (MtCO2e) in 2030 after peaking its emissions earlier1'
# [Doc ID: singapore_english_20250201, Chunk ID: 94]
#  'around 1.35 GWp3. We are on track to achieve at least 2 GWp by 2030, which would meet around 3% of Singapore’s total projected electricity needs then.'
# [Doc ID: singapore_english_20250201, Chunk ID: 22]
#  'Not applicable. Singapore’s 2nd NDC target, which aims to reduce emissions to an absolute emissions level, does not take reference from any baseline.'
# [Doc ID: singapore_english_20221101, Chunk ID: 17]
#  'Not applicable. Singapore’s NDC target, which aims to peak and subsequently reduce emissions to an absolute emissions level, does not take reference from any baseline.'
# [Doc ID: singapore_english_20250201, Chunk ID: 21]
#  'Not applicable. Singapore’s 2nd NDC is an economy-wide absolute GHG emissions reduction target.'
# [Doc ID: singapore_english_20250201, Chunk ID: 19]
#  'Not applicable. Singapore’s 2nd NDC is an economy-wide absolute GHG emissions reduction target.'
# [Doc ID: singapore_english_20250201, Chunk ID: 221]
#  'Singapore’s 2nd NDC is an economy-wide absolute GHG emissions reduction target.'
# [Doc ID: singapore_english_20250201, Chunk ID: 36]
#  'Singapore’s 2nd NDC is an economy-wide absolute GHG emissions reduction target.'
#
# Question: What is the official 2030 emissions reduction target for Singapore, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: sri_lanka_english_20220601, Chunk ID: 155]
#  'Key interventions envisaged for GHG emissions reduction up to the year 2030:'
# [Doc ID: sri_lanka_english_20220601, Chunk ID: 85]
#  ' To achieve 70% renewable energy in electricity generation by 2030  To achieve Carbon Neutrality by 2050 in electricity generation  No capacity addition of Coal power plants'
# [Doc ID: sri_lanka_english_20220601, Chunk ID: 929]
#  'BAU emissions scenario and potential GHG emission reduction pathways for some mitigation'
# [Doc ID: sri_lanka_english_20220601, Chunk ID: 104]
#  'Sri Lanka has an impressive track record of tackling poverty. The overall poverty rate is 4.1%5 showing commendable progress from 20 years ago (28.8% in 2000). However, there is wide disparity in poverty'
# [Doc ID: sri_lanka_english_20220601, Chunk ID: 82]
#  'Sri Lanka’s per capita greenhouse gas emission in 2010 was 1.02 tons and its global cumulative contribution in 2019 was 0.03%.'
# [Doc ID: sri_lanka_english_20220601, Chunk ID: 404]
#  'by improving animal comfort and welfare (40% increase of milk yield per cattle by 2030 on unconditional basis and further increase up to 55% on conditional basis. Increase productive milking cow percentage of the herd up to 40% on conditional basis)'
#
# Question: What is the official 2030 emissions reduction target for Sri Lanka, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 161]
#  'The following are recommended in addition to the mitigation target indicator by 2030:'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 98]
#  'Uzbekistan is a resource-rich developing economy with a stable annual GDP growth of over 5%. The country has about 35 million population. According to UN estimates, the country's population will reach 37 million by 2030.'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 194]
#  'The commitment period is from January 1, 2020 to December 31, 2030.'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 201]
#  'The goal is consistent with a relative reduction in specific greenhouse gas emissions per GDP across the economy compared to the baseline year emissions.'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 152]
#  'The noted difference in total GHG emissions estimates between NDC1 and NDC2 is due to:'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 338]
#  '"Energy" sector makes the greatest contribution to total GHG emissions (76.3%).'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 544]
#  'Five largest categories, whose contribution to total GHG emissions made up around 63%:'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 683]
#  '− reduce pollutant emissions by 10% (from 2.5 million to 2.2 million tons);'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 120]
#  '− achieve Land Degradation Neutrality; − increase the average productivity of basic agricultural products by 20-25%.'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 335]
#  'Uzbekistan’s contribution to global emissions stands at around 0.3%.'
#
# Question: What is the official 2030 emissions reduction target for Uzbekistan, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: finland_english_20231001, Chunk ID: 108]
#  'emissions reduction target of 40% by 2030 compared to 2005.'
# [Doc ID: finland_english_20231001, Chunk ID: 102]
#  'allocation and to contribute to 42% emission reductions by 2030 compared to'
# [Doc ID: finland_english_20231001, Chunk ID: 19]
#  'greenhouse gas emissions by 2030, compared to 1990 levels.'
# [Doc ID: finland_english_20231001, Chunk ID: 42]
#  '55% by 2030 compared to 1990, setting it as a legally binding target.'
# [Doc ID: finland_english_20231001, Chunk ID: 123]
#  'level by 11.7% in 2030 and a new target for increasing renewable energy in final'
# [Doc ID: finland_english_20231001, Chunk ID: 339]
#  'The EU’s at least 55% net reduction target by 2030 is to be achieved through domestic measures only, without contribution from international credits.'
# [Doc ID: finland_english_20231001, Chunk ID: 35]
#  'emissions by 2030 compared to 1990” and submitted it to the UNFCCC'
# [Doc ID: finland_english_20231001, Chunk ID: 180]
#  'of support from 2020 to 2030 (calculated at EUR 75 / tCO2), depending on the'
# [Doc ID: finland_english_20231001, Chunk ID: 116]
#  'CO2 emissions for new cars and 50% for new vans from 2030 until 2034, and'
# [Doc ID: finland_english_20231001, Chunk ID: 124]
#  'energy consumption of at least 42.5% by 2030, with an additional 2.5% indicative'
#
# Question: What is the official 2030 emissions reduction target for Finland, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: united_kingdom_of_great_britain_and_northern_ireland_english_20220901, Chunk ID: 60]
#  'An at least 68% economy-wide net reduction in GHG emissions by 2030 compared to reference year levels.'
# [Doc ID: united_kingdom_of_great_britain_and_northern_ireland_english_20220901, Chunk ID: 395]
#  'Based on latest estimates, the UK’s NDC suggests that emissions per person in 2030 would be below 4tCO2e, which is of a comparable level (3.5-4 tCO2e) to estimates for the global'
# [Doc ID: united_kingdom_of_great_britain_and_northern_ireland_english_20250101, Chunk ID: 123]
#  'Gibraltar’s Climate Change Act (2019)28 sets legally binding carbon emissions reduction targets against a 1990 baseline of 42% by 2030 and 100% by 2045. Gibraltar is looking to set a 2035 interim target.'
# [Doc ID: united_kingdom_of_great_britain_and_northern_ireland_english_20220901, Chunk ID: 22]
#  'Clarifying how the UK’s target - which remains a commitment to reduce economy-wide greenhouse gas emissions by at least 68% by 2030 on 1990 levels - aligns with the Paris Agreement temperature goal;'
# [Doc ID: united_kingdom_of_great_britain_and_northern_ireland_english_20220901, Chunk ID: 384]
#  'In its NDC the UK commits to reducing economy-wide greenhouse gas emissions by at least 68% by 2030 compared to 1990 levels. This requires the fastest rate of reduction in greenhouse gases between 1990 and 2030 of all major economies. It remains a fair and ambitious contribution to global action on climate change.'
# [Doc ID: united_kingdom_of_great_britain_and_northern_ireland_english_20220901, Chunk ID: 148]
#  'Committed to ending the sale of new petrol and diesel vehicles by 2030, and for all'
# [Doc ID: united_kingdom_of_great_britain_and_northern_ireland_english_20250101, Chunk ID: 175]
#  'global energy storage to 1500GW and expanding or upgrading 25 million kilometers of grids by 2030 – critical for decarbonising the power sector and building on the agreement at COP28 to triple renewables by 2030.'
# [Doc ID: united_kingdom_of_great_britain_and_northern_ireland_english_20220901, Chunk ID: 45]
#  'The reference indicator (MtCO2e) in the reference years (1990 and 1995) will be based on the 1990-2030 UK GHG Inventory submitted to the UNFCCC in 2032. The value for the target year (2030) will be based on applying a 68% fixed percentage reduction target to the reference indicator value.'
# [Doc ID: united_kingdom_of_great_britain_and_northern_ireland_english_20220901, Chunk ID: 116]
#  'Carbon Budget 3 (2026-30): 58% average reduction • 2030: 63% reduction • 2040: 89% reduction • 2050: at least 100% reduction (net zero)'
# [Doc ID: united_kingdom_of_great_britain_and_northern_ireland_english_20250101, Chunk ID: 46]
#  'The target year level is an at least 81% reduction in total net GHG emissions and removals in 2035 compared to the base year.'
#
# Question: What is the official 2030 emissions reduction target for United Kingdom of Great Britain and Northern Ireland, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: albania_english_20220801, Chunk ID: 235]
#  'Figure 9. Emission reductions between the NDC and BAU scenarios by sector, in 2030'
# [Doc ID: albania_english_20220801, Chunk ID: 2691]
#  'Target (NDC) Fuelwood consumption decreases by 4% between 2016 and 2030'
# [Doc ID: albania_english_20220801, Chunk ID: 237]
#  'Table 1. Summary of the mitigation reduction in 2030 (NDC compared to BAU scenario)'
# [Doc ID: albania_english_20220801, Chunk ID: 1838]
#  'Albania aims to reduce emissions relative to business-as-usual by 2030, with the implementation of mitigation actions in the main emitting'
# [Doc ID: albania_english_20220801, Chunk ID: 2084]
#  'Energy consumption is expected to decrease by 19% in 2030 between the NDC and BAUs scenarios, Natural gas being introduced in 2026 to reach 30% of total fuel consumption in 2030.'
# [Doc ID: albania_english_20220801, Chunk ID: 1826]
#  'National inventory GHG emissions from the 1st BUR draft and the 4th National Communication were used to estimate the starting point (2016) and to projected emissions up to 2030.'
# [Doc ID: albania_english_20220801, Chunk ID: 229]
#  'Considering all sectors (including FOLU), emissions for the NDC scenario (with mitigation measures) increase from 10,139 kt CO2e in 2016 to 11,978 kt CO2e in 2030, which represents'
# [Doc ID: albania_english_20220801, Chunk ID: 1989]
#  'Albania’s updated NDC represents an enhancement of the first NDC, as the scope includes more sectors and gases, and the mitigation target in 2030 is more ambitious (from 11.5% to 20.9%).'
# [Doc ID: albania_english_20220801, Chunk ID: 1824]
#  'The difference, in 2030, with the BAU scenario, is -3,170 kt CO2e below BAU in 2030, which represents a mitigation impact of -20.9%.'
# [Doc ID: albania_english_20220801, Chunk ID: 2241]
#  'Amounts for the period 2021 and 2029 are estimated by linear interpolation based on calculated 2030 value.'
#
# Question: What is the official 2030 emissions reduction target for Albania, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: grenada_english_20220601, Chunk ID: 27]
#  'Grenada commits to reducing its GHG emissions by 40% of the 2010 emissions levels by 2030.'
# [Doc ID: grenada_english_20220601, Chunk ID: 47]
#  'Grenada’s economy wide target to reduce emissions by 40% by 2030 covers the energy, forestry, waste and IPPU sectors. The inclusion of F-gases is a new addition to Grenada’s second NDC.'
# [Doc ID: grenada_english_20220601, Chunk ID: 13]
#  'access to appropriate technologies. The indicative cost for Grenada’s identified NDC mitigation measures through 2030 is between $984.9 and $1,054.5 Million USD.'
# [Doc ID: grenada_english_20220601, Chunk ID: 178]
#  'This special report shows pathways that limit global warming to 1.5°C with no or limited overshoot. Pathways that describe a 40-50 % reduction in net anthropogenic GHG emissions by 2030 compared to 2010 levels, and net anthropogenic CO2 emissions reaching net zero around 2050.'
# [Doc ID: grenada_english_20220601, Chunk ID: 164]
#  'The baseline GHG emissions for all sectors were calculated using 2006 IPCC guidelines.'
# [Doc ID: grenada_english_20220601, Chunk ID: 179]
#  'Grenada’s NDC is in line with the emissions pathways towards 2050 and onwards that correspond to keeping global warming in line with the global long- term goal of the Paris Agreement.'
# [Doc ID: grenada_english_20220601, Chunk ID: 26]
#  '(d) Target relative to the reference indicator, expressed numerically, for example in percentage or amount of reduction'
# [Doc ID: grenada_english_20220601, Chunk ID: 141]
#  'Grenada’s emissions for CO2, CH4, and the F-gases were derived using the Tier 1 method of the 2006 IPCC guidelines.'
# [Doc ID: grenada_english_20220601, Chunk ID: 144]
#  'Waste Sector: GHG emissions were estimated by using IPCC waste model (IPCC 2006 guidelines).'
# [Doc ID: grenada_english_20220601, Chunk ID: 23]
#  'Grenada’s net Greenhouse Gas (GHG) emissions in 2010 were estimated to be 216.9 GgCO2e.'
#
# Question: What is the official 2030 emissions reduction target for Grenada, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: ukraine_english_20220601, Chunk ID: 30]
#  'Economy-wide net domestic reduction of 65 % in GHG emissions by 2030 compared to 1990.'
# [Doc ID: ukraine_english_20220601, Chunk ID: 52]
#  'Ukrainian NDC target corresponds to an economy- wide absolute GHG reduction of 65 % by 2030, compared to 1990 GHG emissions level.'
# [Doc ID: ukraine_english_20220601, Chunk ID: 298]
#  'Ukraine’s NDC is consistent with a trajectory to achieve net zero GHG emissions not later than 2060.'
# [Doc ID: ukraine_english_20220601, Chunk ID: 261]
#  'target of 65% emissions reduction The NDC economy-wide, is achievable for all sectors of the economy under the following conditions:'
# [Doc ID: ukraine_english_20220601, Chunk ID: 178]
#  'Global warming potential (GWP) values relative to CO2 values from the IPCC Fourth Assessment Report are used.'
# [Doc ID: ukraine_english_20220601, Chunk ID: 27]
#  'the Target reference indicator, expressed numerically, for example in percentage or amount of reduction'
# [Doc ID: ukraine_english_20220601, Chunk ID: 95]
#  'Ukraine has substantially reduced GHG emissions since 1990 due to transformations that did not lead to steady economic growth. The total amount of GHG emissions in Ukraine in 2019 amounted to 332.2 Mt CO2 equivalent (including LULUCF) that is 37.6 % of the 1990 level.'
# [Doc ID: ukraine_english_20220601, Chunk ID: 51]
#  'Single year target, 2030.'
# [Doc ID: ukraine_english_20220601, Chunk ID: 129]
#  'National Economic Strategy until 2030.'
# [Doc ID: ukraine_english_20220601, Chunk ID: 277]
#  'achieve the NDC’s target is 102 billion euro.'
#
# Question: What is the official 2030 emissions reduction target for Ukraine, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: saudi_arabia_english_20211023, Chunk ID: 136]
#  'As a developing country with limited sources economy and historically low GHG emission contribution, the Kingdom considers its 2030 ambition as fair, given that the sum of the contributions leads to a significant deviation from a business-as-usual scenario emission.'
# [Doc ID: saudi_arabia_english_20211023, Chunk ID: 87]
#  'ports which will result in reductions in traffic and GHG emissions. Approved methodologies will be used to estimate avoided GHG emissions.'
# [Doc ID: saudi_arabia_english_20211023, Chunk ID: 26]
#  'Two scenarios for determining dynamic baselines for the period 2020–2030:'
#
# Question: What is the official 2030 emissions reduction target for Saudi Arabia, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: sao_tome_and_principe_english_20220601, Chunk ID: 37]
#  'The type of contribution chosen by Sao tome and Principe is based on estimated results for the reduction of GHG emissions below BAU levels by 2030.'
# [Doc ID: sao_tome_and_principe_english_20220601, Chunk ID: 66]
#  'The timeframe for the implementation is from 2020 to 2030, with specific mitigation results to be reached by 2030.'
# [Doc ID: sao_tome_and_principe_english_20220601, Chunk ID: 36]
#  'It is understood that there is no base year and that the results will be compared to BAU scenarios, by 2030, effected on the basis of the last GHG inventory of 2012.'
# [Doc ID: sao_tome_and_principe_english_20220601, Chunk ID: 38]
#  'In 2012, these emissions stood at approx. 154 GgCO2eq, while BAU projections indicate that by 2030 these emissions could reach 400 ktCO2eq, maintained the projected growth parametres adopted.'
# [Doc ID: sao_tome_and_principe_english_20220601, Chunk ID: 48]
#  '27% of emissions reduction by 2030, considering the results of the national GHG emissions inventory - excluding the LULUCF sector which has historically, since the first GHG emissions inventory, generated removals greater than total GHG emissions. Hence making STP a climate neutral country since 1998 that does not contribute to global warming.'
# [Doc ID: sao_tome_and_principe_english_20220601, Chunk ID: 20]
#  'With the implementation of these measures, STP will be able to contribute towards an estimated GHG emissions reduction of 109 kTCO2eq, corresponding to a 27% emission reduction by 2030, with a total estimated cost of close to USD 150M.'
# [Doc ID: sao_tome_and_principe_english_20220601, Chunk ID: 47]
#  'By implementing these measures, STP will be able to contribute toward reducing GHG emissions by close to 109 GgCO2eq, corresponding to about 27% of emissions reduction by 2030. Sao Tome and Principe reserves the right to apply this paragraph in future to adjust the information contained in paragraph 1b) above.'
# [Doc ID: sao_tome_and_principe_english_20220601, Chunk ID: 67]
#  'Goal is for a single year: 2030'
# [Doc ID: sao_tome_and_principe_english_20220601, Chunk ID: 62]
#  '4.5% from 2012 to 2030'
# [Doc ID: sao_tome_and_principe_english_20220601, Chunk ID: 58]
#  '2% from 2012 to 2030'
#
# Question: What is the official 2030 emissions reduction target for Sao Tome and Principe, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: cuba_english_20220601, Chunk ID: 59]
#  'the It that the contribution will avoid thousand emission of 700 ktCO2eq. into the atmosphere in the period 2014 – 2030.'
# [Doc ID: cuba_english_20220601, Chunk ID: 54]
#  '24% of electricity generation based on renewable energy sources by the year 2030. It that the the contribution will avoid emission of 30.6 million ktCO2eq. into the atmosphere in the period 2014 – 2030.'
# [Doc ID: cuba_english_20220601, Chunk ID: 74]
#  'Treatment of 100% of waste waters in the Cuban swine sector, reducing 8 million emissions in ktCO2eq. annually in the period of 2020- 2030.'
# [Doc ID: cuba_english_20220601, Chunk ID: 70]
#  'Increasing forest coverage by 165 000ha in the period 2019- 2030. Removing 169,9 million tons of atmospheric CO2 in the period 2019-2030.'
# [Doc ID: cuba_english_20220601, Chunk ID: 50]
#  'to 24% of Increase electricity generation based on Renewable Energy Sources (RES) in the Cuban electricity matrix by 2030.'
# [Doc ID: cuba_english_20220601, Chunk ID: 66]
#  'forest Increase coverage in the country to 33% by 2030'
#
# Question: What is the official 2030 emissions reduction target for Cuba, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: kyrgyzstan_english_20220601, Chunk ID: 203]
#  'n 2030, GHG emissions will be reduced by 15.97% of the GHG emission level under the BAU scenario, and by 43.62% subject to international support.'
# [Doc ID: kyrgyzstan_english_20220601, Chunk ID: 631]
#  'Target indicators, 1000 tons of CO2 eq. 2025 2030 Considered in Considered in the indicators the indicators of the Energy of the Energy sector sector'
# [Doc ID: kyrgyzstan_english_20220601, Chunk ID: 202]
#  'In 2025, GHG emissions will be reduced by 16.63% on the GHG emission level under the BAU scenario, and by 36.61% subject to international support.'
# [Doc ID: kyrgyzstan_english_20220601, Chunk ID: 713]
#  'the projection of sectoral emissions under the BAU scenario (see the table below):'
# [Doc ID: kyrgyzstan_english_20220601, Chunk ID: 329]
#  'GHG emissions projections under three scenarios until 2050, 1000 t CO2 eq.'
# [Doc ID: kyrgyzstan_english_20220601, Chunk ID: 694]
#  'The total GHG emission reductions under the “With measures” scenario until 2050 are'
# [Doc ID: kyrgyzstan_english_20220601, Chunk ID: 712]
#  'The indicated GHG emission reductions will reduce the emissions of the sector relative to'
# [Doc ID: kyrgyzstan_english_20220601, Chunk ID: 613]
#  'The indicated CO2 reduction will reduce the GHG emissions of the sector in relation to the'
# [Doc ID: kyrgyzstan_english_20220601, Chunk ID: 590]
#  'СО2 eq.) For scenarios and time periods up to 2050 are presented in the table below. With measures'
# [Doc ID: kyrgyzstan_english_20220601, Chunk ID: 622]
#  'The dynamics of GHG emissions from the tnergy sector until 2050 under three scenarios'
#
# Question: What is the official 2030 emissions reduction target for Kyrgyzstan, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: algeria_english_20220601, Chunk ID: 51]
#  'Reduction of greenhouse gases emissions by 7% to 22%, by 2030, compared to a business as usual -BAU- scenario, conditional on external support in terms of finance, technology development and transfer, and capacity building. The 7% GHG reduction will be achieved with national means.'
# [Doc ID: algeria_english_20220601, Chunk ID: 53]
#  'Type of INDC: Relative reduction compared to Business as usual (BAU) scenario.'
# [Doc ID: algeria_english_20220601, Chunk ID: 71]
# ...
#  'South Africa': [{'role': 'system',
#    'content': "You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'"},
#   {'role': 'user',
#    'content': "Context:\n[Doc ID: south_africa_english_20220601, Chunk ID: 2519] \n 'South Africa’s annual GHG emissions will be in a range from 350-420 Mt CO2-eq.'\n[Doc ID: south_africa_english_20220601, Chunk ID: 2516] \n 'South Africa’s annual GHG emissions will be in a range from 398-510 Mt CO2-eq.'\n[Doc ID: south_africa_english_20220601, Chunk ID: 21] \n '4 (c) Mitigation targets for 2025 and 2030 .................................................................................................................. 15'\n\nQuestion: What is the official 2030 emissions reduction target for South Africa, based on the provided document chunks?\n\nAnswer:"}],
#  'Central African Republic': [{'role': 'system',
#    'content': "You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'"},
#   {'role': 'user',
#    'content': "Context:\n[Doc ID: central_african_republic_french_20220601, Chunk ID: 837] \n 'GPL : 10% en 2030'\n[Doc ID: central_african_republic_french_20220601, Chunk ID: 348] \n '10 MW en 2030'\n[Doc ID: central_african_republic_french_20220601, Chunk ID: 353] \n '40 MWc en 2030'\n[Doc ID: central_african_republic_french_20220601, Chunk ID: 350] \n '60 MW en 2030'\n[Doc ID: central_african_republic_french_20220601, Chunk ID: 286] \n 'Figure 7: Emissions de GES du scenario BAU (2010-2030)'\n\nQuestion: What is the official 2030 emissions reduction target for Central African Republic, based on the provided document chunks?\n\nAnswer:"}],
#  'Mauritania': [{'role': 'system',
#    'content': "You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'"},
#   {'role': 'user',
#    'content': "Context:\n[Doc ID: mauritania_french_20220601, Chunk ID: 1387] \n 'Objectifs l’horizon 2030'\n[Doc ID: mauritania_french_20220601, Chunk ID: 1444] \n 'Objectifs l’horizon 2030'\n[Doc ID: mauritania_french_20220601, Chunk ID: 1313] \n 'Objectifs l’horizon 2030'\n[Doc ID: mauritania_french_20220601, Chunk ID: 1352] \n 'Objectifs l’horizon 2030'\n[Doc ID: mauritania_french_20220601, Chunk ID: 1369] \n 'Objectifs l’horizon 2030'\n[Doc ID: mauritania_french_20220601, Chunk ID: 440] \n 'Période d’engagement : 2021 – 2030'\n\nQuestion: What is the official 2030 emissions reduction target for Mauritania, based on the provided document chunks?\n\nAnswer:"}],
#  'Mozambique': [{'role': 'system',
#    'content': "You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'"},
#   {'role': 'user',
#    'content': "Context:\n[Doc ID: mozambique_english_20220601, Chunk ID: 343] \n 'lion tCO2eq between 2020 and 2025 (see graph below). These reductions are estimates with a significant level'\n[Doc ID: mozambique_english_20220601, Chunk ID: 1013] \n 'by about 40 MtCO2eq between 2020 and 2025. The country expects to reduce these emissions in comparison to the BAU of the specific actions and, should Mozambique benefit'\n[Doc ID: mozambique_english_20220601, Chunk ID: 362] \n 'effort of about 1.2 tCO2 eq per capita by 2025, a very rel- evant figure when compared to Mozambique's total GHG'\n[Doc ID: mozambique_english_20220601, Chunk ID: 944] \n 'Mozambique developed the BAU scenario based on the sum of mitigation actions for the period 2020 to 2025, proposing expectations for annual emission reductions.'\n[Doc ID: mozambique_english_20220601, Chunk ID: 1012] \n 'The emission reduction target presented by Mozambique is divided into cumulative annual efforts between the years 2020 and 2025, whereby the country commits to reduce its emissions'\n[Doc ID: mozambique_english_20220601, Chunk ID: 940] \n 'It is understood that there is no base year and that the results will be compared with the BAU emissions scenarios of the implemented measures, considering two years to reach the target one'\n[Doc ID: mozambique_english_20220601, Chunk ID: 1499] \n 'emissions scenarios for mitigation pathways to achieve temperature rise of up to 1,5oC e 2oC10.'\n[Doc ID: mozambique_english_20220601, Chunk ID: 1155] \n 'rural electrification, which is estimated to average 120 000 new connections per year over the last 15 years (MTA, 2021).'\n[Doc ID: mozambique_english_20220601, Chunk ID: 376] \n '6 tCO2eq and 7 tCO2 eq when accounting for total GHG emissions per capita with LULUCF. Figure 03 below, graph-'\n[Doc ID: mozambique_english_20220601, Chunk ID: 999] \n 'The reference period for operationalization is from 2020 to 2025, so the mitigation results should be achieved by the year 2025.'\n\nQuestion: What is the official 2030 emissions reduction target for Mozambique, based on the provided document chunks?\n\nAnswer:"}],
#  'Brazil': [{'role': 'system',
#    'content': "You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'"},
#   {'role': 'user',
#    'content': "Context:\n[Doc ID: brazil_english_20241101, Chunk ID: 79] \n 'greenhouse gas emissions target for 2035 was based on an integrated modeling exercise'\n[Doc ID: brazil_english_20241101, Chunk ID: 464] \n 'regarding measuring the progress of subsequent NDCs in relation to this NDC, the base level of 59 percent below 2005 levels by 2035 or 1.05 GtCO2e should be taken as a reference.'\n[Doc ID: brazil_english_20241101, Chunk ID: 467] \n 'entire economy since its iNDC in 2015. Brazil also has a climate neutrality target by 2050.'\n[Doc ID: brazil_english_20241101, Chunk ID: 419] \n '(GTP), an accurate metric for assessing the contribution of different gases to climate change.'\n[Doc ID: brazil_english_20241101, Chunk ID: 263] \n 'Single-year targets in 2035.'\n\nQuestion: What is the official 2030 emissions reduction target for Brazil, based on the provided document chunks?\n\nAnswer:"}],
#  'Niger': [{'role': 'system',
#    'content': "You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'"},
#   {'role': 'user',
#    'content': "Context:\n[Doc ID: niger_french_20220601, Chunk ID: 301] \n 'Réductions Conditionnelles : 48% (BAU-2025) et 45% (BAU-2030).'\n[Doc ID: niger_french_20220601, Chunk ID: 298] \n 'Réductions Inconditionnelles : 4,50% (BAU 2025) et 12,57% (BAU 2030).'\n[Doc ID: niger_french_20220601, Chunk ID: 299] \n 'Réductions Conditionnelles : 14,60% (BAU-2025) et 22,75% (BAU'\n\nQuestion: What is the official 2030 emissions reduction target for Niger, based on the provided document chunks?\n\nAnswer:"}],
#  'Nicaragua': [{'role': 'system',
#    'content': "You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'"},
#   {'role': 'user',
#    'content': "Context:\n[Doc ID: nicaragua_spanish_20220601, Chunk ID: 397] \n 'en futuras NDC (2025 – 2030)'\n\nQuestion: What is the official 2030 emissions reduction target for Nicaragua, based on the provided document chunks?\n\nAnswer:"}],
#  'Mexico': [{'role': 'system',
#    'content': "You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'"},
#   {'role': 'user',
#    'content': "Context:\n[Doc ID: mexico_spanish_20221101, Chunk ID: 246] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 214] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 272] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 292] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 318] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 338] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 129] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 399] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 361] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 373] \n 'Actualización 2022 - 2030'\n\nQuestion: What is the official 2030 emissions reduction target for Mexico, based on the provided document chunks?\n\nAnswer:"}],
#  'Guyana': [{'role': 'system',
#    'content': "You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'"},
#   {'role': 'user',
#    'content': "Context:\n[Doc ID: guyana_english_20220601, Chunk ID: 67] \n 'This will result in a reduction of the annual emissions from the timber industry from 3.5M tCO2 to 2.3M tCO2, a 20% reduction from historic levels for this driver, and an 11% reduction in the overall historic level.'\n[Doc ID: guyana_english_20220601, Chunk ID: 61] \n 'In summary, avoided emissions contributions resulting from reforms in the timber and mining industries can contribute up to 48.7 MtCO2e to the global mitigation effort through the implementation of the Emission Reduction Programme described in greater detail below.'\n\nQuestion: What is the official 2030 emissions reduction target for Guyana, based on the provided document chunks?\n\nAnswer:"}],
#  'Republic of Moldova': [{'role': 'system',
#    'content': "You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'"},
#   {'role': 'user',
#    'content': "Context:\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 27] \n 'Absolute reduction as compared to base year emissions.'\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 4] \n 'a) holding the increase in the global average temperature to well below 2°C above pre-industrial levels'\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 119] \n 'In comparison with the 1990-year levels, by 2016 the Republic of Moldova's GHG total and net emissions were 67.5 per cent, respectively 68.5 per cent below (see Figure 2.2-2).'\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 1242] \n 'Lost heat production due to the current water supply deficit on Dniester River is estimated at US$ 4.6 million per year, based on the current import price and the assumption that energy production is affected proportionally by the water supply shortage.'\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 5] \n 'and pursuing efforts to limit the increase to 1.5 °C; and'\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 43] \n 'Single year target established for 2030'\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 30] \n 'Target relative to the reference indicator'\n\nQuestion: What is the official 2030 emissions reduction target for Republic of Moldova, based on the provided document chunks?\n\nAnswer:"}],
#  'Andorra': [{'role': 'system',
#    'content': "You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'"},
#   {'role': 'user',
#    'content': 'Context:\n[Doc ID: andorra_spanish_20250201, Chunk ID: 135] \n \'in net greenhouse gas emissions by 2035, compared to\'\n[Doc ID: andorra_spanish_20250201, Chunk ID: 136] \n \'2005 levels, with the ambition of achieving carbon neutrality by\'\n[Doc ID: andorra_spanish_20250201, Chunk ID: 140] \n \'target based on a "Business as Usual" (BAU) scenario to an\'\n[Doc ID: andorra_spanish_20250201, Chunk ID: 134] \n \'at COP28. This document establishes a 63% reduction target\'\n\nQuestion: What is the official 2030 emissions reduction target for Andorra, based on the provided document chunks?\n\nAnswer:'}]}

# %%
from dotenv import load_dotenv
from openai import OpenAI
import os
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("roberta-base")
load_dotenv()  # Load from .env

api_key = os.getenv("NEBIUS_API_KEY")
llm_model = os.getenv("LLM_MODEL")

client = OpenAI(
    base_url="https://api.studio.nebius.com/v1/",
    api_key=api_key
)

llm_responses = {}
for country, message in country_message_directory.items():
    print(f"Processing country: {country}")
    flattened_text = "".join([m["content"] for m in message])
    tokenized = tokenizer(flattened_text, return_tensors="pt", truncation = True)
    num_tokens = len(tokenized["input_ids"][0])
    
    print(f"[{country}] Token count: {num_tokens}")
    response = client.chat.completions.create(
        model=llm_model,
        max_tokens=1024,
        temperature=0.6,
        top_p=0.9,
        extra_body={
            "top_k": 50
        },
        messages=message
    )
    print(f"API response returned for: {country}")

    llm_responses[country] = response.choices[0].message.content
# Out:
# Processing country: Bangladesh
# [Bangladesh] Token count: 512
# API response returned for: Bangladesh
# Processing country: Brunei Darussalam
# [Brunei Darussalam] Token count: 512
# API response returned for: Brunei Darussalam
# Processing country: Cameroon
# [Cameroon] Token count: 221
# API response returned for: Cameroon
# Processing country: Viet Nam
# [Viet Nam] Token count: 469
# API response returned for: Viet Nam
# Processing country: Uganda
# [Uganda] Token count: 512
# API response returned for: Uganda
# Processing country: Montenegro
# [Montenegro] Token count: 458
# API response returned for: Montenegro
# Processing country: Jordan
# [Jordan] Token count: 512
# API response returned for: Jordan
# Processing country: Cambodia
# [Cambodia] Token count: 512
# API response returned for: Cambodia
# Processing country: Papua New Guinea
# [Papua New Guinea] Token count: 441
# API response returned for: Papua New Guinea
# Processing country: Singapore
# [Singapore] Token count: 512
# API response returned for: Singapore
# Processing country: Sri Lanka
# [Sri Lanka] Token count: 496
# API response returned for: Sri Lanka
# Processing country: Uzbekistan
# [Uzbekistan] Token count: 512
# API response returned for: Uzbekistan
# Processing country: Finland
# [Finland] Token count: 512
# API response returned for: Finland
# Processing country: United Kingdom of Great Britain and Northern Ireland
# [United Kingdom of Great Britain and Northern Ireland] Token count: 512
# API response returned for: United Kingdom of Great Britain and Northern Ireland
# Processing country: Albania
# [Albania] Token count: 512
# API response returned for: Albania
# Processing country: Grenada
# [Grenada] Token count: 512
# API response returned for: Grenada
# Processing country: Ukraine
# [Ukraine] Token count: 512
# API response returned for: Ukraine
# Processing country: Saudi Arabia
# [Saudi Arabia] Token count: 318
# API response returned for: Saudi Arabia
# Processing country: Sao Tome and Principe
# [Sao Tome and Principe] Token count: 512
# API response returned for: Sao Tome and Principe
# Processing country: Cuba
# [Cuba] Token count: 458
# API response returned for: Cuba
# Processing country: Kyrgyzstan
# [Kyrgyzstan] Token count: 512
# API response returned for: Kyrgyzstan
# Processing country: Algeria
# [Algeria] Token count: 325
# API response returned for: Algeria
# Processing country: Maldives
# [Maldives] Token count: 512
# API response returned for: Maldives
# Processing country: Djibouti
# [Djibouti] Token count: 512
# API response returned for: Djibouti
# Processing country: Malaysia
# [Malaysia] Token count: 512
# API response returned for: Malaysia
# Processing country: Ghana
# [Ghana] Token count: 382
# API response returned for: Ghana
# Processing country: Iceland
# [Iceland] Token count: 255
# API response returned for: Iceland
# Processing country: Zambia
# [Zambia] Token count: 512
# API response returned for: Zambia
# Processing country: Bosnia and Herzegovina
# [Bosnia and Herzegovina] Token count: 512
# API response returned for: Bosnia and Herzegovina
# Processing country: Liberia
# [Liberia] Token count: 512
# API response returned for: Liberia
# Processing country: Philippines
# [Philippines] Token count: 367
# API response returned for: Philippines
# Processing country: Tuvalu
# [Tuvalu] Token count: 512
# API response returned for: Tuvalu
# Processing country: State of Palestine
# [State of Palestine] Token count: 512
# API response returned for: State of Palestine
# Processing country: Cabo Verde
# [Cabo Verde] Token count: 512
# API response returned for: Cabo Verde
# Processing country: Rwanda
# [Rwanda] Token count: 512
# API response returned for: Rwanda
# Processing country: Tajikistan
# [Tajikistan] Token count: 512
# API response returned for: Tajikistan
# Processing country: Zimbabwe
# [Zimbabwe] Token count: 512
# API response returned for: Zimbabwe
# Processing country: Lao People's Democratic Republic
# [Lao People's Democratic Republic] Token count: 512
# API response returned for: Lao People's Democratic Republic
# Processing country: China
# [China] Token count: 512
# API response returned for: China
# Processing country: Saint Lucia
# [Saint Lucia] Token count: 512
# API response returned for: Saint Lucia
# Processing country: Armenia
# [Armenia] Token count: 512
# API response returned for: Armenia
# Processing country: Belarus
# [Belarus] Token count: 512
# API response returned for: Belarus
# Processing country: Australia
# [Australia] Token count: 512
# API response returned for: Australia
# Processing country: Dominica
# [Dominica] Token count: 512
# API response returned for: Dominica
# Processing country: Serbia
# [Serbia] Token count: 512
# API response returned for: Serbia
# Processing country: Angola
# [Angola] Token count: 512
# API response returned for: Angola
# Processing country: Vanuatu
# [Vanuatu] Token count: 512
# API response returned for: Vanuatu
# Processing country: United Arab Emirates
# [United Arab Emirates] Token count: 512
# API response returned for: United Arab Emirates
# Processing country: Georgia
# [Georgia] Token count: 512
# API response returned for: Georgia
# Processing country: Bhutan
# [Bhutan] Token count: 512
# API response returned for: Bhutan
# Processing country: Republic of Korea
# [Republic of Korea] Token count: 512
# API response returned for: Republic of Korea
# Processing country: Solomon Islands
# [Solomon Islands] Token count: 512
# API response returned for: Solomon Islands
# Processing country: Thailand
# [Thailand] Token count: 244
# API response returned for: Thailand
# Processing country: Togo
# [Togo] Token count: 262
# API response returned for: Togo
# Processing country: Burkina Faso
# [Burkina Faso] Token count: 303
# API response returned for: Burkina Faso
# Processing country: Oman
# [Oman] Token count: 512
# API response returned for: Oman
# Processing country: Micronesia (Federated States of)
# [Micronesia (Federated States of)] Token count: 512
# API response returned for: Micronesia (Federated States of)
# Processing country: Fiji
# [Fiji] Token count: 512
# API response returned for: Fiji
# Processing country: Holy See
# [Holy See] Token count: 393
# API response returned for: Holy See
# Processing country: Eritrea
# [Eritrea] Token count: 512
# API response returned for: Eritrea
# Processing country: Canada
# [Canada] Token count: 512
# API response returned for: Canada
# Processing country: Barbados
# [Barbados] Token count: 512
# API response returned for: Barbados
# Processing country: United Republic of Tanzania
# [United Republic of Tanzania] Token count: 512
# API response returned for: United Republic of Tanzania
# Processing country: Namibia
# [Namibia] Token count: 512
# API response returned for: Namibia
# Processing country: Marshall Islands
# [Marshall Islands] Token count: 512
# API response returned for: Marshall Islands
# Processing country: Cook Islands
# [Cook Islands] Token count: 397
# API response returned for: Cook Islands
# Processing country: Liechtenstein
# [Liechtenstein] Token count: 511
# API response returned for: Liechtenstein
# Processing country: Egypt
# [Egypt] Token count: 512
# API response returned for: Egypt
# Processing country: Afghanistan
# [Afghanistan] Token count: 330
# API response returned for: Afghanistan
# Processing country: Bahamas
# [Bahamas] Token count: 512
# API response returned for: Bahamas
# Processing country: India
# [India] Token count: 269
# API response returned for: India
# Processing country: Timor-Leste
# [Timor-Leste] Token count: 419
# API response returned for: Timor-Leste
# Processing country: Saint Kitts and Nevis
# [Saint Kitts and Nevis] Token count: 512
# API response returned for: Saint Kitts and Nevis
# Processing country: Gambia
# [Gambia] Token count: 512
# API response returned for: Gambia
# Processing country: Suriname
# [Suriname] Token count: 512
# API response returned for: Suriname
# Processing country: Kazakhstan
# [Kazakhstan] Token count: 269
# API response returned for: Kazakhstan
# Processing country: Japan
# [Japan] Token count: 512
# API response returned for: Japan
# Processing country: Jamaica
# [Jamaica] Token count: 512
# API response returned for: Jamaica
# Processing country: Trinidad and Tobago
# [Trinidad and Tobago] Token count: 448
# API response returned for: Trinidad and Tobago
# Processing country: Mongolia
# [Mongolia] Token count: 356
# API response returned for: Mongolia
# Processing country: United States of America
# [United States of America] Token count: 512
# API response returned for: United States of America
# Processing country: Seychelles
# [Seychelles] Token count: 512
# API response returned for: Seychelles
# Processing country: Switzerland
# [Switzerland] Token count: 512
# API response returned for: Switzerland
# Processing country: New Zealand
# [New Zealand] Token count: 512
# API response returned for: New Zealand
# Processing country: Belize
# [Belize] Token count: 512
# API response returned for: Belize
# Processing country: Norway
# [Norway] Token count: 512
# API response returned for: Norway
# Processing country: Botswana
# [Botswana] Token count: 512
# API response returned for: Botswana
# Processing country: Russian Federation
# [Russian Federation] Token count: 442
# API response returned for: Russian Federation
# Processing country: Pakistan
# [Pakistan] Token count: 512
# API response returned for: Pakistan
# Processing country: Guinea-Bissau
# [Guinea-Bissau] Token count: 512
# API response returned for: Guinea-Bissau
# Processing country: Ethiopia
# [Ethiopia] Token count: 512
# API response returned for: Ethiopia
# Processing country: South Sudan
# [South Sudan] Token count: 512
# API response returned for: South Sudan
# Processing country: Turkmenistan
# [Turkmenistan] Token count: 512
# API response returned for: Turkmenistan
# Processing country: Sudan
# [Sudan] Token count: 298
# API response returned for: Sudan
# Processing country: North Macedonia
# [North Macedonia] Token count: 512
# API response returned for: North Macedonia
# Processing country: Myanmar
# [Myanmar] Token count: 512
# API response returned for: Myanmar
# Processing country: Türkiye
# [Türkiye] Token count: 512
# API response returned for: Türkiye
# Processing country: Nepal
# [Nepal] Token count: 512
# API response returned for: Nepal
# Processing country: Tonga
# [Tonga] Token count: 512
# API response returned for: Tonga
# Processing country: Bolivia (Plurinational State of)
# [Bolivia (Plurinational State of)] Token count: 512
# API response returned for: Bolivia (Plurinational State of)
# Processing country: Lebanon
# [Lebanon] Token count: 512
# API response returned for: Lebanon
# Processing country: Samoa
# [Samoa] Token count: 512
# API response returned for: Samoa
# Processing country: Antigua and Barbuda
# [Antigua and Barbuda] Token count: 512
# API response returned for: Antigua and Barbuda
# Processing country: Somalia
# [Somalia] Token count: 228
# API response returned for: Somalia
# Processing country: Syrian Arab Republic
# [Syrian Arab Republic] Token count: 211
# API response returned for: Syrian Arab Republic
# Processing country: San Marino
# [San Marino] Token count: 260
# API response returned for: San Marino
# Processing country: Senegal
# [Senegal] Token count: 212
# API response returned for: Senegal
# Processing country: Kuwait
# [Kuwait] Token count: 389
# API response returned for: Kuwait
# Processing country: Sierra Leone
# [Sierra Leone] Token count: 423
# API response returned for: Sierra Leone
# Processing country: Benin
# [Benin] Token count: 495
# API response returned for: Benin
# Processing country: Gabon
# [Gabon] Token count: 263
# API response returned for: Gabon
# Processing country: Malawi
# [Malawi] Token count: 512
# API response returned for: Malawi
# Processing country: Burundi
# [Burundi] Token count: 285
# API response returned for: Burundi
# Processing country: Democratic Republic of the Congo
# [Democratic Republic of the Congo] Token count: 202
# API response returned for: Democratic Republic of the Congo
# Processing country: Niue
# [Niue] Token count: 430
# API response returned for: Niue
# Processing country: Saint Vincent and the Grenadines
# [Saint Vincent and the Grenadines] Token count: 512
# API response returned for: Saint Vincent and the Grenadines
# Processing country: Azerbaijan
# [Azerbaijan] Token count: 469
# API response returned for: Azerbaijan
# Processing country: Chile
# [Chile] Token count: 498
# API response returned for: Chile
# Processing country: South Africa
# [South Africa] Token count: 287
# API response returned for: South Africa
# Processing country: Central African Republic
# [Central African Republic] Token count: 334
# API response returned for: Central African Republic
# Processing country: Mauritania
# [Mauritania] Token count: 370
# API response returned for: Mauritania
# Processing country: Mozambique
# [Mozambique] Token count: 512
# API response returned for: Mozambique
# Processing country: Brazil
# [Brazil] Token count: 373
# API response returned for: Brazil
# Processing country: Niger
# [Niger] Token count: 302
# API response returned for: Niger
# Processing country: Nicaragua
# [Nicaragua] Token count: 181
# API response returned for: Nicaragua
# Processing country: Mexico
# [Mexico] Token count: 494
# API response returned for: Mexico
# Processing country: Guyana
# [Guyana] Token count: 290
# API response returned for: Guyana
# Processing country: Republic of Moldova
# [Republic of Moldova] Token count: 503
# API response returned for: Republic of Moldova
# Processing country: Andorra
# [Andorra] Token count: 301
# API response returned for: Andorra

# %%
llm_responses
# Out:
# {'Bangladesh': 'The 2030 emissions reduction target for Bangladesh is as follows:\n\n* Unconditional target: 27.56 MtCO2e (6.73%) reduction below BAU in 2030 [Doc ID: bangladesh_english_20220601, Chunk ID: 755]\n* Conditional target: 89.47 MtCO2e (21.85%) reduction below BAU in 2030 [Doc ID: bangladesh_english_20220601, Chunk ID: 755]\n\nNote that the BAU scenario is 409.4 MtCO2e in 2030 [Doc ID: bangladesh_english_20220601, Chunk ID: 745].',
#  'Brunei Darussalam': 'The official 2030 emissions reduction target for Brunei Darussalam is a reduction in GHG emissions by 20% relative to Business-As-Usual (BAU) levels by 2030 [Doc ID: brunei_darussalam_english_20220601, Chunk ID: 16 and 5].',
#  'Cameroon': 'The target is not clearly specified in the provided chunks.',
#  'Viet Nam': "Viet Nam's 2030 emissions reduction targets are:\n\n- Unconditional contribution: 15.8% reduction compared to BAU [Doc ID: viet_nam_english_20221101, Chunk ID: 74]\n- Conditional contribution: 43.5% reduction compared to BAU [Doc ID: viet_nam_english_20221101, Chunk ID: 74]",
#  'Uganda': "Uganda's 2030 emissions reduction target is 24.7% below the BAU baseline. The unconditional target is 5.9% below the BAU baseline in 2030. [Doc ID: uganda_english_20220901, Chunk ID: 1601, 1053, 1674]",
#  'Montenegro': 'At least a 35% reduction in total national GHG emissions (excl. LULUCF) by 2030 compared to 1990 (base year) [Doc ID: montenegro_english_20220601, Chunk ID: 9].',
#  'Jordan': "Jordan's 2030 emissions reduction target is 31% reduction compared to the BAU scenario in 2012, which is quantified to be 11269 Gg CO2 eq. This target is divided into unconditional and conditional targets: \n\n- Unconditional target: 5% reduction compared to the BAU scenario [Doc ID: jordan_english_20220601, Chunk ID: 751]\n- Conditional target: 26% reduction compared to the BAU scenario, if the resources and means of implementation are available [Doc ID: jordan_english_20220601, Chunk ID: 751, 718]\n\nThe BAU scenario in 2030 is estimated to be 43,989.0 Gg CO2 eq [Doc ID: jordan_english_20220601, Chunk ID: 707].",
#  'Cambodia': "Cambodia's 2030 emissions reduction target is 30.2 million tCO2e/year under the NDC scenario 3 [Doc ID: cambodia_english_20220601, Chunk ID: 5272].",
#  'Papua New Guinea': 'The target is not clearly specified in the provided chunks.',
#  'Singapore': "Singapore's 2030 emissions reduction target is to reduce its GHG emissions to around 60 MtCO2e. No baseline year/scenario or percentage reduction is specified. [Doc ID: singapore_english_20221101, Chunk ID: 26], [Doc ID: singapore_english_20221101, Chunk ID: 1]",
#  'Sri Lanka': 'The target is not clearly specified in the provided chunks.',
#  'Uzbekistan': 'The target is not clearly specified in the provided chunks.',
#  'Finland': 'The official 2030 emissions reduction target for Finland is a reduction of 55% by 2030 compared to 1990 levels [Doc ID: finland_english_20231001, Chunk ID: 42].',
#  'United Kingdom of Great Britain and Northern Ireland': 'The unconditional 2030 emissions reduction target for the United Kingdom of Great Britain and Northern Ireland is at least 68% economy-wide net reduction in GHG emissions by 2030 compared to 1990 levels [Doc ID: united_kingdom_of_great_britain_and_northern_ireland_english_20220901, Chunk ID: 60, 22, 384]. No conditional target is specified in the provided chunks.',
#  'Albania': "The country's 2030 emissions reduction target is a 20.9% reduction below the BAU scenario, which corresponds to a reduction of 3,170 kt CO2e. [Doc ID: albania_english_20220801, Chunk ID: 1824]",
#  'Grenada': "Grenada's 2030 emissions reduction target is 40% below 2010 emissions levels. \n\n[Doc ID: grenada_english_20220601, Chunk ID: 27] \n[Doc ID: grenada_english_20220601, Chunk ID: 47] \n\nNote: There is no mention of a conditional target or a baseline scenario other than 2010 emissions levels.",
#  'Ukraine': "Ukraine's 2030 emissions reduction target is a 65% reduction in GHG emissions compared to 1990 levels [Doc ID: ukraine_english_20220601, Chunk ID: 30, 52]. \n\nNo conditional target is specified in the provided chunks.",
#  'Saudi Arabia': 'The target is not clearly specified in the provided chunks.',
#  'Sao Tome and Principe': "Sao Tome and Principe's 2030 emissions reduction target is 27% below the BAU scenario, which corresponds to a reduction of 109 ktCO2eq from the projected BAU emissions of 400 ktCO2eq in 2030. [Doc ID: sao_tome_and_principe_english_20220601, Chunk ID: 38, 20, 47, 48]",
#  'Cuba': 'The target is not clearly specified in the provided chunks.',
#  'Kyrgyzstan': "Kyrgyzstan's 2030 emissions reduction target is: \n- 15.97% reduction from the BAU scenario (unconditional) [Doc ID: kyrgyzstan_english_20220601, Chunk ID: 203]\n- 43.62% reduction from the BAU scenario (conditional, subject to international support) [Doc ID: kyrgyzstan_english_20220601, Chunk ID: 203]",
#  'Algeria': "Algeria's 2030 emissions reduction target is a 7% to 22% reduction compared to a business-as-usual (BAU) scenario. The 7% reduction is unconditional, while the 22% reduction is conditional on external support in terms of finance, technology development and transfer, and capacity building. [Doc ID: algeria_english_20220601, Chunk ID: 51]",
#  'Maldives': 'The target is not clearly specified in the provided chunks.',
#  'Djibouti': "Djibouti's 2030 emissions reduction targets are as follows:\n\n* Unconditional target: 40% reduction compared to the business-as-usual scenario, equivalent to 1.8 Mt CO2e reduction [Doc ID: djibouti_english_20220601, Chunk ID: 33].\n* Conditional target: 20% reduction compared to the business-as-usual scenario, equivalent to 0.9 Mt CO2e reduction [Doc ID: djibouti_english_20220601, Chunk ID: 34].",
#  'Malaysia': "Malaysia's 2030 emissions reduction target is a 45% reduction in economy-wide carbon intensity (against GDP) compared to the 2005 level [Doc ID: malaysia_english_20220601, Chunk ID: 3, 34]. This target is unconditional and represents an additional 10% reduction compared to the previous target [Doc ID: malaysia_english_20220601, Chunk ID: 190].",
#  'Ghana': 'The target is not clearly specified in the provided chunks.',
#  'Iceland': "Iceland's 2030 emissions reduction target is an economy-wide net reduction of at least 55% in greenhouse gas emissions compared to 1990. [Doc ID: iceland_english_20220601, Chunk ID: 26]",
#  'China': 'The target is not clearly specified in the provided chunks.',
#  'Saint Lucia': "Saint Lucia's 2030 emissions reduction target is a 14.7% reduction in the energy sector relative to 2010, equivalent to 435 GgCO2eq [Doc ID: saint_lucia_english_20250201, Chunk ID: 348, 353, 144].",
#  'Armenia': 'The official 2030 emissions reduction target for Armenia is a 40% reduction from 1990 emission levels [Doc ID: armenia_english_20220601, Chunk ID: 37].',
#  'Belarus': "Belarus' 2030 emissions reduction targets are:\n\n- Unconditional target: at least 35% reduction from the 1990 level by 2030, inclusive of the LULUCF sector. [Doc ID: belarus_english_20220601, Chunk ID: 6, 32]\n  - Baseline year: 1990\n  - Quantitative value (1990 level): 137.8 million tonnes of CO2-eq (exclusive of LULUCF), 117.2 million tonnes of CO2-eq (inclusive of LULUCF) [Doc ID: belarus_english_20220601, Chunk ID: 30]\n\n- Conditional target: at least 40% reduction from the 1990 level by 2030, inclusive of the LULUCF sector, subject to using international financing mechanisms. [Doc ID: belarus_english_20220601, Chunk ID: 7, 33]\n  - Baseline year: 1990\n  - Quantitative value (1990 level): 137.8 million tonnes of CO2-eq (exclusive of LULUCF), 117.2 million tonnes of CO2-eq (inclusive of LULUCF) [Doc ID: belarus_english_20220601, Chunk ID: 30]",
#  'Australia': "Australia's 2030 emissions reduction target is a 43% reduction below 2005 levels by 2030. [Doc ID: australia_english_20220601, Chunk ID: 17, 69, 89, 90]",
#  'Dominica': 'The target is not clearly specified in the provided chunks.',
#  'Serbia': 'The unconditional 2030 emissions reduction target for Serbia is a 13.2% reduction compared to the 2010 level, which is equivalent to a 33.3% reduction compared to 1990. [Doc ID: serbia_english_20220801, Chunk ID: 5, 6]',
#  'Angola': 'The target is not clearly specified in the provided chunks.',
#  'Vanuatu': "Vanuatu's 2030 emissions reduction target is approximately 78.786 Gg CO2e from the energy sector, which is around a 40% reduction compared to the business as usual (BAU) scenario in 2030 [Doc ID: vanuatu_english_20220801, Chunk ID: 131] [Doc ID: vanuatu_english_20220801, Chunk ID: 121].",
#  'United Arab Emirates': 'The target is not clearly specified in the provided chunks.',
#  'Georgia': "Georgia's 2030 emissions reduction target is 50-57% below 1990 levels [Doc ID: georgia_english_20220601, Chunk ID: 37, 39, 43].",
#  'Bhutan': 'The target is not clearly specified in the provided chunks.',
#  'Republic of Korea': 'The 2030 emissions reduction target for the Republic of Korea is a 40% reduction from the 2018 level of 727.6 MtCO2eq, resulting in a targeted GHG emissions level of 436.6 MtCO2eq in 2030, which is approximately a 100 MtCO2eq reduction from the previous target of 536.1 MtCO2eq. [Doc ID: republic_of_korea_english_20220601, Chunk ID: 8] [Doc ID: republic_of_korea_english_20220601, Chunk ID: 245]',
#  'Solomon Islands': 'The unconditional 2030 emissions reduction target for Solomon Islands is a 30% reduction below 2015 levels, compared to a business-as-usual (BAU) projection [Doc ID: solomon_islands_english_20220601, Chunk ID: 52]. The conditional target is a 45% reduction in GHG emissions by 2030, compared to BAU projection [Doc ID: solomon_islands_english_20220601, Chunk ID: 238, 53].',
#  'Thailand': 'The target is not clearly specified in the provided chunks.',
#  'Togo': 'The target is not clearly specified in the provided chunks.',
#  'Burkina Faso': "Burkina Faso's 2030 emissions reduction target is 18.2% below the Business As Usual (BAU) scenario, with a target of 21,574.63 Gg CO2eq [Doc ID: burkina_faso_french_20220601, Chunk ID: 323].",
#  'Oman': "Oman's 2030 emissions reduction target is a 21% reduction relative to the Business-As-Usual (BAU) projection for the year 2030 [Doc ID: oman_english_20231101, Chunk ID: 1184].",
#  'Micronesia (Federated States of)': 'The target is not clearly specified in the provided chunks.',
#  'Fiji': "Fiji's 2030 emissions reduction target is to reduce 30% of BAU CO2 emissions from the energy sector by 2030. This target can be broken down into unconditional and conditional components: \n\n- Unconditional target: 10% reduction of BAU baseline CO2 emissions [Doc ID: fiji_english_20220601, Chunk ID: 29]\n- Conditional target: 20% reduction of BAU baseline CO2 emissions [Doc ID: fiji_english_20220601, Chunk ID: 29]\n\nThe baseline scenario projects energy sector emissions to reach 2,341 kTCO2e by 2030 [Doc ID: fiji_english_20220601, Chunk ID: 12].",
#  'Holy See': 'The 2030 emissions reduction target for Holy See is 20% below the 2011 level [Doc ID: holy_see_english_20230501, Chunk ID: 26, 46]. No conditional target is specified. The 2011 emissions level is approximately 18.94 kt CO2eq [Doc ID: holy_see_english_20230501, Chunk ID: 33].',
#  'Eritrea': 'The unconditional 2030 emissions reduction target for Eritrea is 0.982 MtCO2 from fossil fuel [Doc ID: eritrea_english_20220601, Chunk ID: 175].',
#  'Canada': 'The unconditional 2030 emissions reduction target for Canada is a 45% reduction below 2010 levels [Doc ID: canada_english_20220601, Chunk ID: 26].',
#  'Barbados': 'The official 2030 emissions reduction target for Barbados is: \n\n* Unconditional target: 35% reduction relative to business-as-usual (BAU) emissions in 2030 [Doc ID: barbados_english_20220601, Chunk ID: 220, 264].\n* Conditional target: 70% reduction relative to business-as-usual (BAU) emissions in 2030, conditional upon international support [Doc ID: barbados_english_20220601, Chunk ID: 222, 264, 420]. \n\nQuantitative values for the BAU emissions projections are 1,958Gg CO2e for 2030 [Doc ID: barbados_english_20220601, Chunk ID: 249, 227].',
#  'United Republic of Tanzania': 'The 2030 emissions reduction target for the United Republic of Tanzania is a reduction of 30-35% relative to the Business-As-Usual (BAU) scenario [Doc ID: united_republic_of_tanzania_english_20220601, Chunk ID: 680, 612, 46, 611].',
#  'Namibia': "Namibia's 2030 emissions reduction target is a 24% reduction compared to the BAU scenario from its base year 2010 levels [Doc ID: namibia_english_20240101, Chunk ID: 218].",
#  'Marshall Islands': 'The 2030 emissions reduction target for Marshall Islands is a reduction of at least 45% below 2010 levels by 2030 [Doc ID: marshall_islands_english_20250201, Chunk ID: 323, 69].',
#  'Cook Islands': 'The unconditional 2030 emissions reduction target for Cook Islands is not clearly specified in the provided chunks. However, a conditional reduction target of 43% by 2030 is mentioned, but it is specific to the electricity sub-sector [Doc ID: cook_islands_english_20220601, Chunk ID: 30].',
#  'Liechtenstein': "Liechtenstein's 2030 emissions reduction target is a 40% reduction compared to 1990. [Doc ID: liechtenstein_english_20220601, Chunk ID: 10] The baseline year is 1990, with a quantified amount of emissions of 228.7 Kt CO2 eq. [Doc ID: liechtenstein_english_20220601, Chunk ID: 43]",
#  'Egypt': 'The target is not clearly specified in the provided chunks.',
#  'Afghanistan': "Afghanistan's 2030 emissions reduction target is a 13.6% reduction in GHG emissions compared to a business-as-usual (BAU) 2030 scenario, conditional on external support. [Doc ID: afghanistan_english_20220601, Chunk ID: 16]",
#  'Bahamas': "The Bahamas' 2030 emissions reduction target is a 30% reduction in economy-wide GHG emissions compared to its Business-as-Usual (BaU) scenario [Doc ID: bahamas_english_20221101, Chunk ID: 1698, 1147, 1729, 1739, 1109, 1155, 1658, 1764, 1252].",
#  'India': "India's 2030 emissions reduction target is to reduce the Emissions Intensity of its GDP by 45 percent by 2030 [Doc ID: india_english_20220801, Chunk ID: 26].",
#  'Timor-Leste': 'The target is not clearly specified in the provided chunks.',
#  'Saint Kitts and Nevis': 'The official 2030 emissions reduction target for Saint Kitts and Nevis is a 61% reduction in CO2 emissions relative to 2010, which is mostly conditional upon adequate international financial and capacity building support. This translates to a reduction from 253 GgCO2e (2010 estimate) to 124 GgCO2e. [Doc ID: saint_kitts_and_nevis_english_20220601, Chunk ID: 308, 420]',
#  'Gambia': 'The unconditional 2030 emissions reduction target for Gambia is 2.6% reduction, equivalent to 169 GgCO2e, compared to the expected baseline level in 2030 [Doc ID: gambia_english_20220601, Chunk ID: 555]. The conditional 2030 emissions reduction target is 47.2% reduction, equivalent to 3,121 GgCO2e, compared to the expected baseline level in 2030 [Doc ID: gambia_english_20220601, Chunk ID: 559].',
#  'Suriname': 'The target is not clearly specified in the provided chunks.',
#  'Kazakhstan': 'The target is not clearly specified in the provided chunks.',
#  'Japan': "Japan's 2030 emissions reduction target is a 46% reduction from its fiscal year 2013 levels [Doc ID: japan_english_20220601, Chunk ID: 206]. The target is to reduce emissions to 760 million t-CO2 in fiscal year 2030 from its fiscal year 2013 levels [Doc ID: japan_english_20220601, Chunk ID: 79].",
#  'Jamaica': "Jamaica's 2030 emissions reduction targets are:\n\n* Unconditional: 25.4% reduction relative to business-as-usual emissions in 2030 [Doc ID: jamaica_english_20220601, Chunk ID: 45]\n* Conditional: 28.5% reduction relative to business-as-usual emissions in 2030 [Doc ID: jamaica_english_20220601, Chunk ID: 46]\n\nThe business-as-usual emissions in 2030 for sectors in the NDC are 7.2 MtCO2e [Doc ID: jamaica_english_20220601, Chunk ID: 29], and the reference year for the target is 2030, with business-as-usual emissions calculated based on policies in place in 2005 [Doc ID: jamaica_english_20220601, Chunk ID: 24].",
#  'Trinidad and Tobago': "Trinidad and Tobago's 2030 emissions reduction target is 15% below BAU emission levels, with an additional conditional target that could bring the total reduction to 15% below BAU. However, a sector-specific target exists: a 30% reduction in GHG emissions in the public transportation sector by 2030, compared to a BAU scenario (reference year 2013). \n\n[Doc ID: trinidad_and_tobago_english_20220601, Chunk ID: 21] \n[Doc ID: trinidad_and_tobago_english_20220601, Chunk ID: 19]",
#  'Mongolia': "Mongolia's 2030 emissions reduction target is a 22.7% reduction compared to the business-as-usual (BAU) scenario, excluding LULUCF [Doc ID: mongolia_english_20220601, Chunk ID: 42].",
#  'United States of America': 'The official 2030 emissions reduction target for United States of America is 50-52 percent below 2005 levels [Doc ID: united_states_of_america_english_20220601, Chunk ID: 66, 31, 47].',
#  'Seychelles': "Seychelles' 2030 emissions reduction target is to reduce economy-wide GHG emissions by 26.4% below the BAU scenario. [Doc ID: seychelles_english_20220601, Chunk ID: 204, 292, 37, 195, 281]",
#  'Switzerland': 'The official 2030 emissions reduction target for Switzerland is at least 50% reduction compared to 1990 levels, which is equivalent to an average reduction of net greenhouse gas emissions of at least 35% over the period 2021-2030 [Doc ID: switzerland_english_20241101, Chunk ID: 32].',
#  'New Zealand': "New Zealand's 2030 emissions reduction target is to reduce net greenhouse gas emissions to 50% below gross 2005 levels by 2030 [Doc ID: new_zealand_english_20220601, Chunk ID: 42, 225, 3]. The target is managed using an emissions budget approach, with an expected emissions budget for the period 2021-2030 of 571 Mt CO2-e [Doc ID: new_zealand_english_20220601, Chunk ID: 92].",
#  'Belize': 'The 2030 emissions reduction target for Belize is not clearly specified in the provided chunks as a single, overarching target. However, various sector-specific targets and estimated reductions are mentioned:\n\n* Reduction in GHG emissions and increase in GHG removals related to land use change: 2,053 KtCO2e cumulative over 2021-2030 [Doc ID: belize_english_20220601, Chunk ID: 224]\n* Avoided emissions in the national electricity supply: 44 KtCO2e by 2030 [Doc ID: belize_english_20220601, Chunk ID: 318]\n* Reduced emissions from livestock: 10% by 2030 [Doc ID: belize_english_20220601, Chunk ID: 282]\n* Avoided emissions from agriculturally driven land use change: at least 4.5 KtCO2e by 2025 [Doc ID: belize_english_20220601, Chunk ID: 282]\n* Cumulative avoided emissions: over 5.6 MTCO2e by 2030 [Doc ID: belize_english_20220601, Chunk ID: 746]\n* Annual emissions reduction: 1.0 MTCO2e by 2030 [Doc ID: belize_english_20220601, Chunk ID: 746]\n\nThese targets are set against a business-as-usual baseline projected to 2030 [Doc ID: belize_english_20220601, Chunk ID: 736].',
#  'Norway': "Norway's official 2030 emissions reduction target is at least 55% reduction in greenhouse gas emissions compared to 1990 levels [Doc ID: norway_english_20221101, Chunk ID: 52, 64, 5, 38, 24]. The base year emission level was about 51 Mt CO2-equivalents [Doc ID: norway_english_20221101, Chunk ID: 30].",
#  'Botswana': "Based on the provided document chunks, Botswana's 2030 emissions reduction targets are:\n\n- Unconditional target: 5% reduction by 2030 compared to the BAU (Business-As-Usual) projection [Doc ID: botswana_english_20241201, Chunk ID: 726].\n- Conditional target: 13% reduction by 2030 compared to the BAU projection, subject to the conditionality of funding [Doc ID: botswana_english_20241201, Chunk ID: 726] and [Doc ID: botswana_english_20241201, Chunk ID: 704].\n\nNote that the combined mitigation target is 15% reduction by 2030 compared to the BAU projection [Doc ID: botswana_english_20241201, Chunk ID: 726].",
#  'Russian Federation': 'The unconditional 2030 emissions reduction target for Russian Federation is up to 70% compared to the 1990 level [Doc ID: russian_federation_english_20220601, Chunk ID: 82].',
#  'Pakistan': "Pakistan's 2030 emissions reduction target is a 50% reduction of its projected emissions by 2030, with 15% reduction unconditional and 35% conditional [Doc ID: pakistan_english_20220601, Chunk ID: 3352, 397, 485].",
#  'Guinea-Bissau': 'The official 2030 emissions reduction target for Guinea-Bissau is:\n\n* Unconditional target: 10% reduction, corresponding to a 1.8 MtCO2e reduction, compared to the reference scenario [Doc ID: guinea-bissau_english_20220601, Chunk ID: 405].\n* Conditional target: 30% reduction compared to the baseline scenario [Doc ID: guinea-bissau_english_20220601, Chunk ID: 138, 389].',
#  'Ethiopia': 'The official 2030 emissions reduction target for Ethiopia is a reduction of 68.8% compared to the BAU projection by 2030, consisting of an unconditional component of 14% and a conditional component of 54.8% [Doc ID: ethiopia_english_20220601, Chunk ID: 913].',
#  'South Sudan': 'The unconditional 2030 emissions reduction target for South Sudan is 18% reduction in GHG emissions by 2030 compared to 2017 levels [Doc ID: south_sudan_english_20220601, Chunk ID: 4703]. \n\nAdditionally, there are two conditional targets: \n- 30% reduction in GHG emissions compared to baseline in 2030 [Doc ID: south_sudan_english_20220601, Chunk ID: 4707].\n- 66% reduction in GHG emissions compared to baseline in 2030 is not clearly linked to any specific conditions in the provided chunks, but it is mentioned as a possible reduction [Doc ID: south_sudan_english_20220601, Chunk ID: 4711].',
#  'Turkmenistan': 'The target is not clearly specified in the provided chunks.',
#  'Sudan': 'The target is not clearly specified in the provided chunks.',
#  'North Macedonia': "North Macedonia's 2030 emissions reduction target is 51% reduction in greenhouse gas emissions compared to 1990 levels [Doc ID: north_macedonia_english_20220601, Chunk ID: 44, 162, 222]. Additionally, an 82% reduction in net GHG emissions compared to 1990 levels is mentioned [Doc ID: north_macedonia_english_20220601, Chunk ID: 45, 170].",
#  'Myanmar': "Myanmar's unconditional 2030 emissions reduction target is 25% net reduction (MtCO2e) [Doc ID: myanmar_english_20220601, Chunk ID: 613]. The conditional target is 50% net reduction by 2030 [Doc ID: myanmar_english_20220601, Chunk ID: 666].",
#  'Türkiye': 'The official 2030 emissions reduction target for Türkiye is a 41% reduction in GHG emissions compared to the BAU Scenario, which is equivalent to 695 Mt CO2 eq in 2030 [Doc ID: türkiye_english_20230401, Chunk ID: 999, 34].',
#  'Nepal': 'The target is not clearly specified in the provided chunks.',
#  'Tonga': "Tonga's 2030 emissions reduction target is 13% (16 Gg) reduction in GHG emissions compared to 2006 [Doc ID: tonga_english_20220601, Chunk ID: 235, 109, 117, 146, 63].",
#  'Bolivia (Plurinational State of)': 'The target is not clearly specified in the provided chunks.',
#  'Lebanon': 'The unconditional 2030 emissions reduction target for Lebanon is a 20% reduction compared to the Business-As-Usual (BAU) scenario, amounting to 7,790 Gg CO2eq. [Doc ID: lebanon_english_20220601, Chunk ID: 84].',
#  'Samoa': "Based on the provided document chunks, Samoa's 2030 emissions reduction targets are:\n\n* Unconditional target: Reduce overall GHG emissions by 26% in 2030 compared to 2007 levels (or by 91 Gg CO2e compared to the new reference year) [Doc ID: samoa_english_20220601, Chunk ID: 155].\n* No conditional target is mentioned in the provided chunks.\n\nSector-specific targets are also mentioned, including:\n* Energy sector: Reduce GHG emissions by 30% in 2030 compared to 2007 levels (or by 53 Gg CO2e compared to the new reference year) [Doc ID: samoa_english_20220601, Chunk ID: 237, 157, 194].\n* AFOLU sector: Reduce GHG emissions by 26% in 2030 compared to 2007 levels (or by 35.2 Gg CO2e compared to the new reference year) [Doc ID: samoa_english_20220601, Chunk ID: 258].\n* Waste sector: Reduce GHG emissions by 4% in 2030 compared to 2007 levels (or by 1.2 Gg CO2e compared to the new reference year) [Doc ID: samoa_english_20220601, Chunk ID: 253].",
#  'Antigua and Barbuda': 'The target is not clearly specified in the provided chunks.',
#  'Somalia': 'The target is not clearly specified in the provided chunks.',
#  'Syrian Arab Republic': 'The target is not clearly specified in the provided chunks.',
#  'San Marino': 'The target is not clearly specified in the provided chunks.',
#  'Senegal': 'The target is not clearly specified in the provided chunks.',
#  'Kuwait': 'The target is not clearly specified in the provided chunks.',
#  'Sierra Leone': 'The target is not clearly specified in the provided chunks.',
#  'Benin': 'The target is not clearly specified in the provided chunks.',
#  'Gabon': 'The target is not clearly specified in the provided chunks.',
#  'Malawi': 'The target is not clearly specified in the provided chunks.',
#  'Burundi': 'The target is not clearly specified in the provided chunks.',
#  'Democratic Republic of the Congo': 'The target is not clearly specified in the provided chunks.',
#  'Niue': 'The target is not clearly specified in the provided chunks.',
#  'Saint Vincent and the Grenadines': 'The target is not clearly specified in the provided chunks.',
#  'Azerbaijan': 'The target is not clearly specified in the provided chunks.',
#  'Chile': 'The target is not clearly specified in the provided chunks.',
#  'South Africa': 'The target is not clearly specified in the provided chunks.',
#  'Central African Republic': 'The target is not clearly specified in the provided chunks.',
#  'Mauritania': 'The target is not clearly specified in the provided chunks.',
#  'Mozambique': 'The target is not clearly specified in the provided chunks.',
#  'Brazil': 'The target is not clearly specified in the provided chunks.',
#  'Niger': "Niger's 2030 emissions reduction target is: \n\n- Unconditional target: 12.57% reduction below the BAU 2030 scenario [Doc ID: niger_french_20220601, Chunk ID: 298].\n- Conditional target: 45% reduction below the BAU 2030 scenario [Doc ID: niger_french_20220601, Chunk ID: 301].",
#  'Nicaragua': 'The target is not clearly specified in the provided chunks.',
#  'Mexico': 'The target is not clearly specified in the provided chunks.',
#  'Guyana': 'The target is not clearly specified in the provided chunks.',
#  'Republic of Moldova': 'The target is not clearly specified in the provided chunks.',
#  'Andorra': 'The target is not clearly specified in the provided chunks.'}

# %%
failed_countries = []
successful_countries = []
for country, response in llm_responses.items():
    if response == 'The target is not clearly specified in the provided chunks.':
        failed_countries.append(country)
    else:
        successful_countries.append(country)


print(f'Out of a total of {len(failed_countries + successful_countries)} countries, we managed to obtain answers for {len(successful_countries) } or {round(len(successful_countries) / len(failed_countries + successful_countries) * 100)}% of them')
# Out:
# Out of a total: 129 countries, we managed to obtain answers for 78 or 60% of them

# %% [markdown]
# ### Constructing our final data frame to store the responses from the LLM

# %%
import pandas as pd
import re
llm_df = pd.DataFrame([{"country": country, "llm_response": response} for country, response in llm_responses.items()])

def extract_citations(text):
    pattern = r"\[Doc ID: (.*?), Chunk ID: (\d+)\]"
    return re.findall(pattern, text)

llm_df["citations"] = llm_df["llm_response"].apply(extract_citations)
exploded = llm_df.explode("citations").dropna(subset=["citations"])

exploded[["doc_id", "chunk_index"]] = pd.DataFrame(exploded["citations"].tolist(), index=exploded.index)
exploded["chunk_index"] = exploded["chunk_index"].astype(int)

merged_df = pd.merge(exploded, complete_embeddings_df,on=["doc_id", "chunk_index"],how="left")

merged_df = merged_df.drop(columns=["citations"])

# %% [markdown]
# ### Second Retrieval Loop

# %% [markdown]
# Because our pipeline failed to retrieve information for almost 40% of countries, I wanted to explore how we might obtain more answers. I noticed that the countries where we didnt obtain a generated answer were those ones which had less chunks fed to the LLM. This possibly was because we imposed too strict of thresholds earlier. I now wanted to re-run our retrieval process for those countries we couldn't obtain answers for re-running the similarity search this time with no thresholds, and higher number of returned chunks

# %%
non_retrieved_countries = list(failed_countries)

# %%
all_non_retrieved_country_results = []

for country in non_retrieved_countries:
    for gs_query, embedding_val in gold_standard_query_embeddings.items():
        query = text("""
        SELECT 
            doc_chunks.doc_id,
            doc_chunks.chunk_index,
            doc_chunks.content,
            documents.country,
            doc_chunks.climate_bert_cluster_labels,
            doc_chunks.w2v_cluster_labels,
            doc_chunks.chunk_metadata,
            (doc_chunks.embedding <=> :embedding) AS cosine_distance
        FROM doc_chunks
        LEFT JOIN documents ON doc_chunks.doc_id = documents.doc_id
        WHERE 
            documents.country = :country
        ORDER BY cosine_distance ASC
        LIMIT 15
        """)

        with engine.connect() as conn:
            result_rows = conn.execute(query, {
                "embedding": embedding_val,
                "country": country
            }).fetchall()

        rem_country_results = pd.DataFrame(result_rows, columns=[
            "doc_id", "chunk_index", "content", "country", 
            "climate_bert_cluster", "w2v_cluster", "chunk_metadata", "cosine_distance"
        ])
        rem_country_results["gs_query"] = gs_query
        rem_country_results["cosine_similarity"] = 1 - rem_country_results["cosine_distance"]
        
        all_non_retrieved_country_results.append(rem_country_results)

# Combine into one DataFrame
rem_countries_df = pd.concat(all_non_retrieved_country_results, ignore_index=True)
rem_countries_df = rem_countries_df.drop_duplicates(subset=["doc_id", "chunk_index"]).reset_index(drop=True)
# Out:
# /var/folders/v6/xrbmfj054b7cb1_bvtvf02nc0000gn/T/ipykernel_65382/1618816941.py:39: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   rem_countries_df = pd.concat(all_non_retrieved_country_results, ignore_index=True)

# %%
rem_countries_df
# Out:
#                                    doc_id chunk_index  \
# 0                cameroon_french_20220601         677
# 1                cameroon_french_20220601         898
# 2                cameroon_french_20220601         569
# 3                cameroon_french_20220601         629
# 4       papua_new_guinea_english_20220601          27
# ..                                    ...         ...
# 552  republic_of_moldova_english_20220601         476
# 553              andorra_spanish_20250201         135
# 554              andorra_spanish_20250201         136
# 555              andorra_spanish_20250201         140
# 556              andorra_spanish_20250201         134
#
#                                                content              country  \
# 0    CO2, soit 12 % des émissions dans le scenario ...             Cameroon
# 1                   +0,6° C en 2025 à +3,6° C en 2100.             Cameroon
# 2                        Scénario "with measures" 2030             Cameroon
# 3                                 électrique en 2035 »             Cameroon
# 4    Energy Industries: Within the Energy Industrie...     Papua New Guinea
# ..                                                 ...                  ...
# 552                  Extreme weather events: - - - - -  Republic of Moldova
# 553  in net greenhouse gas emissions by 2035, compa...              Andorra
# 554  2005 levels, with the ambition of achieving ca...              Andorra
# 555  target based on a "Business as Usual" (BAU) sc...              Andorra
# 556  at COP28. This document establishes a 63% redu...              Andorra
#
#                 climate_bert_cluster  \
# 0                Narrative - English
# 1                Narrative - English
# 2    Headers, Keywords, Multilingual
# 3    Headers, Keywords, Multilingual
# 4                Narrative - English
# ..                               ...
# 552                 Tabular, Numeric
# 553              Narrative - English
# 554              Narrative - English
# 555              Narrative - English
# 556              Narrative - English
#
#                                   w2v_cluster  \
# 0      Development & Access Projects – French
# 1          Fragmented Phrases & Minor Details
# 2    Emission Reduction Targets & Commitments
# 3      Development & Access Projects – French
# 4              Project Sectors & Technologies
# ..                                        ...
# 552         Legal & Institutional Disclaimers
# 553  Emission Reduction Targets & Commitments
# 554  Emission Reduction Targets & Commitments
# 555  Emission Reduction Targets & Commitments
# 556  Emission Reduction Targets & Commitments
#
#                                         chunk_metadata  cosine_distance  \
# 0    {'links': [], 'filename': 'cameroon_french_202...         0.029144
# 1    {'links': [], 'filename': 'cameroon_french_202...         0.049589
# 2    {'links': [], 'filename': 'cameroon_french_202...         0.037173
# 3    {'links': [], 'filename': 'cameroon_french_202...         0.048699
# 4    {'links': [], 'filename': 'papua_new_guinea_en...         0.028881
# ..                                                 ...              ...
# 552  {'links': [], 'filename': 'republic_of_moldova...         0.081684
# 553  {'links': [], 'filename': 'andorra_spanish_202...         0.021906
# 554  {'links': [], 'filename': 'andorra_spanish_202...         0.024723
# 555  {'links': [], 'filename': 'andorra_spanish_202...         0.036083
# 556  {'links': [], 'filename': 'andorra_spanish_202...         0.024120
#
#                                               gs_query  cosine_similarity
# 0    2030 target is a % reduction in ghgs below lev...           0.970856
# 1    2030 target is a % reduction in ghgs below lev...           0.950411
# 2        The Estimated Mitigation Target is X% by 2030           0.962827
# 3        The Estimated Mitigation Target is X% by 2030           0.951301
# 4    2030 target is a % reduction in ghgs below lev...           0.971119
# ..                                                 ...                ...
# 552      The Estimated Mitigation Target is X% by 2030           0.918316
# 553  2030 target is a % reduction in ghgs below lev...           0.978094
# 554  2030 target is a % reduction in ghgs below lev...           0.975277
# 555  2030 target is a % reduction in ghgs below lev...           0.963917
# 556      The Estimated Mitigation Target is X% by 2030           0.975880
#
# [557 rows x 10 columns]

# %% [markdown]
# Here I can already see some of the returned chunks are of low quality. This is where the clustering is useful, because we can now remove those obviously incorrect chunks by filtering out the poor clusters

# %%
rem_countries_df = rem_countries_df[rem_countries_df['w2v_cluster'] != 'Fragmented Phrases & Minor Details']
rem_countries_df
# Out:
#                                                  doc_id chunk_index  \
# 0                                nepal_english_20220601          23
# 1                                nepal_english_20220601         141
# 2                                nepal_english_20220601         311
# 3                                nepal_english_20220601          22
# 4                                nepal_english_20220601         140
# ...                                                 ...         ...
# 1079  micronesia_(federated_states_of)_english_20221001         274
# 1080  micronesia_(federated_states_of)_english_20221001          67
# 1081  micronesia_(federated_states_of)_english_20221001         279
# 1082  micronesia_(federated_states_of)_english_20221001          96
# 1083  micronesia_(federated_states_of)_english_20221001          63
#
#                                                 content  \
# 0     aims to achieve net-zero greenhouse gas emissi...
# 1     By 2030, including measures in policies to off...
# 2     This NDC broadens the ambition of the 2016 NDC...
# 3     long-term low greenhouse gas emission developm...
# 4     By 2030, ensure at least five tourist destinat...
# ...                                                 ...
# 1079  Conditional By 2030, increase electricity gene...
# 1080  By 2030, increase electricity generation from ...
# 1081  Carbon dioxide emissions reductions • Reduced ...
# 1082  Mitigation Co-benefits • Reduced emissions of ...
# 1083                             Contributions for 2030
#
#                                country climate_bert_cluster  \
# 0                                Nepal  Narrative - English
# 1                                Nepal  Narrative - English
# 2                                Nepal  Narrative - English
# 3                                Nepal  Narrative - English
# 4                                Nepal  Narrative - English
# ...                                ...                  ...
# 1079  Micronesia (Federated States of)  Narrative - English
# 1080  Micronesia (Federated States of)  Narrative - English
# 1081  Micronesia (Federated States of)  Narrative - English
# 1082  Micronesia (Federated States of)  Narrative - English
# 1083  Micronesia (Federated States of)  Narrative - English
#
#                                        w2v_cluster  \
# 0         Emission Reduction Targets & Commitments
# 1                Legal & Institutional Disclaimers
# 2         Emission Reduction Targets & Commitments
# 3     Mitigation & Adaptation Strategies – English
# 4                Legal & Institutional Disclaimers
# ...                                            ...
# 1079                Project Sectors & Technologies
# 1080                Project Sectors & Technologies
# 1081      Emission Reduction Targets & Commitments
# 1082      Emission Reduction Targets & Commitments
# 1083              Formal Climate Pledges – English
#
#                                          chunk_metadata  cosine_distance  \
# 0     {'links': [], 'filename': 'nepal_english_20220...         0.025414
# 1     {'links': [], 'filename': 'nepal_english_20220...         0.026306
# 2     {'links': [], 'filename': 'nepal_english_20220...         0.028036
# 3     {'links': [], 'filename': 'nepal_english_20220...         0.028532
# 4     {'links': [], 'filename': 'nepal_english_20220...         0.028684
# ...                                                 ...              ...
# 1079  {'links': [], 'filename': 'micronesia_(federat...         0.029710
# 1080  {'links': [], 'filename': 'micronesia_(federat...         0.030883
# 1081  {'links': [], 'filename': 'micronesia_(federat...         0.036580
# 1082  {'links': [], 'filename': 'micronesia_(federat...         0.042539
# 1083  {'links': [], 'filename': 'micronesia_(federat...         0.032396
#
#                                                gs_query  cosine_similarity
# 0     2030 target is a % reduction in ghgs below lev...           0.974586
# 1     2030 target is a % reduction in ghgs below lev...           0.973694
# 2     2030 target is a % reduction in ghgs below lev...           0.971964
# 3     2030 target is a % reduction in ghgs below lev...           0.971468
# 4     2030 target is a % reduction in ghgs below lev...           0.971316
# ...                                                 ...                ...
# 1079  2030 target is a % reduction in ghgs below lev...           0.970290
# 1080  2030 target is a % reduction in ghgs below lev...           0.969117
# 1081  2030 target is a % reduction in ghgs below lev...           0.963420
# 1082  2030 target is a % reduction in ghgs below lev...           0.957461
# 1083      The Estimated Mitigation Target is X% by 2030           0.967604
#
# [1025 rows x 10 columns]

# %%
second_loop_country_message_directory = {}

for country in non_retrieved_countries:
    formatted_chunks = ''
    relevant_df = rem_countries_df[rem_countries_df['country'] == country]
    query_text = f"What is the official 2030 emissions reduction target for {country}, based on the provided document chunks?"
    
    for i in range(len(relevant_df)):
        row = relevant_df.iloc[i]
        formatted_chunk = format_context(row)
        formatted_chunks += formatted_chunk + '\n'
            
    messages = [
        {"role": "system", "content": system_prompt_c},
        {"role": "user", "content": f"Context:\n{formatted_chunks.strip()}\n\nQuestion: {query_text}\n\nAnswer:"}]
    
    for row in messages:
        for key, value in row.items():
            print(f"{key}: {value}")
    
    second_loop_country_message_directory[country] = messages
second_loop_country_message_directory
# Out:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: cameroon_french_20220601, Chunk ID: 677]
#  'CO2, soit 12 % des émissions dans le scenario BAU 2030.'
# [Doc ID: cameroon_french_20220601, Chunk ID: 898]
#  '+0,6° C en 2025 à +3,6° C en 2100.'
# [Doc ID: cameroon_french_20220601, Chunk ID: 569]
#  'Scénario "with measures" 2030'
# [Doc ID: cameroon_french_20220601, Chunk ID: 629]
#  'électrique en 2035 »'
#
# Question: What is the official 2030 emissions reduction target for Cameroon, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: papua_new_guinea_english_20220601, Chunk ID: 27]
#  'Energy Industries: Within the Energy Industries PNG is committing to a headline target of carbon neutrality within the energy industries sub-sector by 2030.'
# [Doc ID: papua_new_guinea_english_20220601, Chunk ID: 46]
#  'PNG’s annual GHG emissions and removals between 2001 and 2015, the future emissions prediction under the business as usual scenario and an illustrative pathway to the NDC target for the LULUCF sub-sector.'
# [Doc ID: papua_new_guinea_english_20220601, Chunk ID: 40]
#  'It should be noted that the LULUCF sector in PNG makes up significantly higher levels of emissions (13,574.04 Gg CO2 eq in 2015) but these are offset by removals within PNG’s current approach to reporting leaving a relatively small net emission of 1,716.46 Gg CO2 eq.'
# [Doc ID: papua_new_guinea_english_20220601, Chunk ID: 31]
#  'Enhancing levels of renewables in the energy mix – through increasing from 30% (2015) to 78% the level of installed capacity for on grid electricity generation that is produced by renewables9.'
# [Doc ID: papua_new_guinea_english_20220601, Chunk ID: 28]
#  'This will be achieved by:'
#
# Question: What is the official 2030 emissions reduction target for Papua New Guinea, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: sri_lanka_english_20220601, Chunk ID: 155]
#  'Key interventions envisaged for GHG emissions reduction up to the year 2030:'
# [Doc ID: sri_lanka_english_20220601, Chunk ID: 85]
#  ' To achieve 70% renewable energy in electricity generation by 2030  To achieve Carbon Neutrality by 2050 in electricity generation  No capacity addition of Coal power plants'
# [Doc ID: sri_lanka_english_20220601, Chunk ID: 929]
#  'BAU emissions scenario and potential GHG emission reduction pathways for some mitigation'
# [Doc ID: sri_lanka_english_20220601, Chunk ID: 104]
#  'Sri Lanka has an impressive track record of tackling poverty. The overall poverty rate is 4.1%5 showing commendable progress from 20 years ago (28.8% in 2000). However, there is wide disparity in poverty'
# [Doc ID: sri_lanka_english_20220601, Chunk ID: 82]
#  'Sri Lanka’s per capita greenhouse gas emission in 2010 was 1.02 tons and its global cumulative contribution in 2019 was 0.03%.'
# [Doc ID: sri_lanka_english_20220601, Chunk ID: 404]
#  'by improving animal comfort and welfare (40% increase of milk yield per cattle by 2030 on unconditional basis and further increase up to 55% on conditional basis. Increase productive milking cow percentage of the herd up to 40% on conditional basis)'
#
# Question: What is the official 2030 emissions reduction target for Sri Lanka, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 161]
#  'The following are recommended in addition to the mitigation target indicator by 2030:'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 201]
#  'The goal is consistent with a relative reduction in specific greenhouse gas emissions per GDP across the economy compared to the baseline year emissions.'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 152]
#  'The noted difference in total GHG emissions estimates between NDC1 and NDC2 is due to:'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 338]
#  '"Energy" sector makes the greatest contribution to total GHG emissions (76.3%).'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 544]
#  'Five largest categories, whose contribution to total GHG emissions made up around 63%:'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 683]
#  '− reduce pollutant emissions by 10% (from 2.5 million to 2.2 million tons);'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 120]
#  '− achieve Land Degradation Neutrality; − increase the average productivity of basic agricultural products by 20-25%.'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 335]
#  'Uzbekistan’s contribution to global emissions stands at around 0.3%.'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 314]
#  'Currently, Uzbekistan’s GHG emissions share in global emissions accounts for about 0.3%.'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 158]
#  'the effects of greenhouse gas emissions over a 100-year period;'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 132]
#  'The gradual modernization of industries and a number of other measures implemented from 1990 to 2017 resulted in the reduction in the energy intensity of GDP by almost 2.5 times. Specific CO2 emissions per unit of GDP decreased by almost 40%.'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 166]
#  'Baseline indicators: In 2019, the share of RES in the total power generation was 10%, mainly from hydropower, the energy intensity of the economy decreased by 44% (www.iea.org).'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 285]
#  'Uzbekistan's GDP growth between 1990 and 2017 was around 400% (in current dollars), while greenhouse gas emissions increased by only 6.7% over the same period.'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 286]
#  'Thus, the GDP growth significantly outpaces the growth in greenhouse gas emissions. Achieving the set target ensures that the growth of greenhouse gas emissions remains contained as the economy develops.'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 162]
#  'Increase the share of renewable energy sources to 25% of total power generation;'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 315]
#  'GHG emissions per capita total 5.8 t CO2-eq/person (2017). Since 1990, they decreased by 2.8 t CO2-eq/person.'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 244]
#  'In the last five years, there has been a decrease in specific GHG emissions per capita, which is due both to the absolute reduction of GHG emissions and consistently high growth rate of the population (1.6% per year in average).'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 649]
#  'Indicator 1.5 “By 2030,'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 196]
#  'A single annual target indicator is set until 2030.'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 142]
#  'Baseline year: 2010'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 690]
#  'from 48% (16 million people) to 100%'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 170]
#  'projected high growth in the near future;'
# [Doc ID: uzbekistan_english_20220601, Chunk ID: 98]
#  'Uzbekistan is a resource-rich developing economy with a stable annual GDP growth of over 5%. The country has about 35 million population. According to UN estimates, the country's population will reach 37 million by 2030.'
#
# Question: What is the official 2030 emissions reduction target for Uzbekistan, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: saudi_arabia_english_20211023, Chunk ID: 136]
#  'As a developing country with limited sources economy and historically low GHG emission contribution, the Kingdom considers its 2030 ambition as fair, given that the sum of the contributions leads to a significant deviation from a business-as-usual scenario emission.'
# [Doc ID: saudi_arabia_english_20211023, Chunk ID: 87]
#  'ports which will result in reductions in traffic and GHG emissions. Approved methodologies will be used to estimate avoided GHG emissions.'
# [Doc ID: saudi_arabia_english_20211023, Chunk ID: 26]
#  'Two scenarios for determining dynamic baselines for the period 2020–2030:'
#
# Question: What is the official 2030 emissions reduction target for Saudi Arabia, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: cuba_english_20220601, Chunk ID: 54]
#  '24% of electricity generation based on renewable energy sources by the year 2030. It that the the contribution will avoid emission of 30.6 million ktCO2eq. into the atmosphere in the period 2014 – 2030.'
# [Doc ID: cuba_english_20220601, Chunk ID: 59]
#  'the It that the contribution will avoid thousand emission of 700 ktCO2eq. into the atmosphere in the period 2014 – 2030.'
# [Doc ID: cuba_english_20220601, Chunk ID: 74]
#  'Treatment of 100% of waste waters in the Cuban swine sector, reducing 8 million emissions in ktCO2eq. annually in the period of 2020- 2030.'
# [Doc ID: cuba_english_20220601, Chunk ID: 70]
#  'Increasing forest coverage by 165 000ha in the period 2019- 2030. Removing 169,9 million tons of atmospheric CO2 in the period 2019-2030.'
# [Doc ID: cuba_english_20220601, Chunk ID: 50]
#  'to 24% of Increase electricity generation based on Renewable Energy Sources (RES) in the Cuban electricity matrix by 2030.'
# [Doc ID: cuba_english_20220601, Chunk ID: 66]
#  'forest Increase coverage in the country to 33% by 2030'
#
# Question: What is the official 2030 emissions reduction target for Cuba, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: maldives_english_20250201, Chunk ID: 295]
#  'The target for 2035 is to reduce emissions under a BAU scenario, where the emissions'
# [Doc ID: maldives_english_20250201, Chunk ID: 231]
#  'Target is set relative to the projected emissions upto 2035 under the BAU scenario which'
# [Doc ID: maldives_english_20220601, Chunk ID: 17]
#  'Target is given relative to the projected emissions to 2030 under a BAU scenario with 2011 as the base year of emissions.'
# [Doc ID: maldives_english_20220601, Chunk ID: 53]
#  'The target for 2030 is to reduce emissions under a BAU where the emissions reduction is mostly from the energy and waste sector'
# [Doc ID: maldives_english_20250201, Chunk ID: 422]
#  'The aggregation of GHG emissions is estimated using the 100-year time-horizon global'
# [Doc ID: maldives_english_20250201, Chunk ID: 420]
#  'emission estimates across all sectors, with a combination of Tier 1 and Tier 2 methods is'
# [Doc ID: maldives_english_20250201, Chunk ID: 225]
#  'date of 2035, in 2030 a nationally determined contribution with an end date of 2040, and so forth'
# [Doc ID: maldives_english_20220601, Chunk ID: 29]
#  '(d) Target relative to the reference indicator, expressed numerically, for example in percentage or amount of reduction'
# [Doc ID: maldives_english_20250201, Chunk ID: 149]
#  'Although the Maldives’ contribution to global greenhouse gas emissions stands at only 0.004%,'
# [Doc ID: maldives_english_20220601, Chunk ID: 110]
#  'The aggregation of GHG emissions will be estimated, and will be reported, using the 100-year time-horizon global warming potential (GWP) values from the IPCC Fifth Assessment Report.'
# [Doc ID: maldives_english_20220601, Chunk ID: 5]
#  'Despite these challenges and although our contribution to GHG emissions stands at only 0.003% in the global share, we are determined to show climate leadership and continue to advocate for more effective and bold actions to address the climate crisis facing the entire world today.'
# [Doc ID: maldives_english_20250201, Chunk ID: 398]
#  'The Maldives will account for its anthropogenic greenhouse gas emissions and removals'
# [Doc ID: maldives_english_20250201, Chunk ID: 151]
#  'reducing greenhouse gas emissions and transitioning to a sustainable, low-carbon economy.'
# [Doc ID: maldives_english_20250201, Chunk ID: 62]
#  'through to 2035. It underscores our ambitious commitment'
# [Doc ID: maldives_english_20250201, Chunk ID: 292]
#  'Single – year target.'
# [Doc ID: maldives_english_20220601, Chunk ID: 52]
#  'Single – year target'
# [Doc ID: maldives_english_20250201, Chunk ID: 276]
#  'o Population growth projections from 2014-2054 from the MBS.'
# [Doc ID: maldives_english_20250201, Chunk ID: 226]
#  'every five years thereafter”.'
#
# Question: What is the official 2030 emissions reduction target for Maldives, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: ghana_english_20220601, Chunk ID: 116]
#  'Ghana adopts an absolute single-year target approach, with 2019 being the base year and 2030 as the target year.'
# [Doc ID: ghana_english_20220601, Chunk ID: 326]
#  'Promote clean rural households lighting. Scale-up renewable energy penetration by 10% by 2030. Decarbonisation of oil and gas production.'
# [Doc ID: ghana_english_20220601, Chunk ID: 100]
#  'd. Target relative to the reference indicator, expressed numerically, for example, in percentage or amount of reduction.'
# [Doc ID: ghana_english_20220601, Chunk ID: 214]
#  'Ghana undertakes a formal emission reduction obligation to control the growth of its GHG emissions, despite having emitted 0.1% of global GHG emissions in 201810.'
# [Doc ID: ghana_english_20220601, Chunk ID: 356]
#  'High – 2,617 tonnes black carbon avoided in 2030'
# [Doc ID: ghana_english_20220601, Chunk ID: 95]
#  'Base year - 2019'
#
# Question: What is the official 2030 emissions reduction target for Ghana, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 614]
#  'The objective is expressed as a reduction in total emissions from BAU by 2040, with a base data period of 2011.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 453]
#  'f. 30% reduction of methane emissions from landfill sites by 2030 and 70% reduction by'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 228]
#  'f. 30% reduction of methane emissions from landfill sites by 2030 and 70% reduction by'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 840]
#  'Reduce the volume of leachate by 50% by 2030 from'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 1049]
#  '30% reduction of methane emissions from landfill sites by 2030 and 70% reduction by 2040.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 442]
#  'a. Reduce the volume of leachate by 50% by 2030 from suitable landfill sites'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 644]
#  'The overall target for emissions reduction is a single-year target for 2040. Some individual actions include interim targets where applicable.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 443]
#  'b. Reduce the amount of waste for final disposal in landfill sites by 30% by 2030 and by 50%'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 220]
#  'b. Reduce the amount of waste for final disposal in landfill sites by 30% by 2030 and by 50%'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 403]
#  'Improve energy efficiency by 20% (versus business as usual) across all sectors by 2030.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 801]
#  'Improve energy efficiency by 20% (versus business as usual) across all sectors by 2030.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 432]
#  'e. The overall number of vehicles is reduced by 20% by 2030 and 40% by 2040.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 1029]
#  'Reduce the emissions of the passenger vehicle fleet by 8% by 2030, and 24% by 2040.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 426]
#  'a. Reducing the emissions of the passenger vehicle fleet by 8% by 2030, and 24% by 2040'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 203]
#  'a. Reducing the emissions of the passenger vehicle fleet by 8% by 2030, and 24% by 2040'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 209]
#  'e. The overall number of vehicles is reduced by 20% by 2030, and 40% by 2040.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 1042]
#  'The overall number of vehicles is reduced by 20% by 2030, and 40% by 2040.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 363]
#  'Figure 2: Total GHG by sector in 2011 (Mt CO2e), as included in the mitigation chapter of the First BUR'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 314]
#  'of Palestine’s increased ambition, as compared to its First NDCs. Palestine’s updated total carbon reduction by 2040 equates to a total of 2.8 Mt CO2e (Status-quo Scenario) and 4.6 Mt CO2e (Independence Scenario).'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 617]
#  'Total absolute GHG emissions in the base year were 3.2 Mt CO2e in 2011. Under a BAU growth scenario, Palestine’s emissions are projected to reach 15.93 MtCO2e and 22.5 MtCO2e in the BAU Status-quo and BAU Independence Scenarios, respectively.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 241]
#  'c. Non-revenue water is reduced by 15% by 2032.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 848]
#  '2030 and 70% reduction by 2040.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 921]
#  'Non-revenue water is reduced by 15% by 2032.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 866]
#  'Non-revenue water is reduced by 15% by 2032.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 1054]
#  'Non-revenue water is reduced by 15% by 2032.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 405]
#  'solar PV, by 2030.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 628]
#  'Data to inform the BAU scenario were:'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 227]
#  'by 100% by 2040.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 336]
#  'will Imports gradually to zero in 2040.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 835]
#  '2030, and 60% by 2040.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 239]
#  'and Gaza are re-used by 2030.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 837]
#  'capacity buses by 2030, and 40% by 2040.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 839]
#  '2030, and 40% by 2040.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 231]
#  'by 2030 and 140MW by 2040.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 452]
#  'by 100% by 2040'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 1045]
#  'Reduce the amount of waste for final disposal in landfill sites by 30% by 2030 and by 50% by 2040.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 223]
#  'Increase the amount of waste re-used or recycled by 30% by 2030 and by 40% by 2040.'
# [Doc ID: state_of_palestine_english_20220601, Chunk ID: 1012]
#  'Improve energy efficiency by 20% (versus business as usual) across all sectors by 2035.'
#
# Question: What is the official 2030 emissions reduction target for State of Palestine, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: china_english_20220601, Chunk ID: 458]
#  'into use in 2015. In accordance with the standard of a 50% reduction in energy use for public buildings'
# [Doc ID: china_english_20220601, Chunk ID: 973]
#  'In line with the country’s climate actions and target to address climate change, the Macao SAR Government has proposed an enhanced target for 2030: a 60%-65% reduction in carbon intensity in 2030 compared to 2005.'
# [Doc ID: china_english_20220601, Chunk ID: 429]
#  'thermal power generation, it contributes to an annual reduction of 8.28 million tons of CO2 emissions.'
# [Doc ID: china_english_20220601, Chunk ID: 86]
#  'Figure 1. Changes in China’s carbon intensity and its share of non-fossil fuels in primary energy'
# [Doc ID: china_english_20220601, Chunk ID: 364]
#  'designated size has increased by 14.0%, while the operating income of strategic emerging service industry increased by 19.6%.'
# [Doc ID: china_english_20220601, Chunk ID: 467]
#  'are 6.87 GWh, equivalent to 1,754 tons of standard coal. This contributes to annual CO2 and sulfur dioxide (SO2) emission reductions of 11,031 tons and 36 tons respectively.'
# [Doc ID: china_english_20220601, Chunk ID: 251]
#  'Figure 3. China’s renewable energy investment, 2015–2019'
# [Doc ID: china_english_20220601, Chunk ID: 487]
#  'energy by 72.9%. Their annual energy savings'
# [Doc ID: china_english_20220601, Chunk ID: 276]
#  'Installed capacity in 2019 (Total: 31.69 GW)'
# [Doc ID: china_english_20220601, Chunk ID: 737]
#  'Jilin Oilfield 300,000 tons / year'
# [Doc ID: china_english_20220601, Chunk ID: 478]
#  'As of the end of 2019, there were 16,432 pure'
#
# Question: What is the official 2030 emissions reduction target for China, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: dominica_english_20220701, Chunk ID: 1874]
#  'A target of 20% emissions reduction by 2030 has been set for the transport sector. This'
# [Doc ID: dominica_english_20220701, Chunk ID: 1428]
#  ' Reduce emissions from forestry and other land use to 95% below 2010 levels by 2030, stop net'
# [Doc ID: dominica_english_20220701, Chunk ID: 1906]
#  'economy. To achieve the communicated emissions reduction target of 78.6% for the waste'
# [Doc ID: dominica_english_20220701, Chunk ID: 1150]
#  'The Government of Dominica has set a target to reduce HFCs emissions by 10% by 2030,'
# [Doc ID: dominica_english_20220701, Chunk ID: 1894]
#  'Dominica has set a target for 100% emissions reduction in the shipping sub-sector by 2030.'
# [Doc ID: dominica_english_20220701, Chunk ID: 1903]
#  'reduction target of 78.6% and emission increases in this sector have been largely attributed to'
# [Doc ID: dominica_english_20220701, Chunk ID: 1140]
#  'emissions at the following rates: 39% by 2025 and 45% by 2030 below 201421 levels. These'
# [Doc ID: dominica_english_20220701, Chunk ID: 2089]
#  'This is a total emissions reduction target from the baseline year (2014) and involves progressive reduction of total greenhouse gases for each of the target years:'
# [Doc ID: dominica_english_20220701, Chunk ID: 1805]
#  'Government has declared a national target of 100% renewable energy by 2030 and 98.6% GHG'
# [Doc ID: dominica_english_20220701, Chunk ID: 1159]
#  'Single-year target'
# [Doc ID: dominica_english_20220701, Chunk ID: 1585]
#  'recovery until 2025 with no further disturbances. From the period 2025-2030, it is assumed that'
# [Doc ID: dominica_english_20220701, Chunk ID: 1241]
#  'estimates, the 2020 target has not been achieved. Table 6 below shows progress towards the'
# [Doc ID: dominica_english_20220701, Chunk ID: 2587]
#  '2014-2019 and a mid-term NAGP 2021-2030 were developed as part of the supporting'
# [Doc ID: dominica_english_20220701, Chunk ID: 148]
#  'C Stocks recovery from 2018 to 2030 (tC)'
# [Doc ID: dominica_english_20220701, Chunk ID: 2880]
#  '50% reduction in landfill waste compared to 2020 baseline - < 5 months post even until all'
# [Doc ID: dominica_english_20220701, Chunk ID: 2778]
#  '< 25% decrease in GDP one year after disaster'
# [Doc ID: dominica_english_20220701, Chunk ID: 2776]
#  '> 50% food import dependence ratio'
# [Doc ID: dominica_english_20220701, Chunk ID: 250]
#  'Nationally Determined Contributions (NDC) in acknowledgement of Article 4 of the Paris Agreement1, with a total greenhouse gas emissions reduction of 45% below 2014 levels by'
# [Doc ID: dominica_english_20220701, Chunk ID: 618]
#  'efforts to further limit the temperature increase to 1.5C through ambitious mitigation actions. In'
# [Doc ID: dominica_english_20220701, Chunk ID: 1195]
#  '(BAU) scenario for the period 2005 to 2030, total and sectoral emissions from 2005 to 2030. The'
#
# Question: What is the official 2030 emissions reduction target for Dominica, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: angola_english_20220601, Chunk ID: 676]
#  'Angola is setting the target to achieve a 14% reduction (unconditionally) by 2025.'
# [Doc ID: angola_english_20220601, Chunk ID: 1009]
#  'For reforestation, 50% of what was proposed for reduction in the INDC by 2030 (target 2030: 2032 ktCO2and sequestration) was considered.'
# [Doc ID: angola_english_20220601, Chunk ID: 1621]
#  'At least 14% domestic reduction in greenhouse gas emissions by 2025.'
# [Doc ID: angola_english_20220601, Chunk ID: 2003]
#  'In terms of flaring, we have increased the ambition to reduce flaring. Instead of 75% reduction, as planned and presented in the unconditional 2030 scenario, it is now considered a 91% emission reduction compared to 2015 emissions.'
# [Doc ID: angola_english_20220601, Chunk ID: 742]
#  'The combined unconditional and conditional contribution is therefore a 24% reduction in GHG emissions compared to BAU scenario in 2025; this is equivalent to an estimated mitigation level of up to 26,5 million tCO2e in 2025.'
# [Doc ID: angola_english_20220601, Chunk ID: 1895]
#  'For flaring, the reduction target value (75%) indicated by the World Bank in 2011 was considered.'
# [Doc ID: angola_english_20220601, Chunk ID: 1067]
#  'In the flaring reduction, 75% of the target considered in the unconditional scenario was considered.'
# [Doc ID: angola_english_20220601, Chunk ID: 1613]
#  'The type of contribution selected by Angola in terms of mitigation is based on results, i.e. the reduction of greenhouse gases to levels below the BAU. The BAU scenario by 2025 was based on the last GHG inventory of 2015.'
# [Doc ID: angola_english_20220601, Chunk ID: 1994]
#  'Since the ambition is extremely high, we have increased the values of all measures except for reforestation and mini-hydro, where the values remain the same as the unconditional 2030 scenario.'
# [Doc ID: angola_english_20220601, Chunk ID: 2004]
#  'For solar panels in industry, we increased one more unit in this measure (from 4 MW in scenario unconditional 2030 scenario, to 6 MW in this scenario)'
# [Doc ID: angola_english_20220601, Chunk ID: 965]
#  'In this NDC update, Angola sets the target of achieving those 15% of emission reduction by 2025, unconditionally. In addition, it is expected that through a conditional mitigation scenario the country could reduce an additional 10% below BAU emission levels by 2025.'
# [Doc ID: angola_english_20220601, Chunk ID: 1615]
#  'In 2015 (base year), emissions were about 99992 ktCO2eq, and BAU projection indicates that to fulfil the condition of the supposed growth parameters by 2025, the emissions will reach 108473 ktCO2eq.'
# [Doc ID: angola_english_20220601, Chunk ID: 1894]
#  'In terms of reforestation, the total value of emissions reduction in reforestation present in INDC (2032ktCO2e) was considered.'
# [Doc ID: angola_english_20220601, Chunk ID: 741]
#  'Conditional contribution: An additional reduction of 10% relative to BAU in the year 2025; equivalent to an estimated mitigation level of 11,1 million tCO2e e in that year. This represents an additional targeted contribution, based on the provision of international support and funding.'
# [Doc ID: angola_english_20220601, Chunk ID: 772]
#  'implications for emissions in the transport sector, resulting in a rise in global temperature and climate change.'
# [Doc ID: angola_english_20220601, Chunk ID: 1592]
#  'National emissions of the greenhouse gases represent only 0.10%19 of global in 2015.'
# [Doc ID: angola_english_20220601, Chunk ID: 890]
#  'Total GHG emissions for the year 2015 accounted for 99.992 ktCO2e.'
# [Doc ID: angola_english_20220601, Chunk ID: 864]
#  'However, there are other sources of greenhouse gas emissions from the industrial sector. The table below shows which are the relevant subsectors considered for this sector.'
# [Doc ID: angola_english_20220601, Chunk ID: 959]
#  'According to BAU projections, and with no considerations for mitigation measures in the country, the GHG emissions in Angola are expected to keep rising for the next decade (Figure 7).'
# [Doc ID: angola_english_20220601, Chunk ID: 891]
#  'Table 9 shows an emissions breakdown – total greenhouse gases, plus carbon dioxide, methane, and nitrous oxide individually – by sector.'
# [Doc ID: angola_english_20220601, Chunk ID: 740]
#  'Unconditional contribution: A reduction of 14% relative to BAU (2015) in the year 2025; equivalent to an estimated mitigation level of 15,4 million tonnes of carbon dioxide equivalent (tCO2e) in that year. This is an unconditional target, based on domestically supported and implemented mitigation measures and policies.'
# [Doc ID: angola_english_20220601, Chunk ID: 489]
#  'Table 3 – Estimated population projections for the 2015-2030 period [15]'
# [Doc ID: angola_english_20220601, Chunk ID: 577]
#  'Figure 3 – Evolution of GDP growth rates between 2012 and 2019 [30]'
# [Doc ID: angola_english_20220601, Chunk ID: 490]
#  'Population projections 2020-2050 (hab.)'
# [Doc ID: angola_english_20220601, Chunk ID: 757]
#  'Long-term development strategy for Angola (Angola 2025)'
# [Doc ID: angola_english_20220601, Chunk ID: 955]
#  'Business-as-Usual (BAU) scenario'
# [Doc ID: angola_english_20220601, Chunk ID: 1611]
#  'Start year: 2020 End year: 2025'
# [Doc ID: angola_english_20220601, Chunk ID: 738]
#  'Angola’s mitigation contribution takes the form of a reduction in GHG emissions relative to a business-as-usual (BAU) emissions baseline (2015) over the period 2015-2025.'
#
# Question: What is the official 2030 emissions reduction target for Angola, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: united_arab_emirates_english_20241101, Chunk ID: 844]
#  'Base year target: 47% reduction below 2019 net GHG emission level in 2035'
# [Doc ID: united_arab_emirates_english_20241101, Chunk ID: 851]
#  'An enhanced and more ambitious Economy-wide target of reducing 47% net GHG emissions level by 2035 compared to 2019 level – with alignment to reach net zero by 2050. Sectoral level targets as described in Chapter 4.'
# [Doc ID: united_arab_emirates_english_20241101, Chunk ID: 942]
#  'Refer to (5.a) above. The UAE has developed the emissions in alignment with the AR5 100-year global warming potentials.'
# [Doc ID: united_arab_emirates_english_20241101, Chunk ID: 979]
#  'Further information can be found in Chapter 2. Although the UAE accounts for around 0.3% of global cumulative CO2 emissions, significant ambitions are being raised across the whole-economy to reduce its emissions by 47% compared to the 2019 baseline.'
# [Doc ID: united_arab_emirates_english_20241101, Chunk ID: 830]
#  'Target relative to the reference indicator, expressed numerically, for example in percentage or amount of reduction;'
# [Doc ID: united_arab_emirates_english_20241101, Chunk ID: 261]
#  'In 2023, the company has doubled its carbon capture capacity commitment to 10mtpa by 2030. Additionally, the company has taken final investment decision on two major CCUS projects with a combined carbon capture capacity of 2.9mtpa.'
# [Doc ID: united_arab_emirates_english_20241101, Chunk ID: 879]
#  'While emissions from domestic aviation and shipping are covered as memo items, emission and reductions from international aviation and shipping are not in the scope of this NDC.'
# [Doc ID: united_arab_emirates_english_20241101, Chunk ID: 209]
#  'Individual sector emissions include emissions from power and water usage, and to prevent double counting, power and water related emissions is detailed in section 4.2.1: power and water.'
# [Doc ID: united_arab_emirates_english_20241101, Chunk ID: 203]
#  'Reduction by 2035'
# [Doc ID: united_arab_emirates_english_20241101, Chunk ID: 202]
#  'Target in MtCO2e by 2035'
# [Doc ID: united_arab_emirates_english_20241101, Chunk ID: 831]
#  'Fixed level target: 103.5 MtCO2e in 2035 (including LULUCF)'
# [Doc ID: united_arab_emirates_english_20241101, Chunk ID: 850]
#  'single-year target'
# [Doc ID: united_arab_emirates_english_20241101, Chunk ID: 849]
#  '2019 - end of 2035'
#
# Question: What is the official 2030 emissions reduction target for United Arab Emirates, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: bhutan_english_20220601, Chunk ID: 160]
#  'Transport emissions are projected to increase by a factor of three by 2050 as compared to 2020 levels under business-as-usual scenario. The LEDS for Surface Transport12 was developed to provide strategic intervention options for transport and mobility and are categorised as follows:'
# [Doc ID: bhutan_english_20220601, Chunk ID: 304]
#  'Bhutan’s target is to maintain the status as a carbon neutral country. This is expressed in relative terms of total GHG emissions against total removals of GHG for each relevant target year.'
# [Doc ID: bhutan_english_20220601, Chunk ID: 326]
#  'Bhutan’s overall national target is to maintain the carbon neutral status. This is expressed in relative terms of total GHG emissions against total removals of GHG for each relevant target year.'
# [Doc ID: bhutan_english_20220601, Chunk ID: 219]
#  'Implementing the NRS is estimated to require approximately USD 54.5 million. Quantifiable actions and targets until 2030 include'
# [Doc ID: bhutan_english_20220601, Chunk ID: 208]
#  'Bhutan is already carbon neutral and has achieved the goal for net zero emissions by 2050. Bhutan’s commitment is to remain carbon neutral, and this refers to total emissions relative to total removals at a national level.'
# [Doc ID: bhutan_english_20220601, Chunk ID: 330]
#  'Bhutan’s target is to maintain the status as a carbon neutral country where total GHG emissions do not exceed total removals by sinks including forests.'
# [Doc ID: bhutan_english_20220601, Chunk ID: 404]
#  'Net emission has been presented in carbon dioxide equivalents (CO2e) using the 100 - year global warming potentials (GWPs) from the 1995 IPCC Second Assessment Report (SAR)'
# [Doc ID: bhutan_english_20220601, Chunk ID: 145]
#  'The short and medium-term prioritized mitigation measures will lead to a cumulative mitigation potential of up to 4,122 Gg CO2e which would require an investment of USD 101.84 Million.'
# [Doc ID: bhutan_english_20220601, Chunk ID: 156]
#  'The mitigation potential from the LEDS for industries is estimated between 999 and 1,137 Gg CO2e per annum based on the grid emission factor11 or 9,990 -11,370 Gg CO2e cumulative mitigation potential till 2030.'
# [Doc ID: bhutan_english_20220601, Chunk ID: 260]
#  'The short-term prioritized mitigation measures in human settlements will lead to a cumulative mitigation potential of up to 4,122 Gg CO2e which would require an investment of USD 101.84 million.'
# [Doc ID: bhutan_english_20220601, Chunk ID: 267]
#  'The total mitigation potential from the LEDS for industries is estimated between 999 Gg CO2e and 1,137 Gg CO2e per annum depending on the grid emission factor or a cumulative mitigation potential of 9,990 – 11,370 Gg CO2e till 2030.'
# [Doc ID: bhutan_english_20220601, Chunk ID: 296]
#  'd Target relative to the reference'
# [Doc ID: bhutan_english_20220601, Chunk ID: 325]
#  'multi-year target, as applicable.'
# [Doc ID: bhutan_english_20220601, Chunk ID: 324]
#  'b Whether it is a single-year or'
# [Doc ID: bhutan_english_20220601, Chunk ID: 242]
#  '5% annually'
# [Doc ID: bhutan_english_20220601, Chunk ID: 125]
#  '5% annually'
#
# Question: What is the official 2030 emissions reduction target for Bhutan, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: thailand_english_20221101, Chunk ID: 5]
#  'Business-as-usual projection from reference year 2005 in the absence of major climate change policies (BAU2030: approx. 555 MtCO2e)'
# [Doc ID: thailand_english_20221101, Chunk ID: 7]
#  '2021 – 2030 Target: Emission reduction relative to a Business-as-Usual baseline'
#
# Question: What is the official 2030 emissions reduction target for Thailand, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: togo_french_20220601, Chunk ID: 548]
#  'Gg CO2-eq entre 2010 et 2030, soit une augmentation de 254% ;'
# [Doc ID: togo_french_20220601, Chunk ID: 2963]
#  'à 80% en 2030'
# [Doc ID: togo_french_20220601, Chunk ID: 2989]
#  'forestière 30% à l’horizon 2050 ;'
#
# Question: What is the official 2030 emissions reduction target for Togo, based on the provided document chunks?
#
# Answer:
# role: system
# content: You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'
# role: user
# content: Context:
# [Doc ID: micronesia_(federated_states_of)_english_20221001, Chunk ID: 275]
#  'Conditional By 2030, reduce carbon dioxide emissions from electricity generation by more than 65% below 2000 levels'
# ...
#   {'role': 'user',
#    'content': "Context:\n[Doc ID: central_african_republic_french_20220601, Chunk ID: 837] \n 'GPL : 10% en 2030'\n[Doc ID: central_african_republic_french_20220601, Chunk ID: 348] \n '10 MW en 2030'\n[Doc ID: central_african_republic_french_20220601, Chunk ID: 353] \n '40 MWc en 2030'\n[Doc ID: central_african_republic_french_20220601, Chunk ID: 350] \n '60 MW en 2030'\n[Doc ID: central_african_republic_french_20220601, Chunk ID: 286] \n 'Figure 7: Emissions de GES du scenario BAU (2010-2030)'\n[Doc ID: central_african_republic_french_20220601, Chunk ID: 130] \n 'Observations (1986 à 2005)'\n\nQuestion: What is the official 2030 emissions reduction target for Central African Republic, based on the provided document chunks?\n\nAnswer:"}],
#  'Mauritania': [{'role': 'system',
#    'content': "You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'"},
#   {'role': 'user',
#    'content': "Context:\n[Doc ID: mauritania_french_20220601, Chunk ID: 1387] \n 'Objectifs l’horizon 2030'\n[Doc ID: mauritania_french_20220601, Chunk ID: 1444] \n 'Objectifs l’horizon 2030'\n[Doc ID: mauritania_french_20220601, Chunk ID: 1313] \n 'Objectifs l’horizon 2030'\n[Doc ID: mauritania_french_20220601, Chunk ID: 1352] \n 'Objectifs l’horizon 2030'\n[Doc ID: mauritania_french_20220601, Chunk ID: 1369] \n 'Objectifs l’horizon 2030'\n[Doc ID: mauritania_french_20220601, Chunk ID: 440] \n 'Période d’engagement : 2021 – 2030'\n\nQuestion: What is the official 2030 emissions reduction target for Mauritania, based on the provided document chunks?\n\nAnswer:"}],
#  'Mozambique': [{'role': 'system',
#    'content': "You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'"},
#   {'role': 'user',
#    'content': "Context:\n[Doc ID: mozambique_english_20220601, Chunk ID: 343] \n 'lion tCO2eq between 2020 and 2025 (see graph below). These reductions are estimates with a significant level'\n[Doc ID: mozambique_english_20220601, Chunk ID: 1013] \n 'by about 40 MtCO2eq between 2020 and 2025. The country expects to reduce these emissions in comparison to the BAU of the specific actions and, should Mozambique benefit'\n[Doc ID: mozambique_english_20220601, Chunk ID: 362] \n 'effort of about 1.2 tCO2 eq per capita by 2025, a very rel- evant figure when compared to Mozambique's total GHG'\n[Doc ID: mozambique_english_20220601, Chunk ID: 944] \n 'Mozambique developed the BAU scenario based on the sum of mitigation actions for the period 2020 to 2025, proposing expectations for annual emission reductions.'\n[Doc ID: mozambique_english_20220601, Chunk ID: 1012] \n 'The emission reduction target presented by Mozambique is divided into cumulative annual efforts between the years 2020 and 2025, whereby the country commits to reduce its emissions'\n[Doc ID: mozambique_english_20220601, Chunk ID: 940] \n 'It is understood that there is no base year and that the results will be compared with the BAU emissions scenarios of the implemented measures, considering two years to reach the target one'\n[Doc ID: mozambique_english_20220601, Chunk ID: 1499] \n 'emissions scenarios for mitigation pathways to achieve temperature rise of up to 1,5oC e 2oC10.'\n[Doc ID: mozambique_english_20220601, Chunk ID: 1155] \n 'rural electrification, which is estimated to average 120 000 new connections per year over the last 15 years (MTA, 2021).'\n[Doc ID: mozambique_english_20220601, Chunk ID: 376] \n '6 tCO2eq and 7 tCO2 eq when accounting for total GHG emissions per capita with LULUCF. Figure 03 below, graph-'\n[Doc ID: mozambique_english_20220601, Chunk ID: 999] \n 'The reference period for operationalization is from 2020 to 2025, so the mitigation results should be achieved by the year 2025.'\n[Doc ID: mozambique_english_20220601, Chunk ID: 959] \n 'Finally, Mozambique proposes to carry out a series of mitigation actions that in aggregate expect to achieve a reduction of GHG emissions by about 40 million tCO2 eq between 2020'\n[Doc ID: mozambique_english_20220601, Chunk ID: 930] \n 'Development of at least 2 national emission factors to achieve the use of TIER 2 in priority sectors (e.g. energy and waste)'\n[Doc ID: mozambique_english_20220601, Chunk ID: 1503] \n 'from renewable sources until 2015 and continues to be an electricity exporting country. Therefore, in practice its historical and current contribution to global emissions is very small.'\n[Doc ID: mozambique_english_20220601, Chunk ID: 1116] \n 'With regard to the distribution of the population by age group (table below), particularly between 2017 and 2025, there is a decrease in the population aged between zero and 14 years old;'\n[Doc ID: mozambique_english_20220601, Chunk ID: 366] \n 'emissions per capita which were respectively 0.6 tCO2eq in 1990 and about 2 tCO2eq today (total emissions with LULUCF). Just for comparison purposes the per capita'\n[Doc ID: mozambique_english_20220601, Chunk ID: 373] \n 'respectively 16 tCO2eq and 12 tCO2eq (total GHG emis- sions per capita without LULUCF). Globally these values are'\n[Doc ID: mozambique_english_20220601, Chunk ID: 1501] \n 'The evolution of Mozambique's emissions is insignificant compared to the global emission and in terms of emissions linked to the electricity sector it has the highest amount of generation'\n[Doc ID: mozambique_english_20220601, Chunk ID: 1385] \n 'To estimate the total emissions, the units of the other gases were converted into CO2equivalent (Gg CO2eq.), corresponding to the global warming potential of carbon dioxide in a period of 100 years.'\n[Doc ID: mozambique_english_20220601, Chunk ID: 1159] \n 'and 71.4% of national generation. Recent studies conducted in the country, indicate a huge potential for renewable energy p ...
#  'Brazil': [{'role': 'system',
#    'content': "You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'"},
#   {'role': 'user',
#    'content': "Context:\n[Doc ID: brazil_english_20241101, Chunk ID: 79] \n 'greenhouse gas emissions target for 2035 was based on an integrated modeling exercise'\n[Doc ID: brazil_english_20241101, Chunk ID: 464] \n 'regarding measuring the progress of subsequent NDCs in relation to this NDC, the base level of 59 percent below 2005 levels by 2035 or 1.05 GtCO2e should be taken as a reference.'\n[Doc ID: brazil_english_20241101, Chunk ID: 467] \n 'entire economy since its iNDC in 2015. Brazil also has a climate neutrality target by 2050.'\n[Doc ID: brazil_english_20241101, Chunk ID: 419] \n '(GTP), an accurate metric for assessing the contribution of different gases to climate change.'\n[Doc ID: brazil_english_20241101, Chunk ID: 263] \n 'Single-year targets in 2035.'\n\nQuestion: What is the official 2030 emissions reduction target for Brazil, based on the provided document chunks?\n\nAnswer:"}],
#  'Nicaragua': [{'role': 'system',
#    'content': "You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'"},
#   {'role': 'user',
#    'content': "Context:\n[Doc ID: nicaragua_spanish_20220601, Chunk ID: 397] \n 'en futuras NDC (2025 – 2030)'\n\nQuestion: What is the official 2030 emissions reduction target for Nicaragua, based on the provided document chunks?\n\nAnswer:"}],
#  'Mexico': [{'role': 'system',
#    'content': "You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'"},
#   {'role': 'user',
#    'content': "Context:\n[Doc ID: mexico_spanish_20221101, Chunk ID: 246] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 214] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 272] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 292] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 318] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 338] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 129] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 399] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 361] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 373] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 109] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 502] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 21] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 38] \n 'Actualización 2022 - 2030'\n[Doc ID: mexico_spanish_20221101, Chunk ID: 52] \n 'Actualización 2022 - 2030'\n\nQuestion: What is the official 2030 emissions reduction target for Mexico, based on the provided document chunks?\n\nAnswer:"}],
#  'Guyana': [{'role': 'system',
#    'content': "You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'"},
#   {'role': 'user',
#    'content': "Context:\n[Doc ID: guyana_english_20220601, Chunk ID: 67] \n 'This will result in a reduction of the annual emissions from the timber industry from 3.5M tCO2 to 2.3M tCO2, a 20% reduction from historic levels for this driver, and an 11% reduction in the overall historic level.'\n[Doc ID: guyana_english_20220601, Chunk ID: 61] \n 'In summary, avoided emissions contributions resulting from reforms in the timber and mining industries can contribute up to 48.7 MtCO2e to the global mitigation effort through the implementation of the Emission Reduction Programme described in greater detail below.'\n\nQuestion: What is the official 2030 emissions reduction target for Guyana, based on the provided document chunks?\n\nAnswer:"}],
#  'Republic of Moldova': [{'role': 'system',
#    'content': "You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'"},
#   {'role': 'user',
#    'content': "Context:\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 27] \n 'Absolute reduction as compared to base year emissions.'\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 4] \n 'a) holding the increase in the global average temperature to well below 2°C above pre-industrial levels'\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 119] \n 'In comparison with the 1990-year levels, by 2016 the Republic of Moldova's GHG total and net emissions were 67.5 per cent, respectively 68.5 per cent below (see Figure 2.2-2).'\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 1242] \n 'Lost heat production due to the current water supply deficit on Dniester River is estimated at US$ 4.6 million per year, based on the current import price and the assumption that energy production is affected proportionally by the water supply shortage.'\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 5] \n 'and pursuing efforts to limit the increase to 1.5 °C; and'\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 43] \n 'Single year target established for 2030'\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 30] \n 'Target relative to the reference indicator'\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 1188] \n 'IRR: 3% to 14% IRR: 4% to 15% BCR: 3.1- 170 BCR: 61-70'\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 1187] \n 'Indicated Rate of Return IRR: 8% to 15% IRR: 8% to 15% n/a'\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 503] \n 'Extreme weather events: - - - - -'\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 486] \n 'Extreme weather events: - - - - -'\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 507] \n 'Extreme weather events: - - - - -'\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 529] \n 'Extreme weather events: - - - - -'\n[Doc ID: republic_of_moldova_english_20220601, Chunk ID: 476] \n 'Extreme weather events: - - - - -'\n\nQuestion: What is the official 2030 emissions reduction target for Republic of Moldova, based on the provided document chunks?\n\nAnswer:"}],
#  'Andorra': [{'role': 'system',
#    'content': "You are a climate policy expert. Based only on the provided document chunks, extract the country’s 2030 emissions reduction target. If both unconditional and conditional targets exist, return both clearly. Include % reductions, baseline year/scenario (e.g. BAU), and any quantitative values (e.g. MtCO2e). Be concise. Always cite the relevant chunks using [Doc ID: <id>, Chunk ID: <id>]. If a target is not found, respond: 'The target is not clearly specified in the provided chunks.'"},
#   {'role': 'user',
#    'content': 'Context:\n[Doc ID: andorra_spanish_20250201, Chunk ID: 135] \n \'in net greenhouse gas emissions by 2035, compared to\'\n[Doc ID: andorra_spanish_20250201, Chunk ID: 136] \n \'2005 levels, with the ambition of achieving carbon neutrality by\'\n[Doc ID: andorra_spanish_20250201, Chunk ID: 140] \n \'target based on a "Business as Usual" (BAU) scenario to an\'\n[Doc ID: andorra_spanish_20250201, Chunk ID: 134] \n \'at COP28. This document establishes a 63% reduction target\'\n\nQuestion: What is the official 2030 emissions reduction target for Andorra, based on the provided document chunks?\n\nAnswer:'}]}

# %% [markdown]
# __Re-running our API queries__

# %%
llm_responses_empty_countries = {}
for country, message in second_loop_country_message_directory.items():
    print(f"Processing country: {country}")
    flattened_text = "".join([m["content"] for m in message])
    tokenized = tokenizer(flattened_text, return_tensors="pt", truncation = True)
    num_tokens = len(tokenized["input_ids"][0])
    
    print(f"[{country}] Token count: {num_tokens}")
    response = client.chat.completions.create(
        model=llm_model,
        max_tokens=1024,
        temperature=0.6,
        top_p=0.9,
        extra_body={
            "top_k": 50
        },
        messages=message
    )
    print(f"API response returned for: {country}")

    llm_responses_empty_countries[country] = response.choices[0].message.content
# Out:
# Processing country: Cameroon
# [Cameroon] Token count: 297
# API response returned for: Cameroon
# Processing country: Papua New Guinea
# [Papua New Guinea] Token count: 475
# API response returned for: Papua New Guinea
# Processing country: Sri Lanka
# [Sri Lanka] Token count: 496
# API response returned for: Sri Lanka
# Processing country: Uzbekistan
# [Uzbekistan] Token count: 512
# API response returned for: Uzbekistan
# Processing country: Saudi Arabia
# [Saudi Arabia] Token count: 318
# API response returned for: Saudi Arabia
# Processing country: Cuba
# [Cuba] Token count: 458
# API response returned for: Cuba
# Processing country: Maldives
# [Maldives] Token count: 512
# API response returned for: Maldives
# Processing country: Ghana
# [Ghana] Token count: 410
# API response returned for: Ghana
# Processing country: State of Palestine
# [State of Palestine] Token count: 512
# API response returned for: State of Palestine
# Processing country: China
# [China] Token count: 512
# API response returned for: China
# Processing country: Dominica
# [Dominica] Token count: 512
# API response returned for: Dominica
# Processing country: Angola
# [Angola] Token count: 512
# API response returned for: Angola
# Processing country: United Arab Emirates
# [United Arab Emirates] Token count: 512
# API response returned for: United Arab Emirates
# Processing country: Bhutan
# [Bhutan] Token count: 512
# API response returned for: Bhutan
# Processing country: Thailand
# [Thailand] Token count: 244
# API response returned for: Thailand
# Processing country: Togo
# [Togo] Token count: 262
# API response returned for: Togo
# Processing country: Micronesia (Federated States of)
# [Micronesia (Federated States of)] Token count: 512
# API response returned for: Micronesia (Federated States of)
# Processing country: Egypt
# [Egypt] Token count: 512
# API response returned for: Egypt
# Processing country: Timor-Leste
# [Timor-Leste] Token count: 419
# API response returned for: Timor-Leste
# Processing country: Suriname
# [Suriname] Token count: 512
# API response returned for: Suriname
# Processing country: Kazakhstan
# [Kazakhstan] Token count: 269
# API response returned for: Kazakhstan
# Processing country: Turkmenistan
# [Turkmenistan] Token count: 512
# API response returned for: Turkmenistan
# Processing country: Sudan
# [Sudan] Token count: 331
# API response returned for: Sudan
# Processing country: Nepal
# [Nepal] Token count: 512
# API response returned for: Nepal
# Processing country: Bolivia (Plurinational State of)
# [Bolivia (Plurinational State of)] Token count: 512
# API response returned for: Bolivia (Plurinational State of)
# Processing country: Antigua and Barbuda
# [Antigua and Barbuda] Token count: 512
# API response returned for: Antigua and Barbuda
# Processing country: Somalia
# [Somalia] Token count: 228
# API response returned for: Somalia
# Processing country: Syrian Arab Republic
# [Syrian Arab Republic] Token count: 211
# API response returned for: Syrian Arab Republic
# Processing country: San Marino
# [San Marino] Token count: 290
# API response returned for: San Marino
# Processing country: Senegal
# [Senegal] Token count: 212
# API response returned for: Senegal
# Processing country: Kuwait
# [Kuwait] Token count: 422
# API response returned for: Kuwait
# Processing country: Sierra Leone
# [Sierra Leone] Token count: 457
# API response returned for: Sierra Leone
# Processing country: Benin
# [Benin] Token count: 512
# API response returned for: Benin
# Processing country: Gabon
# [Gabon] Token count: 263
# API response returned for: Gabon
# Processing country: Malawi
# [Malawi] Token count: 512
# API response returned for: Malawi
# Processing country: Burundi
# [Burundi] Token count: 371
# API response returned for: Burundi
# Processing country: Democratic Republic of the Congo
# [Democratic Republic of the Congo] Token count: 202
# API response returned for: Democratic Republic of the Congo
# Processing country: Niue
# [Niue] Token count: 430
# API response returned for: Niue
# Processing country: Saint Vincent and the Grenadines
# [Saint Vincent and the Grenadines] Token count: 512
# API response returned for: Saint Vincent and the Grenadines
# Processing country: Azerbaijan
# [Azerbaijan] Token count: 512
# API response returned for: Azerbaijan
# Processing country: Chile
# [Chile] Token count: 512
# API response returned for: Chile
# Processing country: South Africa
# [South Africa] Token count: 287
# API response returned for: South Africa
# Processing country: Central African Republic
# [Central African Republic] Token count: 371
# API response returned for: Central African Republic
# Processing country: Mauritania
# [Mauritania] Token count: 370
# API response returned for: Mauritania
# Processing country: Mozambique
# [Mozambique] Token count: 512
# API response returned for: Mozambique
# Processing country: Brazil
# [Brazil] Token count: 373
# API response returned for: Brazil
# Processing country: Nicaragua
# [Nicaragua] Token count: 181
# API response returned for: Nicaragua
# Processing country: Mexico
# [Mexico] Token count: 512
# API response returned for: Mexico
# Processing country: Guyana
# [Guyana] Token count: 290
# API response returned for: Guyana
# Processing country: Republic of Moldova
# [Republic of Moldova] Token count: 512
# API response returned for: Republic of Moldova
# Processing country: Andorra
# [Andorra] Token count: 301
# API response returned for: Andorra

# %%
llm_responses_empty_countries
# Out:
# {'Cameroon': 'The target is not clearly specified in the provided chunks.',
#  'Papua New Guinea': 'The target is not clearly specified in the provided chunks.',
#  'Sri Lanka': 'The target is not clearly specified in the provided chunks.',
#  'Uzbekistan': 'The target is not clearly specified in the provided chunks.',
#  'Saudi Arabia': 'The target is not clearly specified in the provided chunks.',
#  'Cuba': 'The target is not clearly specified in the provided chunks.',
#  'Maldives': 'The target is not clearly specified in the provided chunks.',
#  'Ghana': 'The target is not clearly specified in the provided chunks.',
#  'State of Palestine': 'The target is not clearly specified in the provided chunks.',
#  'China': 'The target is not clearly specified in the provided chunks.',
#  'Dominica': 'The official 2030 emissions reduction target for Dominica is a 45% reduction below 2014 levels [Doc ID: dominica_english_20220701, Chunk ID: 250].',
#  'Angola': 'The target is not clearly specified in the provided chunks.',
#  'United Arab Emirates': 'The target is not clearly specified in the provided chunks.',
#  'Bhutan': 'The target is not clearly specified in the provided chunks.',
#  'Thailand': 'The target is not clearly specified in the provided chunks.',
#  'Togo': 'The target is not clearly specified in the provided chunks.',
#  'Micronesia (Federated States of)': 'The unconditional 2030 emissions reduction target for Micronesia (Federated States of) is: \n\n- More than 65% reduction of carbon dioxide emissions from electricity generation below 2000 levels [Doc ID: micronesia_(federated_states_of)_english_20221001, Chunk ID: 69]\n- More than 65% reduction of black carbon and methane emissions related to diesel electric generation below 2000 levels [Doc ID: micronesia_(federated_states_of)_english_20221001, Chunk ID: 74]\n\nThe conditional 2030 emissions reduction target for Micronesia (Federated States of) is: \n\n- More than 65% reduction of carbon dioxide emissions from electricity generation below 2000 levels [Doc ID: micronesia_(federated_states_of)_english_20221001, Chunk ID: 275]\n- More than 65% reduction of black carbon and methane emissions related to diesel electric generation below 2000 levels [Doc ID: micronesia_(federated_states_of)_english_20221001, Chunk ID: 298]\n\nNote that the targets are specified in terms of percentage reductions from 2000 levels, but do not include quantitative values in MtCO2e.',
#  'Egypt': 'The target is not clearly specified in the provided chunks.',
#  'Timor-Leste': 'The target is not clearly specified in the provided chunks.',
#  'Suriname': 'The target is not clearly specified in the provided chunks.',
#  'Kazakhstan': 'The target is not clearly specified in the provided chunks.',
#  'Turkmenistan': 'The target is not clearly specified in the provided chunks.',
#  'Sudan': 'The target is not clearly specified in the provided chunks.',
#  'Nepal': 'The unconditional 2030 emissions reduction target for Nepal is a 23% reduction in emissions from the business-as-usual (BAU) scenario, which translates to a reduction from approximately 2,064 Gg CO2 eq. to 1,599 Gg CO2 eq. [Doc ID: nepal_english_20220601, Chunk ID: 45].',
#  'Bolivia (Plurinational State of)': 'The target is not clearly specified in the provided chunks.',
#  'Antigua and Barbuda': 'The target is not clearly specified in the provided chunks.',
#  'Somalia': 'The target is not clearly specified in the provided chunks.',
#  'Syrian Arab Republic': 'The target is not clearly specified in the provided chunks.',
#  'San Marino': 'The target is not clearly specified in the provided chunks.',
#  'Senegal': 'The target is not clearly specified in the provided chunks.',
#  'Kuwait': 'The target is not clearly specified in the provided chunks.',
#  'Sierra Leone': 'The target is not clearly specified in the provided chunks.',
#  'Benin': 'The target is not clearly specified in the provided chunks.',
#  'Gabon': 'The target is not clearly specified in the provided chunks.',
#  'Malawi': 'The target is not clearly specified in the provided chunks.',
#  'Burundi': 'The target is not clearly specified in the provided chunks.',
#  'Democratic Republic of the Congo': 'The target is not clearly specified in the provided chunks.',
#  'Niue': 'The target is not clearly specified in the provided chunks.',
#  'Saint Vincent and the Grenadines': 'The target is not clearly specified in the provided chunks.',
#  'Azerbaijan': 'The target is not clearly specified in the provided chunks.',
#  'Chile': 'The target is not clearly specified in the provided chunks.',
#  'South Africa': 'The target is not clearly specified in the provided chunks.',
#  'Central African Republic': 'The target is not clearly specified in the provided chunks.',
#  'Mauritania': 'The target is not clearly specified in the provided chunks.',
#  'Mozambique': 'The target is not clearly specified in the provided chunks.',
#  'Brazil': 'The target is not clearly specified in the provided chunks.',
#  'Nicaragua': 'The target is not clearly specified in the provided chunks.',
#  'Mexico': 'The target is not clearly specified in the provided chunks.',
#  'Guyana': 'The target is not clearly specified in the provided chunks.',
#  'Republic of Moldova': 'The target is not clearly specified in the provided chunks.',
#  'Andorra': 'The target is not clearly specified in the provided chunks.'}

# %%
still_non_retrieved_countries = []
redeemed_countries = []
for key, value in llm_responses_empty_countries.items():
    if value == 'The target is not clearly specified in the provided chunks.':
        still_non_retrieved_countries.append(key)
    
    else:
        redeemed_countries.append(key)

print(len(still_non_retrieved_countries), len(redeemed_countries))
# Out:
# 48 3

# %%
pickle.dump(llm_responses_empty_countries, open("llm_responses_non_retrieved_countries.pkl", "wb")) 
pickle.dump(llm_responses, open("llm_responses.pkl", "wb"))
pickle.dump(complete_embeddings_df, open("complete_embeddings_df.pkl", "wb"))

# %% [markdown]
# ##### ======= ADDITIONAL: INCOMPLETE WORK =========
# __I had also wanted to implement an additional set of retrieved chunks for our documents in spanish and french by constructing queries in those native language and then running a similarity search through our chunks database. I didn't get time to implement this, but have left in the NB as a WIP to finish personally later__

# %%
query = text("""
    SELECT DISTINCT 
        split_part(doc_id, '_', array_length(string_to_array(doc_id, '_'), 1) - 1) AS language
    FROM doc_chunks
""")

with engine.connect() as conn:
    languages = [row[0] for row in conn.execute(query).fetchall()]

# %%
languages
# Out:
# ['english', 'french', 'spanish']

# %%
language_queries = {
    "french": "Quel est l’objectif de réduction des émissions visé par le pays d’ici 2030 ?",
    "spanish": "¿Cuál es el objetivo de reducción de emisiones que persigue el país para 2030?"
}

query_embeddings = {
    lang: get_pooled_embeddings(tokenize_for_transformer_climate_roberta(q), climate_roberta_model)
    for lang, q in language_queries.items()
}

# %%
query_embeddings['english']
# Out:
# (768,)

# %%
all_lang_results = []

for lang in language_queries.keys():
    query = text("""
        SELECT 
            doc_chunks.doc_id,
            doc_chunks.chunk_index,
            doc_chunks.content,
            documents.country,
            (doc_chunks.embedding <=> :embedding) AS cosine_distance
        FROM doc_chunks
        LEFT JOIN documents ON doc_chunks.doc_id = documents.doc_id
        WHERE 
            split_part(doc_chunks.doc_id, '_', array_length(string_to_array(doc_chunks.doc_id, '_'), 1) - 1) = :lang
            AND doc_chunks.content ILIKE '%2030%'
            AND (doc_chunks.embedding <=> :embedding) <= :distance_threshold
        ORDER BY cosine_distance ASC
        LIMIT 10
    """)

    with engine.connect() as conn:
        results = conn.execute(query, {
            "embedding": query_embeddings[lang],
            "lang": lang,
            "distance_threshold": 0.05
        }).fetchall()

    df = pd.DataFrame(results, columns=[
        "doc_id", "chunk_index", "content", "country", "cosine_distance"
    ])
    df["language"] = lang
    df["cosine_similarity"] = 1 - df["cosine_distance"]
    all_lang_results.append(df)

# %%
multilingual_df = pd.concat(all_lang_results, ignore_index=True)
